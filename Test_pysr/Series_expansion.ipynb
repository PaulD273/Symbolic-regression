# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
from scipy.special import jn,j0, factorial
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# **Goal**: Obtain the Taylor series expansion of synthetic data generated from cosine and Bessel function

# %% [markdown]
# \begin{aligned}
# \cos(x) &= 1 - \frac{1}{2}x^2 + \frac{1}{24}x^4 - \frac{1}{720}x^6 + \frac{1}{40320}x^8 - \cdots
# \end{aligned}

# %%
# Dataset
np.random.seed(0)
# Small values of x
x = np.linspace(-2, 2, 500)
noise = 0.001 * np.random.randn(len(x))
y = np.cos(x) + noise

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %%
model = PySRRegressor(
    niterations=300,
    populations=30,
    binary_operators=["+", "*"],
    unary_operators=["sq(x) = x^2/2", "exa(x) = x^6"],
    extra_sympy_mappings={"sq": lambda x: x**2/2, "exa" : lambda x: x**6},
    #maxsize = 20
)
model.fit(x.reshape(-1, 1), y)
# Out:
# /home/paolo/.conda/envs/coderefinery/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.430e+05
# Progress: 1385 / 9000 total iterations (15.389%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.998e-01  0.000e+00  y = 0.4528
# 5           2.083e-02  5.652e-01  y = sq(sq(x₀) + -1.4798)
# 6           1.816e-03  2.440e+00  y = (sq(x₀) * -0.74316) + 0.9503
# 7           1.816e-03  2.384e-07  y = ((x₀ * x₀) * -0.37158) + 0.9503
# 8           1.816e-03  1.669e-06  y = (sq(x₀ + 7.3007e-05) * -0.74316) + 0.9503
# 9           1.816e-03  2.980e-07  y = ((x₀ + 0.00016237) * (x₀ * -0.37158)) + 0.9503
# 10          1.615e-03  1.172e-01  y = exa((x₀ * (x₀ * -0.0047209)) + 1.6871) + -22.096
# 11          2.961e-06  6.302e+00  y = (((sq(x₀) * 0.1386) + -0.98171) * sq(x₀)) + 0.9982
# 14          1.249e-06  2.877e-01  y = (sq(x₀ * (((x₀ * x₀) * -0.056143) + 1.4298)) + -2.0549...
#                                       ) * -0.4864
# 15          1.198e-06  4.203e-02  y = (sq((((sq(x₀) * -0.1052) + 1.3449) * 1.1038) * x₀) + -...
#                                       2.2178) * -0.45059
# 18          9.927e-07  6.258e-02  y = ((sq(x₀ * 0.70652) + sq(x₀ * ((sq(x₀) * -0.12881) + 1....
#                                       113))) + -1.7388) * -0.57505
# 19          9.913e-07  1.477e-03  y = ((sq(sq(x₀)) * 0.10176) + (sq(x₀ * ((sq(x₀) * -0.13076...
#                                       ) + 1.368)) + -1.8737)) * -0.53365
# 20          9.909e-07  3.639e-04  y = (sq(x₀ * 0.71788) + (sq(((sq(x₀) * -0.11872) + 1.025) ...
#                                       * (x₀ * -1.1013)) + -1.7905)) * -0.55845
# 22          9.845e-07  3.211e-03  y = (sq(x₀ * (((sq(x₀ * 0.92924) * -0.1327) + 1.0334) * -1...
#                                       .1107)) + (sq(x₀ * -0.68318) + -1.7867)) * -0.55959
# 24          9.823e-07  1.150e-03  y = ((sq((x₀ * 0.68742) + 0.00014317) + -1.7875) + sq((x₀ ...
#                                       * -1.1098) * ((sq(x₀ * 0.92947) * -0.13323) + 1.0324))) * ...
#                                       -0.55937
# 26          9.822e-07  4.497e-05  y = (((x₀ * 9.6856e-05) + -1.7875) + (sq(x₀ * 0.68741) + s...
#                                       q(x₀ * (((sq(x₀ * 0.92958) * -0.1332) + 1.0324) * -1.1098)...
#                                       ))) * -0.55936
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.500e+05
# Progress: 2834 / 9000 total iterations (31.489%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.998e-01  0.000e+00  y = 0.4528
# 5           2.083e-02  5.652e-01  y = sq(sq(x₀) + -1.4798)
# 6           1.816e-03  2.440e+00  y = (sq(x₀) * -0.74316) + 0.9503
# 7           1.816e-03  4.768e-07  y = (x₀ * (x₀ * -0.37158)) + 0.9503
# 8           1.816e-03  1.490e-06  y = (sq(x₀ + 7.3007e-05) * -0.74316) + 0.9503
# 9           1.816e-03  2.980e-07  y = ((x₀ + 0.00016237) * (x₀ * -0.37158)) + 0.9503
# 10          8.800e-05  3.027e+00  y = exa(((x₀ * -0.034272) * x₀) + 1.1849) + -1.7696
# 11          2.961e-06  3.392e+00  y = (sq(x₀) * ((sq(x₀) * 0.1386) + -0.98171)) + 0.9982
# 13          1.198e-06  4.525e-01  y = -0.5314 * (sq(x₀ * ((sq(x₀) * -0.10693) + 1.367)) + -1...
#                                       .8805)
# 15          1.194e-06  1.682e-03  y = (sq((x₀ + 7.0017e-05) * ((sq(x₀) * -0.10694) + 1.367))...
#                                        + -1.8805) * -0.53142
# 18          9.846e-07  6.419e-02  y = ((sq(x₀ * ((sq(x₀) * -0.17644) + 1.6028)) + -3.4642) +...
#                                        sq(x₀ * 0.94324)) * -0.28861
# 19          9.842e-07  4.407e-04  y = (((sq(sq(x₀)) * 0.097658) + -1.8545) + sq(((sq(x₀) * -...
#                                       0.12924) + 1.3607) * x₀)) * -0.53913
# 21          9.804e-07  1.920e-03  y = ((sq(sq(x₀)) * 0.096597) + (sq(((sq(x₀) * -0.12941) + ...
#                                       1.3674) * (x₀ + 7.2639e-05)) + -1.8729)) * -0.53383
# 25          9.795e-07  2.300e-04  y = ((sq(x₀ * ((sq(x₀) * -0.1294) + 1.3674)) + (sq(sq(x₀ +...
#                                        (exa(sq(x₀)) * 3.5051e-05))) * 0.096582)) + -1.8729) * -0...
#                                       .53383
# 26          9.774e-07  2.190e-03  y = (sq(((sq(x₀) * -0.1294) + 1.3674) * x₀) + ((sq(sq(x₀ +...
#                                        (exa(sq(sq(x₀))) * 4.5017e-05))) * 0.096582) + -1.8729)) ...
#                                       * -0.53383
# 27          9.755e-07  1.898e-03  y = -0.53383 * (-1.8729 + (sq(x₀ * ((sq(x₀) * -0.1294) + 1...
#                                       .3674)) + (sq(sq(sq(sq(exa(sq(x₀))) * 4.5017e-05) + x₀)) *...
#                                        0.096582)))
# 28          9.750e-07  5.114e-04  y = (-1.8729 + (sq(x₀ * ((sq(x₀) * -0.1294) + 1.3674)) + (...
#                                       0.096582 * sq(sq(x₀ + sq(-4.8491e-05 * sq(exa(sq(sq(x₀))))...
#                                       )))))) * -0.53383
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+05
# Progress: 4366 / 9000 total iterations (48.511%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.998e-01  0.000e+00  y = 0.4528
# 5           2.083e-02  5.652e-01  y = sq(sq(x₀) + -1.4798)
# 6           1.816e-03  2.440e+00  y = (sq(x₀) * -0.74315) + 0.9503
# 7           1.816e-03  3.576e-07  y = (x₀ * (x₀ * -0.37158)) + 0.9503
# 8           1.816e-03  1.490e-06  y = (sq(x₀ + 7.3007e-05) * -0.74316) + 0.9503
# 9           1.816e-03  2.980e-07  y = ((x₀ + 0.00016237) * (x₀ * -0.37158)) + 0.9503
# 10          5.964e-06  5.719e+00  y = exa(((x₀ * x₀) * -0.039588) + 1.1597) + -1.4329
# 11          2.961e-06  7.004e-01  y = (sq(x₀) * ((sq(x₀) * 0.1386) + -0.98171)) + 0.9982
# 12          2.961e-06  5.960e-08  y = ((sq(sq(x₀)) * 0.27721) + (sq(x₀) * -0.98171)) + 0.998...
#                                       2
# 13          1.198e-06  9.050e-01  y = -0.5314 * (sq(x₀ * ((sq(x₀) * -0.10693) + 1.367)) + -1...
#                                       .8805)
# 15          1.194e-06  1.682e-03  y = (sq((x₀ + 7.0017e-05) * ((sq(x₀) * -0.10694) + 1.367))...
#                                        + -1.8805) * -0.53142
# 16          9.895e-07  1.876e-01  y = (sq(x₀) + (-3.4838 + sq(((sq(x₀) * -0.18209) + 1.5752)...
#                                        * x₀))) * -0.287
# 18          9.840e-07  2.805e-03  y = ((sq(x₀ * 0.94326) + -3.4642) + sq(((sq(x₀) * -0.17643...
#                                       ) + 1.6028) * x₀)) * -0.28861
# 21          9.804e-07  1.213e-03  y = ((sq((x₀ + 7.264e-05) * ((sq(x₀) * -0.12941) + 1.3674)...
#                                       ) + -1.8729) + (sq(sq(x₀)) * 0.096597)) * -0.53383
# 25          9.794e-07  2.726e-04  y = ((sq(x₀ * ((sq(x₀) * -0.1294) + 1.3674)) + (sq(sq((sq(...
#                                       exa(x₀)) * 9.4384e-07) + x₀)) * 0.096582)) + -1.8729) * -0...
#                                       .53383
# 26          9.753e-07  4.210e-03  y = ((sq(sq(x₀ + exa(exa(sq(x₀ * 0.65892))))) * 0.096609) ...
#                                       + (sq(((sq(x₀) * -0.12941) + 1.3674) * x₀) + -1.8729)) * -...
#                                       0.53383
# 28          9.750e-07  1.465e-04  y = ((sq(x₀ * ((sq(x₀) * -0.1294) + 1.3674)) + -1.8729) + ...
#                                       (sq(sq(sq(sq(exa(sq(sq(x₀)))) * -5.3753e-05) + x₀)) * 0.09...
#                                       6582)) * -0.53383
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.670e+05
# Progress: 5969 / 9000 total iterations (66.322%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.998e-01  0.000e+00  y = 0.4528
# 5           2.083e-02  5.652e-01  y = sq(sq(x₀) + -1.4798)
# 6           1.816e-03  2.440e+00  y = (sq(x₀) * -0.74315) + 0.9503
# 7           1.816e-03  3.576e-07  y = (x₀ * (x₀ * -0.37158)) + 0.9503
# 8           1.816e-03  1.490e-06  y = (sq(x₀ + 7.3007e-05) * -0.74316) + 0.9503
# 9           1.816e-03  2.980e-07  y = ((x₀ + 0.00016237) * (x₀ * -0.37158)) + 0.9503
# 10          5.964e-06  5.719e+00  y = exa(((x₀ * x₀) * -0.039588) + 1.1597) + -1.4329
# 11          2.961e-06  7.004e-01  y = (sq(x₀) * ((sq(x₀) * 0.1386) + -0.98171)) + 0.9982
# 12          2.961e-06  5.960e-08  y = ((sq(sq(x₀)) * 0.27721) + (sq(x₀) * -0.98171)) + 0.998...
#                                       2
# 13          1.198e-06  9.050e-01  y = (sq(((sq(x₀) * -0.10552) + 1.3491) * x₀) + -1.8316) * ...
#                                       -0.54559
# 15          1.194e-06  1.673e-03  y = (sq((x₀ + 7.0017e-05) * ((sq(x₀) * -0.10694) + 1.367))...
#                                        + -1.8805) * -0.53142
# 16          9.895e-07  1.876e-01  y = (sq(x₀) + (-3.4838 + sq(((sq(x₀) * -0.18209) + 1.5752)...
#                                        * x₀))) * -0.287
# 18          9.840e-07  2.805e-03  y = ((sq(x₀ * 0.94326) + -3.4642) + sq(((sq(x₀) * -0.17643...
#                                       ) + 1.6028) * x₀)) * -0.28861
# 20          9.803e-07  1.901e-03  y = ((sq(((sq(x₀) * -0.17646) + 1.6027) * x₀) + -3.464) + ...
#                                       sq((x₀ * 0.94345) + 0.00017977)) * -0.28862
# 21          9.801e-07  1.881e-04  y = ((sq((exa(-0.24599) + x₀) * 0.94326) + sq(((sq(x₀) * -...
#                                       0.17643) + 1.6028) * x₀)) + -3.4642) * -0.28861
# 25          9.794e-07  1.845e-04  y = ((sq(x₀ * ((sq(x₀) * -0.1294) + 1.3674)) + (sq(sq((sq(...
#                                       exa(x₀)) * 9.4384e-07) + x₀)) * 0.096582)) + -1.8729) * -0...
#                                       .53383
# 26          9.753e-07  4.210e-03  y = ((sq(sq(x₀ + exa(exa(sq(x₀ * 0.65892))))) * 0.096609) ...
#                                       + (sq(((sq(x₀) * -0.12941) + 1.3674) * x₀) + -1.8729)) * -...
#                                       0.53383
# 28          9.749e-07  1.803e-04  y = (((0.096582 * sq(sq(sq(sq(exa(sq(sq(x₀)))) * 5.1833e-0...
#                                       5) + x₀))) + sq(x₀ * ((-0.1294 * sq(x₀)) + 1.3674))) + -1....
#                                       8729) * -0.53383
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.750e+05
# Progress: 7426 / 9000 total iterations (82.511%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.998e-01  0.000e+00  y = 0.4528
# 5           2.083e-02  5.652e-01  y = sq(sq(x₀) + -1.4798)
# 6           1.816e-03  2.440e+00  y = (sq(x₀) * -0.74315) + 0.9503
# 7           1.816e-03  3.576e-07  y = (x₀ * (x₀ * -0.37158)) + 0.9503
# 8           1.816e-03  1.609e-06  y = (sq(x₀ + 6.4248e-05) * -0.74315) + 0.9503
# 9           1.816e-03  1.788e-07  y = ((x₀ + 0.00016237) * (x₀ * -0.37158)) + 0.9503
# 10          5.964e-06  5.719e+00  y = exa(((x₀ * x₀) * -0.039588) + 1.1597) + -1.4329
# 11          2.961e-06  7.004e-01  y = (sq(x₀) * ((sq(x₀) * 0.1386) + -0.98171)) + 0.9982
# 12          2.961e-06  8.941e-07  y = ((sq(sq(x₀)) * 0.27719) + 0.9982) + (sq(x₀) * -0.9817)
# 13          1.198e-06  9.050e-01  y = (sq(((sq(x₀) * -0.10552) + 1.3491) * x₀) + -1.8316) * ...
#                                       -0.54559
# 15          1.194e-06  1.673e-03  y = (sq((x₀ + 7.0017e-05) * ((sq(x₀) * -0.10694) + 1.367))...
#                                        + -1.8805) * -0.53142
# 16          9.895e-07  1.876e-01  y = (sq(x₀) + (-3.4838 + sq(((sq(x₀) * -0.18209) + 1.5752)...
#                                        * x₀))) * -0.287
# 17          9.839e-07  5.762e-03  y = (((sq(x₀) * -0.99828) + (exa(x₀) * -0.0011303)) + (sq(...
#                                       sq(x₀)) * 0.32672)) + 0.99979
# 20          9.803e-07  1.226e-03  y = ((sq(((sq(x₀) * -0.17646) + 1.6027) * x₀) + sq((x₀ + 0...
#                                       .00022173) * 0.94345)) + -3.464) * -0.28862
# 21          9.801e-07  1.598e-04  y = (sq((exa(-0.24599) + x₀) * 0.94326) + (sq(((sq(x₀) * -...
#                                       0.17643) + 1.6028) * x₀) + -3.4642)) * -0.28861
# 25          9.794e-07  1.843e-04  y = ((sq(x₀ * ((sq(x₀) * -0.1294) + 1.3674)) + (sq(sq((sq(...
#                                       exa(x₀)) * 9.4384e-07) + x₀)) * 0.096582)) + -1.8729) * -0...
#                                       .53383
# 26          9.753e-07  4.210e-03  y = ((sq(sq(x₀ + exa(exa(sq(x₀ * 0.65892))))) * 0.096609) ...
#                                       + (sq(((sq(x₀) * -0.12941) + 1.3674) * x₀) + -1.8729)) * -...
#                                       0.53383
# 28          9.749e-07  1.803e-04  y = (((0.096582 * sq(sq(sq(sq(exa(sq(sq(x₀)))) * 5.1833e-0...
#                                       5) + x₀))) + sq(x₀ * ((-0.1294 * sq(x₀)) + 1.3674))) + -1....
#                                       8729) * -0.53383
# 30          9.747e-07  8.474e-05  y = ((0.096582 * sq(sq(sq(sq(x₀ + exa(sq(sq(x₀)))) * 5.183...
#                                       3e-05) + x₀))) + (sq(x₀ * (1.3674 + (sq(x₀) * -0.1294))) +...
#                                        -1.8729)) * -0.53383
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.760e+05
# Progress: 8805 / 9000 total iterations (97.833%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.998e-01  0.000e+00  y = 0.4528
# 5           2.083e-02  5.652e-01  y = sq(sq(x₀) + -1.4798)
# 6           1.816e-03  2.440e+00  y = (sq(x₀) * -0.74315) + 0.9503
# 7           1.816e-03  3.576e-07  y = (x₀ * (x₀ * -0.37158)) + 0.9503
# 8           1.816e-03  1.609e-06  y = (sq(x₀ + 6.4248e-05) * -0.74315) + 0.9503
# 9           1.816e-03  1.788e-07  y = ((x₀ + 0.00016237) * (x₀ * -0.37158)) + 0.9503
# 10          3.081e-06  6.379e+00  y = sq(((x₀ * -0.26431) * x₀) + 1.8606) + -0.73242
# 11          2.961e-06  3.978e-02  y = (((sq(x₀) * 0.1386) + -0.98171) * sq(x₀)) + 0.9982
# 12          2.961e-06  5.126e-06  y = (sq(x₀) * -0.98171) + ((sq(sq(x₀)) * 0.2772) + 0.9982)
# 13          1.198e-06  9.052e-01  y = (sq(((sq(x₀) * -0.10637) + 1.3602) * x₀) + -1.8619) * ...
#                                       -0.53669
# 15          1.194e-06  1.589e-03  y = (sq((x₀ + 7.0017e-05) * ((sq(x₀) * -0.10694) + 1.367))...
#                                        + -1.8805) * -0.53142
# 16          9.851e-07  1.921e-01  y = ((sq(x₀ * ((sq(x₀) * -0.18443) + 1.6379)) + sq(x₀)) + ...
#                                       -3.6876) * -0.27113
# 17          9.839e-07  1.273e-03  y = (((exa(x₀) * -0.0011303) + (sq(x₀) * -0.99828)) + (sq(...
#                                       sq(x₀)) * 0.32672)) + 0.99979
# 20          9.803e-07  1.226e-03  y = ((sq(((sq(x₀) * -0.17646) + 1.6027) * x₀) + sq((x₀ + 0...
#                                       .00022173) * 0.94345)) + -3.464) * -0.28862
# 21          9.801e-07  1.598e-04  y = (sq((exa(-0.24599) + x₀) * 0.94326) + (sq(((sq(x₀) * -...
#                                       0.17643) + 1.6028) * x₀) + -3.4642)) * -0.28861
# 25          9.793e-07  2.000e-04  y = ((sq(sq(x₀ + sq(exa(x₀ * 0.31196)))) * 0.096609) + (sq...
#                                       (x₀ * ((sq(x₀) * -0.12941) + 1.3674)) + -1.8729)) * -0.533...
#                                       83
# 26          9.753e-07  4.147e-03  y = ((sq(sq(x₀ + exa(exa(sq(x₀ * 0.65892))))) * 0.096609) ...
#                                       + (sq(((sq(x₀) * -0.12941) + 1.3674) * x₀) + -1.8729)) * -...
#                                       0.53383
# 28          9.749e-07  1.803e-04  y = (((0.096582 * sq(sq(sq(sq(exa(sq(sq(x₀)))) * 5.1833e-0...
#                                       5) + x₀))) + sq(x₀ * ((-0.1294 * sq(x₀)) + 1.3674))) + -1....
#                                       8729) * -0.53383
# 30          9.747e-07  8.474e-05  y = ((0.096582 * sq(sq(sq(sq(x₀ + exa(sq(sq(x₀)))) * 5.183...
#                                       3e-05) + x₀))) + (sq(x₀ * (1.3674 + (sq(x₀) * -0.1294))) +...
#                                        -1.8729)) * -0.53383
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.998e-01  0.000e+00  y = 0.4528
# 5           2.083e-02  5.652e-01  y = sq(sq(x₀) + -1.4798)
# 6           1.816e-03  2.440e+00  y = (sq(x₀) * -0.74315) + 0.9503
# 7           1.816e-03  3.576e-07  y = (x₀ * (x₀ * -0.37158)) + 0.9503
# 8           1.816e-03  1.609e-06  y = (sq(x₀ + 6.4248e-05) * -0.74315) + 0.9503
# 9           1.816e-03  1.788e-07  y = ((x₀ + 0.00016237) * (x₀ * -0.37158)) + 0.9503
# 10          3.081e-06  6.379e+00  y = sq(((x₀ * -0.26431) * x₀) + 1.8606) + -0.73242
# 11          2.961e-06  3.978e-02  y = (((sq(x₀) * 0.1386) + -0.98171) * sq(x₀)) + 0.9982
# 12          2.961e-06  5.126e-06  y = (sq(x₀) * -0.98171) + ((sq(sq(x₀)) * 0.2772) + 0.9982)
# 13          1.198e-06  9.052e-01  y = (sq(((sq(x₀) * -0.10637) + 1.3602) * x₀) + -1.8619) * ...
#                                       -0.53669
# 15          1.194e-06  1.589e-03  y = (sq((x₀ + 7.0017e-05) * ((sq(x₀) * -0.10694) + 1.367))...
#                                        + -1.8805) * -0.53142
# 16          9.851e-07  1.921e-01  y = ((sq(x₀ * ((sq(x₀) * -0.18443) + 1.6379)) + sq(x₀)) + ...
#                                       -3.6876) * -0.27113
# 17          9.839e-07  1.273e-03  y = (((exa(x₀) * -0.0011303) + (sq(x₀) * -0.99828)) + (sq(...
#                                       sq(x₀)) * 0.32672)) + 0.99979
# 20          9.803e-07  1.226e-03  y = ((sq(((sq(x₀) * -0.17646) + 1.6027) * x₀) + sq((x₀ + 0...
#                                       .00022173) * 0.94345)) + -3.464) * -0.28862
# 21          9.801e-07  1.598e-04  y = (sq((exa(-0.24599) + x₀) * 0.94326) + (sq(((sq(x₀) * -...
#                                       0.17643) + 1.6028) * x₀) + -3.4642)) * -0.28861
# 25          9.793e-07  2.000e-04  y = ((sq(sq(x₀ + sq(exa(x₀ * 0.31196)))) * 0.096609) + (sq...
#                                       (x₀ * ((sq(x₀) * -0.12941) + 1.3674)) + -1.8729)) * -0.533...
#                                       83
# 26          9.753e-07  4.147e-03  y = ((sq(sq(x₀ + exa(exa(sq(x₀ * 0.65892))))) * 0.096609) ...
#                                       + (sq(((sq(x₀) * -0.12941) + 1.3674) * x₀) + -1.8729)) * -...
#                                       0.53383
# 28          9.749e-07  1.803e-04  y = (((0.096582 * sq(sq(sq(sq(exa(sq(sq(x₀)))) * 5.1833e-0...
#                                       5) + x₀))) + sq(x₀ * ((-0.1294 * sq(x₀)) + 1.3674))) + -1....
#                                       8729) * -0.53383
# 30          9.747e-07  8.474e-05  y = ((0.096582 * sq(sq(sq(sq(x₀ + exa(sq(sq(x₀)))) * 5.183...
#                                       3e-05) + x₀))) + (sq(x₀ * (1.3674 + (sq(x₀) * -0.1294))) +...
#                                        -1.8729)) * -0.53383
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                         0.45279706
# 	1         5.651831e-01                            sq(sq(x0) + -1.4798226)
# 	2         2.439820e+00                 (sq(x0) * -0.7431538) + 0.95030165
# 	3         3.854969e-07              (x0 * (x0 * -0.3715771)) + 0.95030147
# 	4         1.597060e-06  (sq(x0 + 6.4248285e-5) * -0.74315494) + 0.9503...
# 	5         1.652133e-07  ((x0 + 0.00016237372) * (x0 * -0.3715771)) + 0...
# 	6         6.379086e+00  sq(((x0 * -0.2643071) * x0) + 1.8606046) + -0....
# 	7         3.978010e-02  (((sq(x0) * 0.13860127) + -0.9817061) * sq(x0)...
# 	8         5.133887e-06  (sq(x0) * -0.98170793) + ((sq(sq(x0)) * 0.2772...
# 	9   >>>>  9.051570e-01  (sq(((sq(x0) * -0.106374405) + 1.3602041) * x0...
# 	10        1.588726e-03  (sq((x0 + 7.0016955e-5) * ((sq(x0) * -0.106936...
# 	11        1.920922e-01  ((sq(x0 * ((sq(x0) * -0.18442984) + 1.637924))...
# 	12        1.273047e-03  (((exa(x0) * -0.0011302682) + (sq(x0) * -0.998...
# 	13        1.225661e-03  ((sq(((sq(x0) * -0.1764634) + 1.6026713) * x0)...
# 	14        1.598698e-04  (sq((exa(-0.24598949) + x0) * 0.94325846) + (s...
# 	15        1.999587e-04  ((sq(sq(x0 + sq(exa(x0 * 0.31195915)))) * 0.09...
# 	16        4.146804e-03  ((sq(sq(x0 + exa(exa(sq(x0 * 0.65891707))))) *...
# 	17        1.803438e-04  (((0.09658187 * sq(sq(sq(sq(exa(sq(sq(x0)))) *...
# 	18        8.473329e-05  ((0.09658187 * sq(sq(sq(sq(x0 + exa(sq(sq(x0))...
#
# 	            loss  complexity
# 	0   1.997566e-01           1
# 	1   2.082943e-02           5
# 	2   1.815839e-03           6
# 	3   1.815838e-03           7
# 	4   1.815835e-03           8
# 	5   1.815835e-03           9
# 	6   3.080879e-06          10
# 	7   2.960727e-06          11
# 	8   2.960712e-06          12
# 	9   1.197544e-06          13
# 	10  1.193745e-06          15
# 	11  9.851150e-07          16
# 	12  9.838617e-07          17
# 	13  9.802507e-07          20
# 	14  9.800940e-07          21
# 	15  9.793104e-07          25
# 	16  9.752578e-07          26
# 	17  9.749061e-07          28
# 	18  9.747409e-07          30
# ]
#   - outputs/20250926_103811_tsde74/hall_of_fame.csv

# %%
model.sympy()
# Out:
# (x0**2*(1.3602041 + (x0**2/2)*(-0.106374405))**2/2 - 1.8619431)*(-0.53669125)

# %%
# Define the symbolic variable
x0 = sympy.symbols('x0')

# Build each part of the expression
expr = (sympy.simplify(model.sympy()))

# Optionally simplify or expand the expression
expanded_expr = sympy.expand(expr)
expanded_expr
# Out:
# -0.000759117171754911*x0**6 + 0.0388271704796444*x0**4 - 0.496481051788833*x0**2 + 0.999288569767875

# %%
1/factorial(6), 1/factorial(4)
# Out:
# (0.001388888888888889, 0.041666666666666664)

# %%
sympy.latex(expanded_expr)
# Out:
# '- 0.000759117171754911 x_{0}^{6} + 0.0388271704796444 x_{0}^{4} - 0.496481051788833 x_{0}^{2} + 0.999288569767875'

# %% [markdown]
# <ul>
# Results around $x = 0$ in the range $\left[-1, +1\right]$
# <li> obtained for niter=100, maxsize=20, noise=0.001 and fitting with sq: $$0.0404522973487644 x_{0}^{4} - 0.49966508442707 x_{0}^{2} + 0.9999080045205$$
# <li> obtained for niter=100, maxsize=20, noise=0.001 and fitting with only + and *: $$0.04024306 x_{0}^{4} - 0.49952888 x_{0}^{2} + 0.99990594$$
# Increasing maxsize in the range $\left[-2, +2\right]$
# <li> obtained for niter=100, maxsize=30, noise=0.001 and fitting with sq and exa: $$- 0.000759117171754911 x_{0}^{6} + 0.0388271704796444 x_{0}^{4} - 0.496481051788833 x_{0}^{2} + 0.999288569767875$$
# <li> obtained for niter=100, maxsize=30, noise=0.001 and fitting with only + and *: $$- 0.0011299928 x_{0}^{6} + 0.04083892 x_{0}^{4} - 0.49913806 x_{0}^{2} + 0.9997868$$
# </ul>

# %% [markdown]
# # Bessel Function

# %% [markdown]
# $$J_0(x) = 1 - \frac{1}{4}x^2 + \frac{1}{64}x^4 - \frac{1}{2304}x^6 + \frac{1}{147456}x^8 - \cdots $$

# %%
# Dataset
np.random.seed(0)
# Small values of x
x = np.linspace(-3, 3, 500)
noise = 0.001 * np.random.randn(len(x))
y = jn(0,x) + noise

# %%
model = PySRRegressor(
    niterations=300,
    populations=30,
    binary_operators=["+", "*"],
    #unary_operators=["sq(x) = x^2/2", "exa(x) = x^6"],
    #extra_sympy_mappings={"sq": lambda x: x**2/2, "exa" : lambda x: x**6},
    #maxsize = 20
)
model.fit(x.reshape(-1, 1), y)
# Out:
# /home/paolo/.conda/envs/coderefinery/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 2.810e+05
# Progress: 1560 / 9000 total iterations (17.333%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.712e-01  0.000e+00  y = 0.46105
# 7           4.727e-03  5.983e-01  y = ((x₀ * x₀) * -0.15146) + 0.91726
# 9           4.727e-03  4.470e-07  y = (((x₀ + 0.00018733) * -0.15146) * x₀) + 0.91726
# 11          4.727e-03  8.941e-08  y = ((((x₀ + 0.00023739) * x₀) + 0.11857) * -0.15147) + 0....
#                                       93522
# 13          2.225e-05  2.679e+00  y = ((((x₀ * 0.011027) * x₀) + -0.23686) * (x₀ * x₀)) + 0....
#                                       99443
# 15          2.225e-05  9.505e-05  y = ((((x₀ * 0.011026) * x₀) + -0.23686) * ((x₀ + 0.000210...
#                                       27) * x₀)) + 0.99442
# 17          2.225e-05  3.427e-06  y = (x₀ * ((x₀ + 0.00028073) * (((x₀ + 0.00023336) * (x₀ *...
#                                        0.011027)) + -0.23686))) + 0.99443
# 19          1.033e-06  1.535e+00  y = ((x₀ * x₀) * ((x₀ * ((((x₀ * -0.00032508) * x₀) + 0.01...
#                                       5032) * x₀)) + -0.24893)) + 0.99962
# 21          1.028e-06  2.116e-03  y = (((x₀ * (((x₀ * (x₀ * -0.00032509)) + 0.015032) * x₀))...
#                                        + -0.24893) * (x₀ * (x₀ + 0.00021371))) + 0.99962
# 23          1.028e-06  1.195e-04  y = ((x₀ + 0.00028202) * (((((-0.00032492 * (x₀ * x₀)) + 0...
#                                       .01503) * (x₀ * (0.00020411 + x₀))) + -0.24892) * x₀)) + 0...
#                                       .99961
# 25          1.028e-06  3.007e-05  y = (((x₀ + 0.00028202) * ((((((x₀ * (x₀ + 0.00020411)) * ...
#                                       -0.00032492) + 0.01503) * x₀) * (x₀ + 0.00020411)) + -0.24...
#                                       892)) * x₀) + 0.99961
# 27          1.025e-06  1.275e-03  y = (((x₀ * (x₀ + 0.0007016)) * 0.99981) * (((x₀ * ((x₀ * ...
#                                       ((x₀ + 0.0085768) * -0.00032525)) + 0.015036)) * (x₀ + 0.0...
#                                       026822)) + -0.24898)) + 0.99962
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+05
# Progress: 3001 / 9000 total iterations (33.344%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.712e-01  0.000e+00  y = 0.46105
# 7           4.727e-03  5.983e-01  y = ((x₀ * x₀) * -0.15146) + 0.91726
# 9           4.727e-03  4.470e-07  y = (((x₀ + 0.00018733) * -0.15146) * x₀) + 0.91726
# 11          4.727e-03  8.941e-08  y = ((((x₀ + 0.00023739) * x₀) + 0.11857) * -0.15147) + 0....
#                                       93522
# 13          2.225e-05  2.679e+00  y = ((((x₀ * 0.011027) * x₀) + -0.23686) * (x₀ * x₀)) + 0....
#                                       99443
# 15          2.225e-05  9.505e-05  y = ((((x₀ * 0.011026) * x₀) + -0.23686) * ((x₀ + 0.000210...
#                                       27) * x₀)) + 0.99442
# 17          2.225e-05  3.427e-06  y = (x₀ * ((x₀ + 0.00028073) * (((x₀ + 0.00023336) * (x₀ *...
#                                        0.011027)) + -0.23686))) + 0.99443
# 19          1.033e-06  1.535e+00  y = ((x₀ * x₀) * ((x₀ * ((((x₀ * -0.00032508) * x₀) + 0.01...
#                                       5032) * x₀)) + -0.24893)) + 0.99962
# 21          1.028e-06  2.116e-03  y = ((((x₀ * (((x₀ * x₀) * -0.00032509) + 0.015032)) * x₀)...
#                                        + -0.24893) * ((x₀ + 0.00021371) * x₀)) + 0.99962
# 23          1.028e-06  1.242e-04  y = ((x₀ * (x₀ + 0.00031018)) * ((((x₀ + 0.00027708) * (((...
#                                       x₀ * -0.00032523) * x₀) + 0.015034)) * x₀) + -0.24893)) + ...
#                                       0.99962
# 25          1.024e-06  1.839e-03  y = ((((x₀ + 0.003106) * (((x₀ * ((x₀ + 0.011299) * -0.000...
#                                       32518)) + 0.015033) * x₀)) + -0.24893) * (x₀ * (x₀ + 0.000...
#                                       69935))) + 0.99962
# 27          1.024e-06  2.310e-05  y = ((x₀ + 0.00066354) * ((((0.00052774 + x₀) * ((x₀ + 0.0...
#                                       024859) * (((x₀ * (0.011248 + x₀)) * -0.00032503) + 0.0150...
#                                       31))) + -0.24893) * x₀)) + 0.99962
# 29          1.024e-06  1.490e-06  y = ((((0.0024873 + x₀) * ((0.00052914 + x₀) * (((x₀ * (x₀...
#                                        + 0.011246)) * -0.00032511) + 0.015033))) + -0.24894) * (...
#                                       (x₀ * (x₀ + 0.00067074)) + 0.00050137)) + 0.99974
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+05
# Progress: 4376 / 9000 total iterations (48.622%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.712e-01  0.000e+00  y = 0.46105
# 5           1.712e-01  1.490e-08  y = (x₀ * -3.6945e-05) + 0.46105
# 7           4.727e-03  1.795e+00  y = ((x₀ * x₀) * -0.15146) + 0.91726
# 9           4.727e-03  4.470e-07  y = (((x₀ + 0.00018733) * -0.15146) * x₀) + 0.91726
# 11          4.727e-03  8.941e-08  y = ((((x₀ + 0.00023739) * x₀) + 0.11857) * -0.15147) + 0....
#                                       93522
# 13          2.225e-05  2.679e+00  y = ((((x₀ * 0.011027) * x₀) + -0.23686) * (x₀ * x₀)) + 0....
#                                       99443
# 15          2.225e-05  9.553e-05  y = ((((x₀ * (x₀ * 0.011027)) + -0.23686) * (x₀ + 0.000220...
#                                       98)) * x₀) + 0.99443
# 17          2.225e-05  2.950e-06  y = (x₀ * ((x₀ + 0.00028073) * (((x₀ + 0.00023336) * (x₀ *...
#                                        0.011027)) + -0.23686))) + 0.99443
# 19          1.033e-06  1.535e+00  y = ((x₀ * x₀) * ((x₀ * ((((x₀ * -0.00032508) * x₀) + 0.01...
#                                       5032) * x₀)) + -0.24893)) + 0.99962
# 21          1.028e-06  2.117e-03  y = ((((x₀ * ((x₀ * (x₀ * -0.00032509)) + 0.015032)) * x₀)...
#                                        + -0.24893) * (x₀ * (x₀ + 0.00021371))) + 0.99962
# 23          1.028e-06  1.251e-04  y = (((((x₀ * (x₀ * -0.00032503)) + 0.015031) * ((x₀ + 0.0...
#                                       0027203) * x₀)) + -0.24893) * ((x₀ + 0.00030831) * x₀)) + ...
#                                       0.99962
# 25          1.024e-06  2.034e-03  y = ((x₀ * ((x₀ * ((x₀ + 0.0039197) * (((x₀ * -0.00032512)...
#                                        * (x₀ + 0.014718)) + 0.015033))) + -0.24893)) * (x₀ + 0.0...
#                                       0080213)) + 0.99962
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+05
# Progress: 5829 / 9000 total iterations (64.767%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.712e-01  0.000e+00  y = 0.46105
# 5           1.712e-01  1.490e-08  y = (x₀ * -3.6945e-05) + 0.46105
# 7           4.727e-03  1.795e+00  y = ((x₀ * x₀) * -0.15146) + 0.91726
# 9           4.727e-03  4.470e-07  y = (((x₀ + 0.00018733) * -0.15146) * x₀) + 0.91726
# 11          4.727e-03  8.941e-08  y = ((((x₀ + 0.00023739) * x₀) + 0.11857) * -0.15147) + 0....
#                                       93522
# 13          2.225e-05  2.679e+00  y = ((((x₀ * 0.011027) * x₀) + -0.23686) * (x₀ * x₀)) + 0....
#                                       99443
# 15          2.225e-05  9.553e-05  y = ((((x₀ * (x₀ * 0.011027)) + -0.23686) * (x₀ + 0.000220...
#                                       98)) * x₀) + 0.99443
# 17          2.225e-05  2.950e-06  y = (x₀ * ((x₀ + 0.00028073) * (((x₀ + 0.00023336) * (x₀ *...
#                                        0.011027)) + -0.23686))) + 0.99443
# 19          1.033e-06  1.535e+00  y = ((x₀ * x₀) * ((x₀ * ((((x₀ * -0.00032508) * x₀) + 0.01...
#                                       5032) * x₀)) + -0.24893)) + 0.99962
# 21          1.028e-06  2.117e-03  y = ((((x₀ * ((x₀ * (x₀ * -0.00032509)) + 0.015032)) * x₀)...
#                                        + -0.24893) * (x₀ * (x₀ + 0.00021371))) + 0.99962
# 23          1.028e-06  1.251e-04  y = (((((x₀ * (x₀ * -0.00032503)) + 0.015031) * ((x₀ + 0.0...
#                                       0027203) * x₀)) + -0.24893) * ((x₀ + 0.00030831) * x₀)) + ...
#                                       0.99962
# 25          1.024e-06  2.094e-03  y = ((x₀ + 0.00086564) * (x₀ * ((x₀ * ((x₀ + 0.0046263) * ...
#                                       ((((x₀ * -0.0003251) + -5.8781e-06) * x₀) + 0.015032))) + ...
#                                       -0.24893))) + 0.99962
# 27          1.024e-06  7.659e-06  y = (((x₀ + 0.00084695) * x₀) * (((x₀ + 0.0045109) * (x₀ *...
#                                        (((x₀ + 0.00027936) * ((x₀ * -0.00032503) + -5.6401e-06))...
#                                        + 0.015031))) + -0.24893)) + 0.99962
# 29          1.023e-06  4.617e-04  y = (((((((((x₀ + 0.00048868) * x₀) * ((x₀ * -6.4107e-07) ...
#                                       + -0.00032497)) + 0.015031) * x₀) * (x₀ + 0.0044556)) + -0...
#                                       .24893) * (x₀ + 0.0010334)) * x₀) + 0.99962
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.630e+05
# Progress: 7381 / 9000 total iterations (82.011%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.712e-01  0.000e+00  y = 0.46105
# 5           1.712e-01  1.490e-08  y = (x₀ * -3.6945e-05) + 0.46105
# 7           4.727e-03  1.795e+00  y = ((x₀ * x₀) * -0.15146) + 0.91726
# 9           4.727e-03  4.470e-07  y = (((x₀ + 0.00018733) * -0.15146) * x₀) + 0.91726
# 11          4.727e-03  8.941e-08  y = ((((x₀ + 0.00023739) * x₀) + 0.11857) * -0.15147) + 0....
#                                       93522
# 13          2.225e-05  2.679e+00  y = ((((x₀ * 0.011027) * x₀) + -0.23686) * (x₀ * x₀)) + 0....
#                                       99443
# 15          2.225e-05  9.553e-05  y = ((((x₀ * (x₀ * 0.011027)) + -0.23686) * (x₀ + 0.000220...
#                                       98)) * x₀) + 0.99443
# 17          2.225e-05  2.950e-06  y = (x₀ * ((x₀ + 0.00028073) * (((x₀ + 0.00023336) * (x₀ *...
#                                        0.011027)) + -0.23686))) + 0.99443
# 19          1.033e-06  1.535e+00  y = ((x₀ * x₀) * ((x₀ * ((((x₀ * -0.00032508) * x₀) + 0.01...
#                                       5032) * x₀)) + -0.24893)) + 0.99962
# 21          1.028e-06  2.117e-03  y = ((((x₀ * ((x₀ * (x₀ * -0.00032509)) + 0.015032)) * x₀)...
#                                        + -0.24893) * (x₀ * (x₀ + 0.00021371))) + 0.99962
# 23          1.028e-06  1.261e-04  y = ((((((x₀ + 0.0002605) * x₀) * ((x₀ * (x₀ * -0.00032501...
#                                       )) + 0.015031)) + -0.24893) * x₀) * (x₀ + 0.00030376)) + 0...
#                                       .99962
# 25          9.763e-07  2.584e-02  y = ((x₀ * x₀) * ((x₀ * ((((x₀ * x₀) * ((x₀ * (x₀ * 7.3153...
#                                       e-06)) + -0.00044849)) + 0.015676) * x₀)) + -0.24999)) + 0...
#                                       .99988
# 27          9.721e-07  2.160e-03  y = (((x₀ + 0.00021059) * x₀) * ((x₀ * ((((((x₀ * (x₀ * 7....
#                                       008e-06)) + -0.00044319) * x₀) * x₀) + 0.015647) * x₀)) + ...
#                                       -0.24994)) + 0.99987
# 29          9.721e-07  2.018e-05  y = (((x₀ + 0.00021059) * x₀) * ((x₀ * ((((((x₀ + -0.00044...
#                                       319) * (x₀ * 7.0087e-06)) + -0.00044319) * (x₀ * x₀)) + 0....
#                                       015647) * x₀)) + -0.24994)) + 0.99987
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+05
# Progress: 8937 / 9000 total iterations (99.300%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.712e-01  0.000e+00  y = 0.46105
# 5           1.712e-01  1.490e-08  y = (x₀ * -3.6945e-05) + 0.46105
# 7           4.727e-03  1.795e+00  y = ((x₀ * x₀) * -0.15146) + 0.91726
# 9           4.727e-03  4.470e-07  y = (((x₀ + 0.00018733) * -0.15146) * x₀) + 0.91726
# 11          4.727e-03  8.941e-08  y = ((((x₀ + 0.00023739) * x₀) + 0.11857) * -0.15147) + 0....
#                                       93522
# 13          2.225e-05  2.679e+00  y = ((((x₀ * 0.011027) * x₀) + -0.23686) * (x₀ * x₀)) + 0....
#                                       99443
# 15          2.225e-05  9.553e-05  y = ((((x₀ * (x₀ * 0.011027)) + -0.23686) * (x₀ + 0.000220...
#                                       98)) * x₀) + 0.99443
# 17          2.225e-05  2.950e-06  y = (x₀ * ((x₀ + 0.00028073) * (((x₀ + 0.00023336) * (x₀ *...
#                                        0.011027)) + -0.23686))) + 0.99443
# 19          1.033e-06  1.535e+00  y = ((x₀ * ((x₀ * (((x₀ * (x₀ * -0.00032506)) + 0.015032) ...
#                                       * x₀)) + -0.24893)) * x₀) + 0.99962
# 21          1.028e-06  2.117e-03  y = ((((x₀ * ((x₀ * (x₀ * -0.00032509)) + 0.015032)) * x₀)...
#                                        + -0.24893) * (x₀ * (x₀ + 0.00021371))) + 0.99962
# 23          1.028e-06  1.257e-04  y = ((x₀ + 0.00030376) * ((((x₀ + 0.0002605) * (x₀ * (((x₀...
#                                        * -0.00032501) * x₀) + 0.015031))) + -0.24893) * x₀)) + 0...
#                                       .99962
# 25          9.763e-07  2.585e-02  y = ((x₀ * (((x₀ * ((((((x₀ * x₀) * 7.3601e-06) + -0.00044...
#                                       915) * x₀) * x₀) + 0.015678)) * x₀) + -0.24999)) * x₀) + 0...
#                                       .99988
# 27          9.720e-07  2.235e-03  y = (((((x₀ * (x₀ * (((x₀ * x₀) * 7.3695e-06) + -0.0004492...
#                                       7))) + 0.015678) * (x₀ * x₀)) + -0.24999) * ((x₀ + 0.00020...
#                                       988) * x₀)) + 0.99988
# 29          9.719e-07  3.410e-05  y = (x₀ * ((x₀ + 0.00020988) * (((((((x₀ * ((x₀ + -0.00096...
#                                       032) * 7.3695e-06)) + -0.00044927) * (x₀ * x₀)) + 0.015678...
#                                       ) * x₀) * x₀) + -0.24999))) + 0.99988
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.712e-01  0.000e+00  y = 0.46105
# 5           1.712e-01  1.490e-08  y = (x₀ * -3.6945e-05) + 0.46105
# 7           4.727e-03  1.795e+00  y = ((x₀ * x₀) * -0.15146) + 0.91726
# 9           4.727e-03  4.470e-07  y = (((x₀ + 0.00018733) * -0.15146) * x₀) + 0.91726
# 11          4.727e-03  8.941e-08  y = ((((x₀ + 0.00023739) * x₀) + 0.11857) * -0.15147) + 0....
#                                       93522
# 13          2.225e-05  2.679e+00  y = ((x₀ * (((x₀ * 0.011027) * x₀) + -0.23686)) * x₀) + 0....
#                                       99443
# 15          2.225e-05  9.505e-05  y = ((((x₀ * (x₀ * 0.011027)) + -0.23686) * (x₀ + 0.000220...
#                                       98)) * x₀) + 0.99443
# 17          2.225e-05  2.950e-06  y = (x₀ * ((x₀ + 0.00028073) * (((x₀ + 0.00023336) * (x₀ *...
#                                        0.011027)) + -0.23686))) + 0.99443
# 19          1.033e-06  1.535e+00  y = ((x₀ * ((x₀ * (((x₀ * (x₀ * -0.00032506)) + 0.015032) ...
#                                       * x₀)) + -0.24893)) * x₀) + 0.99962
# 21          1.028e-06  2.117e-03  y = ((((x₀ * ((x₀ * (x₀ * -0.00032509)) + 0.015032)) * x₀)...
#                                        + -0.24893) * (x₀ * (x₀ + 0.00021371))) + 0.99962
# 23          1.028e-06  1.257e-04  y = ((x₀ + 0.00030376) * ((((x₀ + 0.0002605) * (x₀ * (((x₀...
#                                        * -0.00032501) * x₀) + 0.015031))) + -0.24893) * x₀)) + 0...
#                                       .99962
# 25          9.763e-07  2.585e-02  y = ((x₀ * (((x₀ * ((((((x₀ * x₀) * 7.3601e-06) + -0.00044...
#                                       915) * x₀) * x₀) + 0.015678)) * x₀) + -0.24999)) * x₀) + 0...
#                                       .99988
# 27          9.720e-07  2.235e-03  y = (((((x₀ * (x₀ * (((x₀ * x₀) * 7.3695e-06) + -0.0004492...
#                                       7))) + 0.015678) * (x₀ * x₀)) + -0.24999) * ((x₀ + 0.00020...
#                                       988) * x₀)) + 0.99988
# 29          9.719e-07  3.410e-05  y = (x₀ * ((x₀ + 0.00020988) * (((((((x₀ * ((x₀ + -0.00096...
#                                       032) * 7.3695e-06)) + -0.00044927) * (x₀ * x₀)) + 0.015678...
#                                       ) * x₀) * x₀) + -0.24999))) + 0.99988
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                         0.46104702
# 	1         1.460068e-08                    (x0 * -3.694452e-5) + 0.4610485
# 	2         1.794821e+00             ((x0 * x0) * -0.15146188) + 0.91725796
# 	3         4.442363e-07  (((x0 + 0.00018733334) * -0.15146197) * x0) + ...
# 	4         9.519354e-08  ((((x0 + 0.00023739116) * x0) + 0.118570745) *...
# 	5         2.679345e+00  ((x0 * (((x0 * 0.01102665) * x0) + -0.23686442...
# 	6         9.501471e-05  ((((x0 * (x0 * 0.011026582)) + -0.23686387) * ...
# 	7         2.966691e-06  (x0 * ((x0 + 0.0002807322) * (((x0 + 0.0002333...
# 	8   >>>>  1.534998e+00  ((x0 * ((x0 * (((x0 * (x0 * -0.00032506048)) +...
# 	9         2.116586e-03  ((((x0 * ((x0 * (x0 * -0.0003250863)) + 0.0150...
# 	10        1.256514e-04  ((x0 + 0.00030375953) * ((((x0 + 0.00026050286...
# 	11        2.584606e-02  ((x0 * (((x0 * ((((((x0 * x0) * 7.3601195e-6) ...
# 	12        2.234588e-03  (((((x0 * (x0 * (((x0 * x0) * 7.369467e-6) + -...
# 	13        3.405592e-05  (x0 * ((x0 + 0.00020988098) * (((((((x0 * ((x0...
#
# 	            loss  complexity
# 	0   1.712249e-01           1
# 	1   1.712249e-01           5
# 	2   4.727216e-03           7
# 	3   4.727212e-03           9
# 	4   4.727211e-03          11
# 	5   2.225130e-05          13
# 	6   2.224707e-05          15
# 	7   2.224694e-05          17
# 	8   1.032734e-06          19
# 	9   1.028371e-06          21
# 	10  1.028113e-06          23
# 	11  9.763177e-07          25
# 	12  9.719641e-07          27
# 	13  9.718979e-07          29
# ]
#   - outputs/20250926_105001_SzqzwM/hall_of_fame.csv

# %%
model.sympy()
# Out:
# x0*x0*(x0*x0*(x0*x0*(-0.00032506048) + 0.015031787) - 0.24892703) + 0.9996159

# %%
# Define the symbolic variable
x0 = sympy.symbols('x0')

# Build each part of the expression
expr = (sympy.simplify(model.sympy()))

# Optionally simplify or expand the expression
expanded_expr = sympy.expand(expr)
expanded_expr
# Out:
# -0.00032506048*x0**6 + 0.015031787*x0**4 - 0.24892703*x0**2 + 0.9996159

# %%
sympy.latex(expanded_expr)
# Out:
# '- 0.00032506048 x_{0}^{6} + 0.015031787 x_{0}^{4} - 0.24892703 x_{0}^{2} + 0.9996159'

# %%
1/2304, 1/64, -1/4
# Out:
# (0.00043402777777777775, 0.015625, -0.25)

# %% [markdown]
# <ul>
# Results around $x = 0$ in the range $\left[-1, +1\right]$
# <li> obtained for niter=300, maxsize=20, noise=0.001 and fitting with only + and *: $$0.015487796 x_{0}^{4} - 0.24995881 x_{0}^{2} + 0.9999266$$
# Increasing maxsize in the range $\left[-3, +3\right]$
# <li> obtained for niter=300, maxsize=30, noise=0.001 and fitting with only + and *: $$- 0.00032506048 x_{0}^{6} + 0.015031787 x_{0}^{4} - 0.24892703 x_{0}^{2} + 0.9996159$$
# </ul>
