# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
import pandas as pd

# %% [markdown]
# # Tegmark repository

# %%
# Reads the equations
df = pd.read_csv('FeynmanEquations.csv')

# %% [markdown]
# ## Gaussian distribution

# %%
df['Formula'][1]
# Out:
# 'exp(-(theta/sigma)**2/2)/(sqrt(2*pi)*sigma)'

# %%
sympy.simplify(df['Formula'][1])
# Out:
# sqrt(2)*exp(-theta**2/(2*sigma**2))/(2*sqrt(pi)*sigma)

# %%
data = []
with open('./data/I.6.2', 'r') as file:
    for line in file:
        float_line = [float(x) for x in line.strip().split()]
        data.append(float_line)

# %%
data[:5]
# Out:
# [[2.564830477319424, 1.0663712017158176, 0.1426641647178555],
#  [2.8932169466669677, 2.8713313517397934, 0.08426643057964915],
#  [2.3150505694914836, 1.6346393044277656, 0.13430348728451916],
#  [1.4298257485557877, 2.852188446260336, 0.038156252873846254],
#  [2.293784737145745, 2.82801732058014, 0.08133585378750949]]

# %%
data = np.array(data)
data[:, 0]
# Out:
# array([2.56483048, 2.89321695, 2.31505057, ..., 2.97097419, 1.98654694,
#        1.68419834])

# %%
# Dataset
X = data[:800, :2]
theta = X[:,0]
sigma = X[:,1]
#theta, sigma
y = data[:800, 2]
#y

# %%
#X

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %%
# Learn equations
model = PySRRegressor(
    niterations=100,
    binary_operators=["*", "/"],
    unary_operators=["exp", "sq(x) = x^2"],
    extra_sympy_mappings={"sq": lambda x: x**2},
    **default_pysr_params,
)

model.fit(X, y)
# Out:
# /home/paolo/.conda/envs/coderefinery/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 1.980e+05
# Progress: 1122 / 3000 total iterations (37.400%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.759e-03  0.000e+00  y = 0.11316
# 3           4.381e-04  6.951e-01  y = 0.20787 / x₁
# 6           4.101e-04  2.202e-02  y = 0.34355 / exp(x₁ * 0.58058)
# 10          9.072e-05  3.771e-01  y = exp(x₁ * (-1.0758 / x₀)) / (x₀ / 0.66369)
# 14          6.145e-13  4.703e+00  y = exp((((x₁ * x₁) / x₀) / x₀) * -0.5) / (x₀ / 0.39895)
# 16          7.242e-14  1.069e+00  y = exp(((x₁ * x₁) * ((0.99996 / x₀) * -0.50002)) / x₀) / ...
#                                       (x₀ / 0.39894)
# 25          7.219e-14  3.451e-04  y = exp(x₁ * (((x₁ / x₀) * -0.50002) / (x₀ * exp(0.41776 /...
#                                        ((x₀ / 0.87024) / (x₁ * 4.8373e-05)))))) / (x₀ / 0.39894)
# 27          7.215e-14  2.892e-04  y = exp(((-0.50002 * x₁) * (x₁ / x₀)) / (x₀ * exp(0.41776 ...
#                                       / ((x₀ * 0.87024) / ((0.75212 * x₁) * 4.8373e-05))))) / (x...
#                                       ₀ / 0.39894)
# 30          7.204e-14  5.192e-04  y = exp((-0.50002 / (x₀ * exp(0.41776 / (x₀ * (x₁ * (1.145...
#                                       1 / sq((x₁ / -0.78896) * 0.0054681))))))) * ((x₁ / x₀) * x...
#                                       ₁)) / (x₀ / 0.39894)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.210e+05
# Progress: 2651 / 3000 total iterations (88.367%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.759e-03  0.000e+00  y = 0.11316
# 3           4.381e-04  6.951e-01  y = 0.20787 / x₁
# 6           4.101e-04  2.202e-02  y = 0.34347 / exp(x₁ * 0.58046)
# 10          9.072e-05  3.771e-01  y = exp(x₁ * (-1.0758 / x₀)) / (x₀ / 0.66369)
# 11          7.771e-17  2.779e+01  y = exp(-0.5 / sq(x₀ / x₁)) / (x₀ / 0.39894)
# 13          7.260e-17  3.404e-02  y = exp(x₁ * ((x₁ / sq(x₀)) * -0.5)) / (x₀ / 0.39894)
# 17          5.928e-17  5.069e-02  y = exp((x₁ * (x₁ / sq(x₀))) * -0.5) / (x₀ * ((x₀ / x₀) / ...
#                                       0.39894))
# 25          5.848e-17  1.694e-03  y = exp(x₁ * (-0.5 * (((((x₀ * x₀) / x₀) / x₀) * x₁) / sq(...
#                                       x₀)))) / (((x₀ / x₀) / 0.39894) * x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.759e-03  0.000e+00  y = 0.11316
# 3           4.381e-04  6.951e-01  y = 0.20787 / x₁
# 6           4.101e-04  2.202e-02  y = 0.34347 / exp(x₁ * 0.58046)
# 10          9.072e-05  3.771e-01  y = exp(x₁ * (-1.0758 / x₀)) / (x₀ / 0.66369)
# 11          7.771e-17  2.779e+01  y = exp(-0.5 / sq(x₀ / x₁)) / (x₀ / 0.39894)
# 13          7.260e-17  3.404e-02  y = exp(x₁ * ((x₁ / sq(x₀)) * -0.5)) / (x₀ / 0.39894)
# 15          6.030e-17  9.284e-02  y = exp(-0.5 * sq(x₁ / x₀)) / (((x₀ / x₀) / 0.39894) * x₀)
# 17          5.928e-17  8.551e-03  y = exp((x₁ * (x₁ / sq(x₀))) * -0.5) / (x₀ * ((x₀ / x₀) / ...
#                                       0.39894))
# 18          5.054e-17  1.593e-01  y = exp(((x₁ / x₀) * (x₁ * -0.5)) / x₀) / (x₀ * ((x₀ / x₀)...
#                                        / 0.39894))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                         0.11315549
# 	1         0.695142                                    0.20787439 / x1
# 	2         0.022023                  0.34347293 / exp(x1 * 0.58046097)
# 	3         0.377146     exp(x1 * (-1.0758005 / x0)) / (x0 / 0.6636941)
# 	4        27.785738  exp(-0.49999997 / sq(x0 / x1)) / (x0 / 0.39894...
# 	5         0.034036  exp(x1 * ((x1 / sq(x0)) * -0.49999997)) / (x0 ...
# 	6         0.092836  exp(-0.5 * sq(x1 / x0)) / (((x0 / x0) / 0.3989...
# 	7         0.008551  exp((x1 * (x1 / sq(x0))) * -0.5) / (x0 * ((x0 ...
# 	8  >>>>   0.159344  exp(((x1 / x0) * (x1 * -0.5)) / x0) / (x0 * ((...
#
# 	           loss  complexity
# 	0  1.759348e-03           1
# 	1  4.380856e-04           3
# 	2  4.100767e-04           6
# 	3  9.071831e-05          10
# 	4  7.771452e-17          11
# 	5  7.260034e-17          13
# 	6  6.029791e-17          15
# 	7  5.927550e-17          17
# 	8  5.054442e-17          18
# ]
#   - outputs/20250926_122258_MQNCE0/hall_of_fame.csv

# %%
model.sympy()
# Out:
# exp(x1*x1*(-0.5)/(x0*x0))/((x0*x0/(0.39894226*x0)))

# %%
1/np.sqrt(2*np.pi)
# Out:
# 0.3989422804014327

# %% [markdown]
# ## Train test split

# %%
# Dataset
X = data[:1000, :2]
y = data[:1000, 2]
X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=0)
theta_train = X_train[:,0]
sigma_train = X_train[:,1]
theta_test = X_test[:,0]
sigma_test = X_test[:,1]

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %%
# Learn equations
model = PySRRegressor(
    niterations=100,
    binary_operators=["*", "/"],
    unary_operators=["exp", "sq(x) = x^2"],
    extra_sympy_mappings={"sq": lambda x: x**2},
    **default_pysr_params,
)

model.fit(X_train, y_train)
# Out:
# /home/paolo/.conda/envs/coderefinery/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 1.710e+05
# Progress: 1055 / 3000 total iterations (35.167%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.804e-03  0.000e+00  y = 0.11185
# 3           4.678e-04  6.748e-01  y = 0.20608 / x₁
# 6           4.279e-04  2.974e-02  y = 0.34152 / exp(x₁ / 1.7201)
# 8           1.074e-04  6.913e-01  y = 0.6173 / (x₀ * exp(x₁ / x₀))
# 10          9.562e-05  5.797e-02  y = 0.66319 / (exp((x₁ / x₀) * 1.0791) * x₀)
# 11          1.401e-16  2.725e+01  y = 0.39894 / (exp(sq(x₁ * (0.70711 / x₀))) * x₀)
# 13          1.370e-16  1.103e-02  y = 0.39894 / (exp(sq((x₁ / 1.4142) * (1 / x₀))) * x₀)
# 23          1.207e-16  1.270e-02  y = 0.39894 / (exp(sq(x₁ * ((exp(-3.6962e-05 / ((exp(x₀ / ...
#                                       x₁) / -0.019642) * 0.78329)) / 1.4142) / x₀))) * x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.910e+05
# Progress: 2301 / 3000 total iterations (76.700%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.804e-03  0.000e+00  y = 0.11185
# 3           4.678e-04  6.748e-01  y = 0.20608 / x₁
# 6           4.279e-04  2.974e-02  y = 0.34152 / exp(x₁ / 1.7201)
# 7           4.260e-04  4.350e-03  y = 0.72493 / exp(exp(x₁ * 0.31798))
# 8           1.074e-04  1.378e+00  y = 0.6173 / (x₀ * exp(x₁ / x₀))
# 10          9.559e-05  5.813e-02  y = 0.66197 / (exp(x₁ / (x₀ / 1.076)) * x₀)
# 11          1.186e-16  2.742e+01  y = 0.39894 / (exp(sq((x₁ / x₀) * 0.70711)) * x₀)
# 13          1.031e-16  7.025e-02  y = 0.39894 / (exp(sq((x₁ / (x₀ * 1)) / 1.4142)) * x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.804e-03  0.000e+00  y = 0.11185
# 3           4.678e-04  6.748e-01  y = 0.20608 / x₁
# 6           4.279e-04  2.974e-02  y = 0.34152 / exp(x₁ / 1.7201)
# 7           4.260e-04  4.350e-03  y = 0.72493 / exp(exp(x₁ * 0.31798))
# 8           1.074e-04  1.378e+00  y = 0.6173 / (x₀ * exp(x₁ / x₀))
# 10          9.559e-05  5.813e-02  y = 0.66197 / (exp(x₁ / (x₀ / 1.076)) * x₀)
# 11          1.021e-16  2.756e+01  y = 0.39894 / (x₀ * exp(sq((x₁ / x₀) * 0.70711)))
# 13          9.091e-17  5.820e-02  y = 0.39894 / (exp(sq(((x₁ / x₀) * 0.70711) / 1)) * x₀)
# 14          8.753e-17  3.784e-02  y = 0.39894 / (x₀ * exp(sq((x₁ / x₀) * 0.70711) / sq(1)))
# 16          6.564e-17  1.439e-01  y = 0.39894 / (exp(((x₁ / x₀) * x₁) * ((0.5 / x₀) / 1)) * ...
#                                       x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                        0.111851566
# 	1         0.674830                                    0.20608288 / x1
# 	2         0.029744                   0.34152472 / exp(x1 / 1.7201153)
# 	3         0.004350              0.7249251 / exp(exp(x1 * 0.31798345))
# 	4         1.378183                   0.61730486 / (x0 * exp(x1 / x0))
# 	5         0.058131      0.6619692 / (exp(x1 / (x0 / 1.0760016)) * x0)
# 	6        27.564854  0.3989423 / (x0 * exp(sq((x1 / x0) * 0.7071067...
# 	7         0.058203  0.3989423 / (exp(sq(((x1 / x0) * 0.7071061) / ...
# 	8         0.037842  0.3989423 / (x0 * exp(sq((x1 / x0) * 0.7071061...
# 	9  >>>>   0.143887  0.3989423 / (exp(((x1 / x0) * x1) * ((0.499999...
#
# 	           loss  complexity
# 	0  1.803990e-03           1
# 	1  4.678256e-04           3
# 	2  4.278888e-04           6
# 	3  4.260315e-04           7
# 	4  1.073753e-04           8
# 	5  9.559006e-05          10
# 	6  1.021290e-16          11
# 	7  9.090645e-17          13
# 	8  8.753068e-17          14
# 	9  6.564194e-17          16
# ]
#   - outputs/20250926_122318_cfaV2U/hall_of_fame.csv

# %%
model.sympy()
# Out:
# 0.3989423/((x0*exp(x1*x1*0.49999955/(x0*x0*0.99999905))))

# %%
ypredict = model.predict(X_test)
# Computes the MSE <(ypredict - y)^2>
print("Default selection MSE:", np.power(ypredict - y_test, 2).mean())
# Out:
# Default selection MSE: 1.393858600583851e-17

# %% [markdown]
# ## Gravitational formula in 3D

# %%
sympy.simplify(df['Formula'][4])
# Out:
# G*m1*m2/((x1 - x2)**2 + (y1 - y2)**2 + (z1 - z2)**2)

# %%
sympy.expand(sympy.simplify(df['Formula'][4]))
# Out:
# G*m1*m2/(x1**2 - 2*x1*x2 + x2**2 + y1**2 - 2*y1*y2 + y2**2 + z1**2 - 2*z1*z2 + z2**2)

# %%
data = []
entry = df['Filename'][4]
with open(f'./data/{entry}', 'r') as file:
    for line in file:
        float_line = [float(x) for x in line.strip().split()]
        data.append(float_line)

# %%
data[:3]
# Out:
# [[1.8713055326412502,
#   1.0034480251479807,
#   1.4573398867123015,
#   3.927323289786794,
#   1.0338899958093903,
#   3.2516726878475066,
#   1.91158690483094,
#   3.531639561705637,
#   1.4131164955760318,
#   0.18671842217267526],
#  [1.808359710690784,
#   1.888191130541064,
#   1.1700083522943014,
#   3.9460692884442943,
#   1.1586814965781298,
#   3.321795862499887,
#   1.8989500490089544,
#   3.9122131670461195,
#   1.0609920020361066,
#   0.22289346141204303],
#  [1.3140296599405707,
#   1.1341163486796548,
#   1.584233779002786,
#   3.9541727371365933,
#   1.9032366118772042,
#   3.2446283989093927,
#   1.5810304725687252,
#   3.0123984645744963,
#   1.6277773919237948,
#   0.26553874197089344]]

# %%
arr = np.array(data[:800])
arr[:3], arr.shape
# Out:
# (array([[1.87130553, 1.00344803, 1.45733989, 3.92732329, 1.03389   ,
#          3.25167269, 1.9115869 , 3.53163956, 1.4131165 , 0.18671842],
#         [1.80835971, 1.88819113, 1.17000835, 3.94606929, 1.1586815 ,
#          3.32179586, 1.89895005, 3.91221317, 1.060992  , 0.22289346],
#         [1.31402966, 1.13411635, 1.58423378, 3.95417274, 1.90323661,
#          3.2446284 , 1.58103047, 3.01239846, 1.62777739, 0.26553874]]),
#  (800, 10))

# %%
# Dataset
X = arr[:, :9]
m1 = X[:,0]
m2 = X[:,1]
G = X[:,2]
x1 = X[:,3]
x2 = X[:,4]
y1 = X[:,5]
y2 = X[:,6]
z1 = X[:,7]
z2 = X[:,8]
#theta, sigma
y = arr[:, 9]

# %%
r = np.sqrt((x1-x2)**2 + (y1-y2)**2  + (z1-z2)**2)
red_X = np.vstack((m1, m2, G, r)).T

# %%
red_X
# Out:
# array([[1.87130553, 1.00344803, 1.45733989, 3.82830591],
#        [1.80835971, 1.88819113, 1.17000835, 4.23361347],
#        [1.31402966, 1.13411635, 1.58423378, 2.98179016],
#        ...,
#        [1.2492723 , 1.62560002, 1.43596808, 3.20761271],
#        [1.66643626, 1.7680461 , 1.09803292, 3.17852966],
#        [1.3406618 , 1.93043857, 1.75476337, 3.35661377]])

# %%
red_X.shape
# Out:
# (800, 4)

# %%
X
# Out:
# array([[1.87130553, 1.00344803, 1.45733989, ..., 1.9115869 , 3.53163956,
#         1.4131165 ],
#        [1.80835971, 1.88819113, 1.17000835, ..., 1.89895005, 3.91221317,
#         1.060992  ],
#        [1.31402966, 1.13411635, 1.58423378, ..., 1.58103047, 3.01239846,
#         1.62777739],
#        ...,
#        [1.2492723 , 1.62560002, 1.43596808, ..., 1.42645594, 3.14785256,
#         1.41486756],
#        [1.66643626, 1.7680461 , 1.09803292, ..., 1.97501942, 3.56992166,
#         1.66019458],
#        [1.3406618 , 1.93043857, 1.75476337, ..., 1.23830632, 3.22593331,
#         1.90110934]])

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %%
# Learn equations
model = PySRRegressor(
    niterations=600,
    binary_operators=["+", "-", "*", "/"],
    # unary_operators=["inv(x) = 1/x"],
    # extra_sympy_mappings={"inv": lambda x: 1/x},
    #maxsize = 20
)

#model.fit(X, y, variable_names=["m1", "m2", "G", "x1", "x2", "y1", "y2", "z1", "z2"])
model.fit(red_X, y, variable_names=["m1", "m2", "G", "r"])
# Out:
# /home/paolo/.conda/envs/coderefinery/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 3.060e+05
# Progress: 1802 / 18600 total iterations (9.688%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.307e-03  2.492e-01  y = 0.53363 / (r - m1)
# 7           3.478e-03  2.977e-01  y = (G * -0.3487) / (m2 - r)
# 9           5.465e-16  1.474e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 15          5.420e-16  8.308e-04  y = ((G / ((r - -0.22638) + -0.22638)) * ((m1 * m2) / r)) ...
#                                       + 0
# 17          5.376e-16  4.049e-03  y = ((G / r) + ((1.3287e-08 / r) * (m1 / 0.60728))) * ((m2...
#                                        * m1) / r)
# 19          5.360e-16  1.486e-03  y = ((m2 * m1) / r) * (G / ((r - -0.22638) + ((-4.883e-09 ...
#                                       / (m2 / r)) + -0.22638)))
# 21          5.302e-16  5.467e-03  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 25          5.205e-16  4.623e-03  y = ((m2 * m1) / r) * (G / ((r - -0.22638) + ((1 - (-6.996...
#                                       3e-09 / (m2 / ((r * r) + -0.52121)))) * -0.22638)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.170e+05
# Progress: 3732 / 18600 total iterations (20.065%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = 0.53145 / (r - m1)
# 7           3.478e-03  2.976e-01  y = G * (-0.34871 / (m2 - r))
# 9           5.465e-16  1.474e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.432e-16  5.107e-04  y = ((3.9097e-08 / r) + (G / r)) * ((m2 * m1) / r)
# 15          5.330e-16  9.543e-03  y = ((G / r) + (3.07e-08 / (r - 0.75864))) * ((m2 * m1) / ...
#                                       r)
# 17          5.318e-16  1.108e-03  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.249e-16  4.998e-03  y = (G / (((1 - ((r / m2) * (r * -6.3401e-09))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# 25          5.205e-16  4.248e-03  y = ((m2 * m1) / r) * (G / ((r - -0.22638) + ((1 - (-6.996...
#                                       3e-09 / (m2 / ((r * r) + -0.52121)))) * -0.22638)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.270e+05
# Progress: 5727 / 18600 total iterations (30.790%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = 0.53145 / (r - m1)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.249e-16  4.998e-03  y = (G / (((1 - ((r / m2) * (r * -6.3401e-09))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# 25          5.205e-16  4.248e-03  y = ((m2 * m1) / r) * (G / ((r - -0.22638) + ((1 - (-6.996...
#                                       3e-09 / (m2 / ((r * r) + -0.52121)))) * -0.22638)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.310e+05
# Progress: 7745 / 18600 total iterations (41.640%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = 0.53145 / (r - m1)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.205e-16  9.246e-03  y = (G / (((1 - ((r * -9.8712e-09) * (r - m2))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.370e+05
# Progress: 9686 / 18600 total iterations (52.075%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = -0.53148 / (m1 - r)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.205e-16  9.246e-03  y = (G / (((1 - ((r * -9.8712e-09) * (r - m2))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.360e+05
# Progress: 11604 / 18600 total iterations (62.387%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = -0.53145 / (m1 - r)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.205e-16  9.246e-03  y = (G / (((1 - ((r * -9.8712e-09) * (r - m2))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.350e+05
# Progress: 13619 / 18600 total iterations (73.220%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = -0.53145 / (m1 - r)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.205e-16  9.246e-03  y = (G / (((1 - ((r * -9.8712e-09) * (r - m2))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.380e+05
# Progress: 15682 / 18600 total iterations (84.312%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = -0.53145 / (m1 - r)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.205e-16  9.246e-03  y = (G / (((1 - ((r * -9.8712e-09) * (r - m2))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.420e+05
# Progress: 17766 / 18600 total iterations (95.516%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = -0.53145 / (m1 - r)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.205e-16  9.246e-03  y = (G / (((1 - ((r * -9.8712e-09) * (r - m2))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.038e-02  1.530e-01  y = 0.97942 / r
# 5           6.306e-03  2.494e-01  y = -0.53145 / (m1 - r)
# 7           3.268e-03  3.287e-01  y = m2 * (-0.34847 / (G - r))
# 9           5.465e-16  1.471e+01  y = ((m1 * m2) / r) * (G / r)
# 11          5.438e-16  2.482e-03  y = (G / (r + 0)) * ((m1 * m2) / r)
# 13          5.321e-16  1.083e-02  y = ((G / r) + (4.1684e-08 / r)) * ((m2 * m1) / r)
# 17          5.318e-16  1.631e-04  y = ((3.07e-08 / (r * (-2.0268 + r))) + (G / r)) * ((m2 * ...
#                                       m1) / r)
# 21          5.302e-16  7.514e-04  y = ((m2 * m1) / r) * (G / (((1 - (-6.9963e-09 * (r + m1))...
#                                       ) * -0.22638) + (r - -0.22638)))
# 23          5.205e-16  9.246e-03  y = (G / (((1 - ((r * -9.8712e-09) * (r - m2))) * -0.22638...
#                                       ) + (r - -0.22638))) * ((m1 * m2) / r)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                          0.2773229
# 	1         0.153021                                      0.9794189 / r
# 	2         0.249359                             -0.53145367 / (m1 - r)
# 	3         0.328661                        m2 * (-0.3484667 / (G - r))
# 	4  >>>>  14.709707                          ((m1 * m2) / r) * (G / r)
# 	5         0.002482                  (G / (r + 0.0)) * ((m1 * m2) / r)
# 	6         0.010835   ((G / r) + (4.1683943e-8 / r)) * ((m2 * m1) / r)
# 	7         0.000163  ((3.0700082e-8 / (r * (-2.0268338 + r))) + (G ...
# 	8         0.000751  ((m2 * m1) / r) * (G / (((0.99999994 - (-6.996...
# 	9         0.009246  (G / (((0.99999994 - ((r * -9.871207e-9) * (r ...
#
# 	           loss  complexity
# 	0  1.410131e-02           1
# 	1  1.038359e-02           3
# 	2  6.306039e-03           5
# 	3  3.268024e-03           7
# 	4  5.465073e-16           9
# 	5  5.438011e-16          11
# 	6  5.321438e-16          13
# 	7  5.317968e-16          17
# 	8  5.302009e-16          21
# 	9  5.204865e-16          23
# ]
#   - outputs/20250927_215048_W22Tys/hall_of_fame.csv

# %%
model.sympy()
# Out:
# G*m1*m2/(r*r)

# %%
# Define the symbolic variable
x0 = sympy.symbols('x0')

# Build each part of the expression
expr = (sympy.simplify(model.sympy()))

# Optionally simplify or expand the expression
expanded_expr = sympy.expand(expr)
expanded_expr
# Out:
# G*m1*m2/r**2

# %%
# "sq_dif(x, x_0) = abs(x-x_0)^2"
# extra_sympy_mappings={"sq_dif": lambda x,x0: (abs(x - x0))**2}
#extra_sympy_mappings={"sq_dif": lambda x,x0: 1/((abs(x - x0))**2), 
    #                      "num" : lambda x,x0: x*x0 },

# %%
# Learn equations
model = PySRRegressor(
    niterations=600,
    #niterations=1000,
    binary_operators=["+", "-", "/", "biprod(x,y) = x*y"],
    unary_operators=["sqr(x) = x^2"],
    extra_sympy_mappings={"sqr": lambda x: x**2, "biprod": lambda x,y: x*y},
    maxsize = 40
)

model.fit(X, y, variable_names=["m1", "m2", "G", "x1", "x2", "y1", "y2", "z1", "z2"])
# Out:
# /home/paolo/.conda/envs/coderefinery/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.390e+05
# Progress: 1387 / 18600 total iterations (7.457%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           7.668e-03  5.459e-02  y = m1 / ((y1 / 0.44649) / m2)
# 8           5.098e-03  4.082e-01  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / ((biprod(z1, y1) / m2) + -0.20096))
# 13          2.797e-03  1.598e-01  y = m1 / (biprod((z1 + (1.4294 - x2)) / m2, y1) / G)
# 15          2.029e-03  1.604e-01  y = m1 / (biprod(y1 / G, (z1 + (x1 + -2.0505)) - x2) / m2)
# 17          1.338e-03  2.084e-01  y = m1 / (((x1 + biprod(-1.3661, z2)) + ((biprod(z1, y1) /...
#                                        G) / m2)) - x2)
# 21          6.230e-04  1.910e-01  y = m1 / biprod((((((y2 / -1.084) - x2) + x1) - (z2 / 2.55...
#                                       44)) + z1) / m2, y1 / G)
# 23          2.035e-04  5.593e-01  y = biprod(m1 / (biprod((((((y2 / -1.2954) - x2) + x1) - (...
#                                       z2 / 1.1597)) + z1) / m2, y1) / G), 0.84443)
# 24          1.982e-04  2.680e-02  y = biprod(m1 / biprod((((y2 / -1.084) - x2) + ((x1 - sqr(...
#                                       z2 / -1.5982)) + z1)) / m2, y1 / G), 0.88831)
# 27          1.546e-04  8.281e-02  y = biprod((m1 / x2) / 0.75848, (x2 - 0.48847) / biprod((y...
#                                       1 / G) / m2, biprod(-0.97994, y2) + ((x1 + (z1 - z2)) - 0....
#                                       94903)))
# 29          1.544e-04  6.035e-04  y = (biprod((x2 - 0.48703) / biprod((y1 / G) / m2, biprod(...
#                                       0.99398, (((x1 + z1) - z2) - 0.94902) + biprod(y2, -0.9836...
#                                       8))), m1) / x2) / 0.7657
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.360e+05
# Progress: 2797 / 18600 total iterations (15.038%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 13          2.797e-03  1.598e-01  y = m1 / (biprod((z1 + (1.4294 - x2)) / m2, y1) / G)
# 15          1.972e-03  1.747e-01  y = m1 / ((biprod(x1, (2.9567 + z1) - (y2 + x2)) / m2) / G...
#                                       )
# 17          1.101e-03  2.915e-01  y = m1 / (biprod(((x1 + (z1 + -0.54697)) - y2) - z2, y1 / ...
#                                       G) / m2)
# 19          1.018e-03  3.937e-02  y = m1 / biprod(((-1.0023 - y2) + (x1 + z1)) - z2, ((y1 / ...
#                                       G) / m2) / 0.85122)
# 20          9.281e-04  9.210e-02  y = m1 / (((biprod(y1, (x1 + (biprod(y2, -1.0503) + z1)) -...
#                                        x2) - sqr(z2)) / G) / m2)
# 21          2.248e-04  1.418e+00  y = biprod(0.81972, m1 / ((biprod(y1, (y2 / -1.4107) + ((x...
#                                       1 + (z1 - z2)) - x2)) / G) / m2))
# 22          1.087e-04  7.264e-01  y = biprod(m1, 0.91659) / (((biprod(y1, biprod(y2, -1.0439...
#                                       ) + ((z1 + x1) - x2)) - sqr(z2)) / G) / m2)
# 24          1.064e-04  1.050e-02  y = biprod(m1, 0.92062) / (((biprod(y1, ((x1 + z1) - x2) +...
#                                        biprod(y2, -1.0227)) - sqr(z2 / -0.98066)) / G) / m2)
# 26          1.050e-04  6.754e-03  y = biprod(m1, (0.90575 / (((biprod(y1, (x1 + z1) + (bipro...
#                                       d(y2, -1.0257) - x2)) - sqr(z2 / -0.97405)) / G) / m2)) + ...
#                                       0.0013871)
# 31          8.556e-05  4.098e-02  y = m1 / biprod(((((z1 + x1) - x2) + biprod(y1, 0.17683)) ...
#                                       + (y2 / -0.97604)) - ((0.21918 - z2) / -0.98009), (((y1 / ...
#                                       m2) / 0.54593) / G) / 1.6826)
# 33          8.543e-05  7.878e-04  y = biprod(0.87303, m1) / biprod(((biprod(y1, 0.17263) + (...
#                                       y2 / -0.98127)) + (x1 + (z1 - x2))) - ((0.20969 - z2) / -0...
#                                       .98643), (((y1 / m2) / 0.61492) / G) / 1.707)
# 35          8.525e-05  1.008e-03  y = biprod((m1 + -0.0046981) / ((biprod(((y2 / -0.97883) -...
#                                        ((0.21702 - z2) / -0.98425)) + ((x1 - x2) + (z1 + biprod(...
#                                       y1, 0.17107))), (y1 / m2) / 0.60941) / G) / 1.705), 0.8831...
#                                       )
# 39          8.504e-05  6.207e-04  y = biprod(0.85071, (m1 - 0.016362) / (biprod((((((x1 - x2...
#                                       ) + (((y2 / -0.97444) - biprod(0.21727 - z2, -0.99287)) + ...
#                                       biprod(y1, 0.18092))) + z1) - 0.06473) / G) / 1.6879, y1 /...
#                                        m2) / 0.56396)) / 0.87716
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.440e+05
# Progress: 4342 / 18600 total iterations (23.344%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 13          2.797e-03  1.598e-01  y = m1 / (biprod((z1 + (1.4294 - x2)) / m2, y1) / G)
# 15          1.906e-03  1.917e-01  y = m1 / (biprod((z1 - z2) + (x1 - x2), y1 - G) / m2)
# 17          7.287e-04  4.808e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - z2) / G) /...
#                                        m2)
# 18          4.957e-04  3.852e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - sqr(z2)) /...
#                                        G) / m2)
# 19          1.589e-04  1.138e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.156e-04  3.181e-01  y = (m1 / (((biprod(((z1 + x1) - x2) - y2, y1) - sqr(z2)) ...
#                                       / G) / m2)) / 1.0647
# 22          1.059e-04  4.406e-02  y = m1 / (((biprod((((-0.13033 - y2) + x1) + z1) - x2, y1)...
#                                        - sqr(z2)) / G) / (m2 / 1.1154))
# 24          1.052e-04  2.924e-03  y = biprod(0.91526, m1) / (((biprod((biprod(-1.0219, y2) +...
#                                        (x1 + z1)) - x2, y1) - sqr(z2 / -0.97536)) / G) / m2)
# 26          1.003e-04  2.408e-02  y = biprod(m1, 0.93283) / (((((0.47178 / z2) + biprod(((x1...
#                                        + z1) + biprod(y2, -1.0693)) - x2, y1)) - sqr(z2)) / G) /...
#                                        m2)
# 27          9.249e-05  8.099e-02  y = biprod(0.93977, m1 / ((((biprod(((biprod(y2, -1.0598) ...
#                                       + z1) + x1) - x2, y1) - sqr(z2)) / G) + (0.46386 / sqr(z2)...
#                                       )) / m2))
# 28          8.931e-05  3.499e-02  y = biprod(0.93518, m1) / (((0.47126 / sqr(sqr(z2))) + ((b...
#                                       iprod(y1, z1 + ((x1 + biprod(-1.0399, y2)) - x2)) - sqr(z2...
#                                       )) / G)) / m2)
# 30          8.101e-05  4.881e-02  y = biprod(0.94294, m1 / ((sqr(sqr(z1 / (z2 / -0.24709))) ...
#                                       + ((biprod(y1, ((z1 + biprod(-1.0296, y2)) - x2) + x1) - s...
#                                       qr(z2)) / G)) / m2))
# 32          8.043e-05  3.572e-03  y = biprod(m1, 0.94781) / (((sqr(sqr(z1 / (z2 / -0.25019))...
#                                       ) + ((biprod(biprod(-1.0362, y2) + ((x1 + z1) - x2), y1) -...
#                                        sqr(z2)) / G)) / m2) - -0.029508)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.550e+05
# Progress: 5991 / 18600 total iterations (32.210%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 13          2.797e-03  1.598e-01  y = m1 / (biprod((z1 + (1.4294 - x2)) / m2, y1) / G)
# 15          1.906e-03  1.917e-01  y = m1 / (biprod((z1 - z2) + (x1 - x2), y1 - G) / m2)
# 16          1.671e-03  1.319e-01  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          7.287e-04  8.297e-01  y = m1 / (((biprod(((z1 + x1) - x2) - y2, y1) - z2) / G) /...
#                                        m2)
# 18          4.957e-04  3.852e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - sqr(z2)) /...
#                                        G) / m2)
# 19          1.589e-04  1.138e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.156e-04  3.181e-01  y = (m1 / (((biprod(y1, ((x1 + z1) - x2) - y2) - sqr(z2)) ...
#                                       / G) / m2)) / 1.0647
# 22          1.058e-04  4.436e-02  y = m1 / (((biprod((x1 + z1) + ((-0.12378 - y2) - x2), y1)...
#                                        - sqr(z2)) / G) / (m2 / 1.1122))
# 24          1.052e-04  2.624e-03  y = biprod(0.91526, m1) / (((biprod((biprod(-1.0219, y2) +...
#                                        (x1 + z1)) - x2, y1) - sqr(z2 / -0.97536)) / G) / m2)
# 26          9.614e-05  4.526e-02  y = m1 / (((biprod((z1 + biprod(y2, -1.05)) + (x1 - x2), (...
#                                       z1 / (z2 / 0.099511)) + y1) - sqr(z2)) / G) / m2)
# 27          8.527e-05  1.200e-01  y = m1 / (((biprod((x1 + (z1 + biprod(y2, -0.99968))) - x2...
#                                       , y1 + sqr(z1 / (z2 / 0.17746))) - sqr(z2)) / G) / m2)
# 29          8.334e-05  1.139e-02  y = biprod(0.96681, m1) / (((biprod((z1 / sqr(z2 / -0.2943...
#                                       2)) + y1, biprod(-1.0369, y2) + (x1 + (z1 - x2))) - sqr(z2...
#                                       )) / G) / m2)
# 30          8.101e-05  2.845e-02  y = biprod(m1, 0.94296) / ((sqr(sqr(z1 / (z2 / -0.24709)))...
#                                        + ((biprod(y1, (z1 + (biprod(y2, -1.0296) - x2)) + x1) - ...
#                                       sqr(z2)) / G)) / m2)
# 32          7.902e-05  1.243e-02  y = biprod(m1, 0.94888 / (((((biprod(y1, (biprod(-1.0462, ...
#                                       y2) + (z1 + x1)) - x2) + sqr(sqr(z1 / (z2 / -0.2855)))) - ...
#                                       sqr(z2)) / G) / m2) - -0.050959))
# 34          7.429e-05  3.085e-02  y = biprod(0.96021 / ((((biprod(((x1 + z1) - x2) + biprod(...
#                                       -1.0504, y2), y1) + (sqr(sqr(z1 / (z2 / 0.28769))) - sqr(z...
#                                       2))) / G) / m2) - (-0.16132 / x2)), m1)
# 36          7.152e-05  1.899e-02  y = biprod(0.96428, m1) / (((((biprod(y1, (z1 + (biprod(y2...
#                                       , -1.0218) - x2)) + x1) - sqr(z2)) + sqr(sqr(z1 / (z2 / -0...
#                                       .29016)))) / G) / m2) - (-0.26235 / sqr(sqr(x2))))
# 38          7.133e-05  1.350e-03  y = biprod(0.96192, m1 / (((((biprod(x1 + ((biprod(y2, -1....
#                                       02) + z1) - x2), y1) - sqr(z2)) + sqr(sqr(z1 / (z2 / -0.28...
#                                       841)))) / G) / m2) - (-0.16205 / sqr(sqr(x2 / 1.0669)))))
# 39          6.613e-05  7.574e-02  y = biprod(0.96181, m1) / (((((biprod((biprod(y2, -1.0364)...
#                                        + x1) + (z1 - x2), y1) - sqr(z2)) / G) + sqr(sqr(z1 / (z2...
#                                        / -0.25161)))) / m2) - (-0.18447 / sqr(x2 / (x1 / y1))))
# 40          5.833e-05  1.254e-01  y = biprod(m1, 0.9618 / (((((biprod(biprod(-1.0219, y2) + ...
#                                       ((x1 + z1) - x2), y1) - sqr(z2)) / G) + sqr(sqr(z1 / (z2 /...
#                                        -0.25183)))) / m2) - (-0.21189 / sqr(sqr(x2 / (x1 / y1)))...
#                                       )))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.700e+05
# Progress: 7784 / 18600 total iterations (41.849%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 13          2.749e-03  1.684e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 15          1.906e-03  1.832e-01  y = m1 / (biprod((z1 - z2) + (x1 - x2), y1 - G) / m2)
# 16          1.671e-03  1.319e-01  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          7.287e-04  8.297e-01  y = m1 / (((biprod(((z1 + x1) - x2) - y2, y1) - z2) / G) /...
#                                        m2)
# 18          4.957e-04  3.852e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - sqr(z2)) /...
#                                        G) / m2)
# 19          1.589e-04  1.138e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.156e-04  3.181e-01  y = (m1 / (((biprod(y1, ((x1 + z1) - x2) - y2) - sqr(z2)) ...
#                                       / G) / m2)) / 1.0647
# 22          1.058e-04  4.436e-02  y = m1 / (((biprod((x1 + z1) + ((-0.12378 - y2) - x2), y1)...
#                                        - sqr(z2)) / G) / (m2 / 1.1122))
# 24          1.052e-04  2.855e-03  y = biprod(m1, 0.91649) / (((biprod(y1, biprod(-1.0174, y2...
#                                       ) + ((x1 + z1) - x2)) - sqr(z2 / -0.97334)) / G) / m2)
# 26          8.640e-05  9.840e-02  y = m1 / (((biprod((biprod(y2, -1.0454) + (x1 + z1)) - x2,...
#                                        (x1 / (z2 / 0.11018)) + y1) - sqr(z2)) / G) / m2)
# 27          8.519e-05  1.421e-02  y = m1 / (((biprod((biprod(y2, -0.99795) + z1) + (x1 - x2)...
#                                       , y1 + sqr(z1 / (z2 / 0.17739))) - sqr(z2)) / G) / m2)
# 29          8.282e-05  1.407e-02  y = biprod(0.97345 / (((biprod((z1 / sqr(z2 / -0.30289)) +...
#                                        y1, (z1 + biprod(y2, -1.0277)) + (x1 - x2)) - sqr(z2)) / ...
#                                       G) / m2), m1)
# 30          8.101e-05  2.217e-02  y = biprod(0.94292, m1) / ((sqr(sqr(z1 / (z2 / -0.24714)))...
#                                        + ((biprod((biprod(-1.0297, y2) + x1) + (z1 - x2), y1) - ...
#                                       sqr(z2)) / G)) / m2)
# 32          7.672e-05  2.721e-02  y = biprod(m1 / ((((biprod(sqr(sqr(z1 / (z2 / -0.2046))) +...
#                                        y1, (biprod(y2, -1.0187) - x2) + (x1 + z1)) - sqr(z2)) / ...
#                                       G) / m2) - -0.055561), 0.96464)
# 34          7.203e-05  3.147e-02  y = biprod(m1, 0.96561) / ((((biprod(y1 + sqr(sqr(z1 / (z2...
#                                        / -0.20727))), (x1 - x2) + (z1 + biprod(-1.0347, y2))) - ...
#                                       sqr(z2)) / G) / m2) - (-0.14317 / x2))
# 35          7.127e-05  1.069e-02  y = biprod(0.96464, m1 / ((((biprod(((biprod(y2, -1.0187) ...
#                                       - x2) + x1) + z1, y1 + sqr(sqr(z1 / (z2 / -0.2046)))) - sq...
#                                       r(z2)) / G) / m2) - (-0.1304 / sqr(x2))))
# 37          6.835e-05  2.092e-02  y = biprod(m1 / ((((biprod(sqr(sqr(z1 / (z2 / 0.21603))) +...
#                                        y1, biprod(y2, -1.0321) + ((z1 + x1) - x2)) - sqr(z2)) / ...
#                                       G) / m2) - biprod(-0.13151 / sqr(x2), z2)), 0.96883)
# 39          6.604e-05  1.719e-02  y = biprod(m1 / (((sqr(sqr(z1 / (z2 / -0.25137))) + ((bipr...
#                                       od(((biprod(y2, -1.0363) + x1) + z1) - x2, y1) - sqr(z2)) ...
#                                       / G)) / m2) - (-0.18885 / sqr(x2 / (x1 / y1)))), 0.96155)
# 40          5.831e-05  1.245e-01  y = biprod(0.96155 / (((((biprod(y1, (z1 + biprod(-1.0213,...
#                                        y2)) + (x1 - x2)) - sqr(z2)) / G) + sqr(sqr(z1 / (z2 / -0...
#                                       .25113)))) / m2) - (-0.20772 / sqr(sqr(x2 / (x1 / y1))))),...
#                                        m1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+05
# Progress: 9536 / 18600 total iterations (51.269%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 13          2.749e-03  1.684e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 15          1.720e-03  2.345e-01  y = m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 16          1.671e-03  2.928e-02  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          7.287e-04  8.297e-01  y = m1 / (((biprod(((z1 + x1) - x2) - y2, y1) - z2) / G) /...
#                                        m2)
# 18          4.957e-04  3.852e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - sqr(z2)) /...
#                                        G) / m2)
# 19          1.589e-04  1.138e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.156e-04  3.181e-01  y = (m1 / (((biprod(y1, ((x1 + z1) - x2) - y2) - sqr(z2)) ...
#                                       / G) / m2)) / 1.0647
# 22          1.058e-04  4.436e-02  y = m1 / (((biprod((x1 + z1) + ((-0.12378 - y2) - x2), y1)...
#                                        - sqr(z2)) / G) / (m2 / 1.1122))
# 23          8.640e-05  2.026e-01  y = (m1 / biprod((y1 / G) / m2, ((((z1 + x1) - x2) + bipro...
#                                       d(0.21077, y1)) - y2) - z2)) / 1.1028
# 27          8.519e-05  3.543e-03  y = m1 / (((biprod((biprod(y2, -0.99795) + z1) + (x1 - x2)...
#                                       , y1 + sqr(z1 / (z2 / 0.17739))) - sqr(z2)) / G) / m2)
# 29          8.239e-05  1.670e-02  y = biprod(0.97464 / (((biprod(((z1 - x2) + biprod(-1.0197...
#                                       , y2)) + x1, y1 + sqr(z1 / (z2 / -0.15713))) - sqr(z2)) / ...
#                                       G) / m2), m1)
# 30          7.817e-05  5.261e-02  y = biprod(0.95276, m1 / (((biprod((biprod(-1.0145, y2) - ...
#                                       x2) + (x1 + z1), y1 + sqr(sqr(z1 / (z2 / -0.20483)))) - sq...
#                                       r(z2)) / G) / m2))
# 32          7.592e-05  1.455e-02  y = biprod(0.95916, m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 ...
#                                       / 0.20682))), biprod(-1.0363, y2) + ((z1 + x1) - x2)) - sq...
#                                       r(z2)) / G) / m2) - -0.069714))
# 34          7.197e-05  2.671e-02  y = biprod(m1, 0.96761) / ((((biprod(sqr(sqr(z1 / (z2 / -0...
#                                       .20895))) + y1, (x1 - x2) + (z1 + biprod(y2, -1.0339))) - ...
#                                       sqr(z2)) / G) / m2) - (-0.14824 / x2))
# 35          7.082e-05  1.614e-02  y = biprod(m1 / ((((biprod((biprod(-1.0235, y2) + (x1 + z1...
#                                       )) - x2, sqr(sqr(z1 / (z2 / -0.21121))) + y1) - sqr(z2)) /...
#                                        G) / m2) - (-0.24336 / sqr(x2))), 0.97752)
# 36          7.061e-05  2.995e-03  y = biprod(m1 / ((((biprod(biprod(-1.0321, y2) + ((x1 + z1...
#                                       ) - x2), sqr(sqr(z1 / (z2 / -0.20786))) + y1) - sqr(z2)) /...
#                                        G) / m2) - (-0.24052 / x2)), 0.99639) - 0.0046066
# 37          6.802e-05  3.741e-02  y = biprod(m1, 0.97286) / ((((biprod(sqr(sqr(z1 / (z2 / 0....
#                                       21529))) + y1, (z1 + biprod(-1.0263, y2)) + (x1 - x2)) - s...
#                                       qr(z2)) / G) / m2) - biprod(z2, -0.1318 / sqr(x2)))
# 39          6.230e-05  4.387e-02  y = biprod(0.9776, m1 / ((((biprod(sqr(sqr(z1 / (z2 / -0.2...
#                                       0873))) + y1, biprod(y2, -1.0214) + ((z1 + x1) - x2)) - sq...
#                                       r(z2)) / G) / m2) - (-0.24078 / sqr(x2 / (x1 / y1)))))
# 40          5.604e-05  1.059e-01  y = biprod(0.96393, m1 / (((((biprod(y1, biprod(y2, -1.019...
#                                       5) + ((z1 + x1) - x2)) - sqr(z2)) + sqr(sqr(z1 / (z2 / -0....
#                                       28835)))) / G) / m2) - (-0.20651 / sqr(sqr(x2 / (x1 / y1))...
#                                       ))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.940e+05
# Progress: 11155 / 18600 total iterations (59.973%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 13          2.749e-03  1.684e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 15          1.720e-03  2.345e-01  y = m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 16          1.671e-03  2.928e-02  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          6.961e-04  8.755e-01  y = m1 / (((biprod((z1 - z2) + (y1 - x2), x1) - y2) / G) /...
#                                        m2)
# 18          4.957e-04  3.395e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - sqr(z2)) /...
#                                        G) / m2)
# 19          1.589e-04  1.138e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.110e-04  3.592e-01  y = (m1 / (((biprod(x1, (y1 + (z1 - z2)) - x2) - sqr(y2)) ...
#                                       / G) / m2)) / 1.0654
# 22          1.058e-04  2.379e-02  y = m1 / (((biprod((x1 + z1) + ((-0.12378 - y2) - x2), y1)...
#                                        - sqr(z2)) / G) / (m2 / 1.1122))
# 23          8.640e-05  2.026e-01  y = (m1 / (biprod((((x1 + z1) - x2) + (biprod(y1, 0.21076)...
#                                        - y2)) - z2, y1 / G) / m2)) / 1.1028
# 25          8.449e-05  1.121e-02  y = m1 / (biprod(y1 / G, ((((z1 + x1) - x2) - y2) + (bipro...
#                                       d(y1, 0.20944) - z2)) / (m2 / 1.0923)) - -0.040526)
# 27          8.314e-05  8.022e-03  y = biprod(m1, 0.86453 / biprod(((x1 + ((z1 - x2) - y2)) -...
#                                        z2) + biprod(0.21108, y1), ((y1 / (m2 / 0.93059)) / G) - ...
#                                       -0.030015))
# 29          8.239e-05  4.556e-03  y = biprod(0.97464 / (((biprod(((z1 - x2) + biprod(-1.0197...
#                                       , y2)) + x1, y1 + sqr(z1 / (z2 / -0.15713))) - sqr(z2)) / ...
#                                       G) / m2), m1)
# 30          7.817e-05  5.261e-02  y = biprod(0.95276, m1 / (((biprod((biprod(-1.0145, y2) - ...
#                                       x2) + (x1 + z1), y1 + sqr(sqr(z1 / (z2 / -0.20483)))) - sq...
#                                       r(z2)) / G) / m2))
# 32          7.570e-05  1.599e-02  y = m1 / ((((biprod(y1 + sqr(z1 / (z2 / -0.16623)), ((x1 +...
#                                        z1) - x2) + biprod(y2, -1.0295)) - sqr(z2)) / G) / m2) - ...
#                                       (-0.23735 / sqr(x2)))
# 33          7.464e-05  1.420e-02  y = m1 / ((((biprod(biprod(y2, -0.98978) + ((x1 + z1) - x2...
#                                       ), sqr(sqr(z1 / (z2 / -0.21958))) + y1) - sqr(z2)) / G) / ...
#                                       m2) - (-0.24718 / sqr(x2)))
# 34          7.064e-05  5.510e-02  y = (m1 / ((((biprod(((biprod(-1.0286, y2) + z1) + x1) - x...
#                                       2, sqr(sqr(z1 / (z2 / -0.20851))) + y1) - sqr(z2)) / G) / ...
#                                       m2) - (-0.24136 / x2))) - 0.0050194
# 35          7.032e-05  4.551e-03  y = biprod(m1, 0.96912 / ((((biprod(sqr(sqr(z1 / (z2 / 0.2...
#                                       0792))) + y1, biprod(-1.0218, y2) + ((z1 + x1) - x2)) - sq...
#                                       r(z2)) / G) / m2) - (-0.18023 / sqr(x2))))
# 37          6.665e-05  2.676e-02  y = m1 / (((biprod(y1, (z1 + (biprod(-1.0146, y2) + x1)) -...
#                                        x2) + (sqr(z1 / (z2 / -0.32324)) - sqr(z2))) / G) / (m2 -...
#                                        (0.081877 / sqr(sqr(x2 / (x1 / y1))))))
# 39          6.201e-05  3.609e-02  y = biprod(m1 / ((((biprod(z1 + ((x1 - x2) + biprod(-1.020...
#                                       6, y2)), y1 + sqr(sqr(z1 / (z2 / -0.20955)))) - sqr(z2)) /...
#                                        G) / m2) - (-0.2221 / sqr(x2 / (x1 / y1)))), 0.97601)
# 40          5.600e-05  1.020e-01  y = biprod(m1 / ((((sqr(sqr(z1 / (z2 / -0.28951))) + (bipr...
#                                       od(y1, (biprod(-1.0191, y2) + (z1 + x1)) - x2) - sqr(z2)))...
#                                        / G) / m2) - (-0.21326 / sqr(sqr(x2 / (x1 / y1))))), 0.96...
#                                       501)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.920e+05
# Progress: 12765 / 18600 total iterations (68.629%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 13          2.749e-03  1.684e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 14          2.726e-03  8.504e-03  y = m1 / (((z1 - sqr(x2)) + biprod(x1, y1 - G)) / m2)
# 15          1.720e-03  4.604e-01  y = m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 16          1.671e-03  2.928e-02  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          6.961e-04  8.755e-01  y = m1 / (((biprod((z1 - z2) + (y1 - x2), x1) - y2) / G) /...
#                                        m2)
# 18          4.957e-04  3.395e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - sqr(z2)) /...
#                                        G) / m2)
# 19          1.589e-04  1.138e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.110e-04  3.592e-01  y = m1 / biprod(((biprod((y1 + (z1 - z2)) - x2, x1) - sqr(...
#                                       y2)) / G) / m2, 1.0654)
# 22          1.058e-04  2.379e-02  y = m1 / (((biprod((x1 + z1) + ((-0.12378 - y2) - x2), y1)...
#                                        - sqr(z2)) / G) / (m2 / 1.1122))
# 23          8.640e-05  2.026e-01  y = (m1 / (biprod(y1, (((biprod(0.21056, y1) - y2) + ((x1 ...
#                                       + z1) - x2)) - z2) / G) / m2)) / 1.1031
# 25          8.331e-05  1.824e-02  y = m1 / (biprod(((((z1 + (x1 - z2)) - x2) - y2) + biprod(...
#                                       0.19533, y1)) / (m2 / 1.1017), y1 / G) - -0.082119)
# 27          8.233e-05  5.910e-03  y = (m1 / ((biprod(y1 / G, ((z1 - x2) + (x1 - z2)) + (bipr...
#                                       od(0.19666, y1) - y2)) / (m2 / 1.0828)) - -0.10479)) - 0.0...
#                                       031643
# 30          7.817e-05  1.729e-02  y = biprod(0.95276, m1 / (((biprod((biprod(-1.0145, y2) - ...
#                                       x2) + (x1 + z1), y1 + sqr(sqr(z1 / (z2 / -0.20483)))) - sq...
#                                       r(z2)) / G) / m2))
# 32          7.570e-05  1.599e-02  y = m1 / ((((biprod(y1 + sqr(z1 / (z2 / -0.16623)), ((x1 +...
#                                        z1) - x2) + biprod(y2, -1.0295)) - sqr(z2)) / G) / m2) - ...
#                                       (-0.23735 / sqr(x2)))
# 33          7.443e-05  1.697e-02  y = m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 / -0.21923))), (...
#                                       biprod(y2, -0.99523) + x1) + (z1 - x2)) - sqr(z2)) / G) / ...
#                                       m2) - (-0.2752 / sqr(x2)))
# 34          7.064e-05  5.232e-02  y = (m1 / ((((biprod(((biprod(-1.0286, y2) + z1) + x1) - x...
#                                       2, sqr(sqr(z1 / (z2 / -0.20851))) + y1) - sqr(z2)) / G) / ...
#                                       m2) - (-0.24136 / x2))) - 0.0050194
# 35          7.025e-05  5.443e-03  y = biprod(m1, 0.97047) / ((((biprod((biprod(-1.0224, y2) ...
#                                       + z1) + (x1 - x2), sqr(sqr(z1 / (z2 / 0.20823))) + y1) - s...
#                                       qr(z2)) / G) / m2) - (-0.19522 / sqr(x2)))
# 37          6.401e-05  4.655e-02  y = m1 / (((biprod(y1, z1 + (((biprod(y2, -1.0279) + sqr(z...
#                                       1 / (z2 / -0.17381))) + x1) - x2)) - sqr(z2)) / G) / (m2 -...
#                                        (0.068786 / sqr(x2 / sqr(x1 / y1)))))
# 39          6.197e-05  1.613e-02  y = biprod(0.97593, m1) / ((((biprod(sqr(sqr(z1 / (z2 / -0...
#                                       .2097))) + y1, (x1 + (biprod(-1.0197, y2) + z1)) - x2) - s...
#                                       qr(z2)) / G) / m2) - (-0.21693 / sqr(x2 / (x1 / y1))))
# 40          5.600e-05  1.014e-01  y = biprod(m1 / ((((sqr(sqr(z1 / (z2 / -0.28951))) + (bipr...
#                                       od(y1, (biprod(-1.0191, y2) + (z1 + x1)) - x2) - sqr(z2)))...
#                                        / G) / m2) - (-0.21326 / sqr(sqr(x2 / (x1 / y1))))), 0.96...
#                                       501)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+05
# Progress: 14264 / 18600 total iterations (76.688%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = biprod(0.18809, m1)
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 12          3.680e-03  4.519e-02  y = m1 / (((biprod(4.1326, y1) - sqr(z2)) / m2) / G)
# 13          2.749e-03  2.916e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 14          2.726e-03  8.504e-03  y = m1 / (((z1 - sqr(x2)) + biprod(x1, y1 - G)) / m2)
# 15          1.720e-03  4.604e-01  y = m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 16          1.671e-03  2.928e-02  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          6.961e-04  8.755e-01  y = m1 / (((biprod(x1, ((z1 + y1) - x2) - z2) - y2) / m2) ...
#                                       / G)
# 18          4.957e-04  3.395e-01  y = m1 / (((biprod(y1, (z1 - y2) + (x1 - x2)) - sqr(z2)) /...
#                                        G) / m2)
# 19          1.589e-04  1.138e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.110e-04  3.592e-01  y = m1 / (biprod(1.0654, (biprod(x1, ((y1 - x2) + z1) - z2...
#                                       ) - sqr(y2)) / G) / m2)
# 22          1.029e-04  3.789e-02  y = m1 / biprod((biprod(x1, (z1 + (y1 - x2)) - z2) - sqr(y...
#                                       2 - -0.074293)) / G, 1.0922 / m2)
# 23          8.640e-05  1.744e-01  y = (m1 / (biprod(y1, (((biprod(0.21056, y1) - y2) + ((x1 ...
#                                       + z1) - x2)) - z2) / G) / m2)) / 1.1031
# 25          8.330e-05  1.828e-02  y = m1 / ((biprod(y1, ((biprod(y1, 0.19641) + ((z1 + (x1 -...
#                                        z2)) - x2)) - y2) / (m2 / 1.1005)) / G) - -0.080427)
# 27          8.226e-05  6.298e-03  y = (m1 / ((biprod(((((x1 - z2) + z1) + (biprod(y1, 0.1966...
#                                       9) - y2)) - x2) / G, y1) / (m2 / 1.0782)) - -0.11384)) - 0...
#                                       .0037694
# 29          8.225e-05  2.757e-05  y = (m1 / (biprod(y1, (((((biprod(y1, 0.19407) + (x1 + (z1...
#                                        - z2))) - y2) - -0.011343) - x2) / G) / (m2 / 1.0768)) - ...
#                                       -0.11319)) - 0.0039259
# 30          7.817e-05  5.096e-02  y = biprod(0.95276, m1 / (((biprod((biprod(-1.0145, y2) - ...
#                                       x2) + (x1 + z1), y1 + sqr(sqr(z1 / (z2 / -0.20483)))) - sq...
#                                       r(z2)) / G) / m2))
# 32          7.570e-05  1.599e-02  y = m1 / ((((biprod(y1 + sqr(z1 / (z2 / -0.16623)), ((x1 +...
#                                        z1) - x2) + biprod(y2, -1.0295)) - sqr(z2)) / G) / m2) - ...
#                                       (-0.23735 / sqr(x2)))
# 33          7.443e-05  1.697e-02  y = m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 / -0.21923))), (...
#                                       biprod(y2, -0.99523) + x1) + (z1 - x2)) - sqr(z2)) / G) / ...
#                                       m2) - (-0.2752 / sqr(x2)))
# 34          7.064e-05  5.232e-02  y = (m1 / ((((biprod(((biprod(-1.0286, y2) + z1) + x1) - x...
#                                       2, sqr(sqr(z1 / (z2 / -0.20851))) + y1) - sqr(z2)) / G) / ...
#                                       m2) - (-0.24136 / x2))) - 0.0050194
# 35          7.025e-05  5.443e-03  y = biprod(m1, 0.97047) / ((((biprod((biprod(-1.0224, y2) ...
#                                       + z1) + (x1 - x2), sqr(sqr(z1 / (z2 / 0.20823))) + y1) - s...
#                                       qr(z2)) / G) / m2) - (-0.19522 / sqr(x2)))
# 37          6.388e-05  4.755e-02  y = m1 / (((biprod((x1 + (biprod(y2, -1.0255) + z1)) + (sq...
#                                       r(z1 / (z2 / -0.16998)) - x2), y1) - sqr(z2)) / G) / (m2 -...
#                                        (0.071521 / sqr(x2 / sqr(x1 / y1)))))
# 39          6.196e-05  1.528e-02  y = biprod(m1, 0.97465 / ((((biprod((x1 + (biprod(-1.0204,...
#                                        y2) + z1)) - x2, y1 + sqr(sqr(z1 / (z2 / -0.20874)))) - s...
#                                       qr(z2)) / G) / m2) - (-0.21287 / sqr(x2 / (x1 / y1)))))
# 40          5.600e-05  1.011e-01  y = biprod(m1 / ((((sqr(sqr(z1 / (z2 / -0.28951))) + (bipr...
#                                       od(y1, (biprod(-1.0191, y2) + (z1 + x1)) - x2) - sqr(z2)))...
#                                        / G) / m2) - (-0.21326 / sqr(sqr(x2 / (x1 / y1))))), 0.96...
#                                       501)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# IOStream.flush timed out
# Expressions evaluated per second: 2.660e+05
# Progress: 15695 / 18600 total iterations (84.382%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = m1 / 5.316
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 12          3.651e-03  5.311e-02  y = m1 / (((biprod(4.1326, y1) - sqr(x2)) / m2) / G)
# 13          2.749e-03  2.837e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 14          2.726e-03  8.504e-03  y = m1 / (((z1 - sqr(x2)) + biprod(x1, y1 - G)) / m2)
# 15          1.720e-03  4.604e-01  y = m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 16          1.671e-03  2.928e-02  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          6.854e-04  8.910e-01  y = m1 / (((biprod(((x1 + y1) - x2) - z2, z1) - y2) / G) /...
#                                        m2)
# 18          4.906e-04  3.344e-01  y = m1 / (((biprod(((y1 - x2) - z2) + x1, z1) - sqr(y2)) /...
#                                        m2) / G)
# 19          1.589e-04  1.127e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.097e-04  3.709e-01  y = m1 / biprod((1.0647 / m2) / G, biprod(z1, x1 + ((y1 - ...
#                                       x2) - z2)) - sqr(y2))
# 22          1.029e-04  3.204e-02  y = m1 / biprod((biprod(x1, (z1 + (y1 - x2)) - z2) - sqr(y...
#                                       2 - -0.074293)) / G, 1.0922 / m2)
# 23          8.640e-05  1.744e-01  y = (m1 / (biprod(y1, (((biprod(0.21056, y1) - y2) + ((x1 ...
#                                       + z1) - x2)) - z2) / G) / m2)) / 1.1031
# 25          8.330e-05  1.828e-02  y = m1 / ((biprod(y1, ((biprod(y1, 0.19641) + ((z1 + (x1 -...
#                                        z2)) - x2)) - y2) / (m2 / 1.1005)) / G) - -0.080427)
# 27          8.224e-05  6.407e-03  y = (m1 / (biprod(y1 / (m2 / 1.0762), ((((z1 + x1) - z2) +...
#                                        (biprod(y1, 0.19494) - x2)) - y2) / G) - -0.12443)) - 0.0...
#                                       042062
# 30          7.817e-05  1.693e-02  y = biprod(0.95276, m1 / (((biprod(y1 + sqr(sqr(z1 / (z2 /...
#                                        -0.20483))), ((x1 + z1) + biprod(-1.0145, y2)) - x2) - sq...
#                                       r(z2)) / G) / m2))
# 32          7.570e-05  1.599e-02  y = m1 / ((((biprod(y1 + sqr(z1 / (z2 / -0.16623)), ((x1 +...
#                                        z1) - x2) + biprod(y2, -1.0295)) - sqr(z2)) / G) / m2) - ...
#                                       (-0.23735 / sqr(x2)))
# 33          7.442e-05  1.711e-02  y = m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 / -0.21929))), (...
#                                       biprod(y2, -0.99472) - x2) + (z1 + x1)) - sqr(z2)) / G) / ...
#                                       m2) - (-0.27531 / sqr(x2)))
# 34          7.064e-05  5.218e-02  y = (m1 / ((((biprod(((biprod(-1.0286, y2) + z1) + x1) - x...
#                                       2, sqr(sqr(z1 / (z2 / -0.20851))) + y1) - sqr(z2)) / G) / ...
#                                       m2) - (-0.24136 / x2))) - 0.0050194
# 35          7.025e-05  5.444e-03  y = biprod(m1, 0.97047 / ((((biprod(sqr(sqr(z1 / (z2 / 0.2...
#                                       0822))) + y1, (z1 + biprod(-1.0224, y2)) + (x1 - x2)) - sq...
#                                       r(z2)) / G) / m2) - (-0.19522 / sqr(x2))))
# 36          6.976e-05  7.110e-03  y = biprod(0.96882, m1) / ((((biprod(biprod(y2, -1.0071) +...
#                                        ((z1 + x1) - x2), sqr(sqr(z1 / (z2 / -0.20738))) + y1) - ...
#                                       sqr(z2)) / G) / m2) - (-0.21101 / sqr(sqr(x2))))
# 37          6.388e-05  8.800e-02  y = m1 / (((biprod(biprod(y2, -1.0255) + (z1 + (sqr(z1 / (...
#                                       z2 / -0.1699)) + (x1 - x2))), y1) - sqr(z2)) / G) / (m2 - ...
#                                       (0.071637 / sqr(x2 / sqr(x1 / y1)))))
# 39          6.196e-05  1.528e-02  y = biprod(0.9747 / ((((biprod((biprod(-1.0204, y2) + (z1 ...
#                                       + x1)) - x2, y1 + sqr(sqr(z1 / (z2 / -0.20869)))) - sqr(z2...
#                                       )) / G) / m2) - (-0.21285 / sqr(x2 / (x1 / y1)))), m1)
# 40          5.570e-05  1.064e-01  y = biprod(m1, 0.97144) / ((((biprod(sqr(sqr(z1 / (z2 / 0....
#                                       20737))) + y1, biprod(-1.0058, y2) + ((x1 - x2) + z1)) - s...
#                                       qr(z2)) / G) / m2) - (-0.20941 / sqr(sqr(x2 / (x1 / y1))))...
#                                       )
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+05
# Progress: 17150 / 18600 total iterations (92.204%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = m1 / 5.316
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 12          3.651e-03  5.311e-02  y = m1 / (((biprod(4.1326, y1) - sqr(x2)) / m2) / G)
# 13          2.749e-03  2.837e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 14          2.726e-03  8.504e-03  y = m1 / (((z1 - sqr(x2)) + biprod(x1, y1 - G)) / m2)
# 15          1.720e-03  4.604e-01  y = m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 16          1.671e-03  2.928e-02  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          6.854e-04  8.910e-01  y = m1 / (((biprod(((x1 + y1) - x2) - z2, z1) - y2) / G) /...
#                                        m2)
# 18          4.906e-04  3.344e-01  y = m1 / (((biprod(((y1 - x2) - z2) + x1, z1) - sqr(y2)) /...
#                                        m2) / G)
# 19          1.589e-04  1.127e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.097e-04  3.709e-01  y = m1 / biprod((1.0647 / m2) / G, biprod(z1, x1 + ((y1 - ...
#                                       x2) - z2)) - sqr(y2))
# 22          1.029e-04  3.204e-02  y = m1 / biprod((biprod(x1, (z1 + (y1 - x2)) - z2) - sqr(y...
#                                       2 - -0.074293)) / G, 1.0922 / m2)
# 23          8.640e-05  1.744e-01  y = (m1 / (biprod(y1, (((biprod(0.21056, y1) - y2) + ((x1 ...
#                                       + z1) - x2)) - z2) / G) / m2)) / 1.1031
# 25          8.296e-05  2.030e-02  y = m1 / (biprod(y1 - -0.22804, (((biprod(0.21499, y1) - x...
#                                       2) + ((x1 + (z1 - z2)) - y2)) / G) / m2) / 0.97214)
# 27          8.215e-05  4.922e-03  y = m1 / (biprod(((x1 + ((z1 - z2) + biprod(y1, 0.20788)))...
#                                        - x2) - y2, (((y1 - -0.22734) / m2) / 0.97262) / G) - -0....
#                                       037258)
# 30          7.817e-05  1.657e-02  y = biprod(0.95276, m1 / (((biprod(y1 + sqr(sqr(z1 / (z2 /...
#                                        -0.20483))), ((x1 + z1) + biprod(-1.0145, y2)) - x2) - sq...
#                                       r(z2)) / G) / m2))
# 32          7.570e-05  1.599e-02  y = m1 / ((((biprod(y1 + sqr(z1 / (z2 / -0.16623)), ((x1 +...
#                                        z1) - x2) + biprod(y2, -1.0295)) - sqr(z2)) / G) / m2) - ...
#                                       (-0.23735 / sqr(x2)))
# 33          7.442e-05  1.711e-02  y = m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 / -0.21929))), (...
#                                       biprod(y2, -0.99472) - x2) + (z1 + x1)) - sqr(z2)) / G) / ...
#                                       m2) - (-0.27531 / sqr(x2)))
# 34          7.064e-05  5.218e-02  y = (m1 / ((((biprod(((biprod(-1.0286, y2) + z1) + x1) - x...
#                                       2, sqr(sqr(z1 / (z2 / -0.20851))) + y1) - sqr(z2)) / G) / ...
#                                       m2) - (-0.24136 / x2))) - 0.0050194
# 35          7.025e-05  5.444e-03  y = biprod(m1, 0.97047 / ((((biprod(sqr(sqr(z1 / (z2 / 0.2...
#                                       0822))) + y1, (z1 + biprod(-1.0224, y2)) + (x1 - x2)) - sq...
#                                       r(z2)) / G) / m2) - (-0.19522 / sqr(x2))))
# 36          6.974e-05  7.277e-03  y = biprod(0.96749, m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 ...
#                                       / 0.20735))), biprod(-1.0091, y2) + ((z1 + x1) - x2)) - sq...
#                                       r(z2)) / G) / m2) - (-0.20692 / sqr(sqr(x2)))))
# 37          6.388e-05  8.783e-02  y = m1 / (((biprod(biprod(y2, -1.0255) + (z1 + (sqr(z1 / (...
#                                       z2 / -0.1699)) + (x1 - x2))), y1) - sqr(z2)) / G) / (m2 - ...
#                                       (0.071637 / sqr(x2 / sqr(x1 / y1)))))
# 39          6.196e-05  1.528e-02  y = biprod(0.97468 / ((((biprod(sqr(sqr(z1 / (z2 / -0.2086...
#                                       6))) + y1, (z1 + (biprod(y2, -1.0204) + x1)) - x2) - sqr(z...
#                                       2)) / G) / m2) - (-0.21283 / sqr(x2 / (x1 / y1)))), m1)
# 40          5.570e-05  1.065e-01  y = biprod(0.97171, m1 / ((((biprod(sqr(sqr(z1 / (z2 / 0.2...
#                                       0738))) + y1, ((biprod(-1.0051, y2) + x1) + z1) - x2) - sq...
#                                       r(z2)) / G) / m2) - (-0.20615 / sqr(sqr(x2 / (x1 / y1)))))...
#                                       )
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.410e-02  0.000e+00  y = 0.27732
# 3           1.136e-02  1.083e-01  y = m1 / 5.316
# 5           8.553e-03  1.417e-01  y = biprod(m2, m1 / 7.9365)
# 7           5.297e-03  2.396e-01  y = biprod(biprod(m2, G), m1) / 11.815
# 8           5.098e-03  3.826e-02  y = biprod(biprod(G, m2), m1 / sqr(y1))
# 9           3.910e-03  2.652e-01  y = m1 / ((biprod(y1, x1) / m2) / G)
# 11          3.850e-03  7.726e-03  y = biprod(G, m1 / (biprod(z1, y1 / m2) + -0.2008))
# 12          3.651e-03  5.311e-02  y = m1 / (((biprod(4.1326, y1) - sqr(x2)) / m2) / G)
# 13          2.749e-03  2.837e-01  y = m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 14          2.726e-03  8.504e-03  y = m1 / (((z1 - sqr(x2)) + biprod(x1, y1 - G)) / m2)
# 15          1.720e-03  4.604e-01  y = m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 16          1.671e-03  2.928e-02  y = m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1) / G)) /...
#                                        m2)
# 17          6.854e-04  8.910e-01  y = m1 / (((biprod(((x1 + y1) - x2) - z2, z1) - y2) / G) /...
#                                        m2)
# 18          4.906e-04  3.344e-01  y = m1 / (((biprod(((y1 - x2) - z2) + x1, z1) - sqr(y2)) /...
#                                        m2) / G)
# 19          1.589e-04  1.127e+00  y = m1 / (biprod(y1 / G, ((((x1 + z1) + 1.0001) - y2) - x2...
#                                       ) - z2) / m2)
# 20          1.097e-04  3.709e-01  y = m1 / biprod((1.0647 / m2) / G, biprod(z1, x1 + ((y1 - ...
#                                       x2) - z2)) - sqr(y2))
# 22          1.029e-04  3.204e-02  y = m1 / biprod((biprod(x1, (z1 + (y1 - x2)) - z2) - sqr(y...
#                                       2 - -0.074293)) / G, 1.0922 / m2)
# 23          8.285e-05  2.164e-01  y = m1 / ((biprod(((((x1 + z1) - z2) - y2) + biprod(y1, 0....
#                                       21669)) - x2, y1 - -0.32365) / G) / m2)
# 25          8.191e-05  5.721e-03  y = m1 / ((biprod(biprod(0.23697, y1 + -0.38042) + ((((x1 ...
#                                       - y2) - x2) + z1) - z2), y1 - -0.34906) / G) / m2)
# 27          8.094e-05  5.924e-03  y = (m1 / ((biprod((y1 - -0.23656) / m2, ((x1 + (z1 - z2))...
#                                        - x2) + (biprod(0.20762, y1) - y2)) / G) - -0.084781)) + ...
#                                       -0.0044333
# 29          8.057e-05  2.300e-03  y = (m1 / (biprod((((biprod(y1, 0.21912) + (x1 - x2)) + ((...
#                                       z1 - (y2 / 0.98448)) - z2)) / m2) / G, y1 - -0.23192) - -0...
#                                       .079065)) + -0.0037937
# 30          7.817e-05  3.029e-02  y = biprod(0.95276, m1 / (((biprod(y1 + sqr(sqr(z1 / (z2 /...
#                                        -0.20483))), ((x1 + z1) + biprod(-1.0145, y2)) - x2) - sq...
#                                       r(z2)) / G) / m2))
# 32          7.570e-05  1.599e-02  y = m1 / ((((biprod(y1 + sqr(z1 / (z2 / -0.16623)), ((x1 +...
#                                        z1) - x2) + biprod(y2, -1.0295)) - sqr(z2)) / G) / m2) - ...
#                                       (-0.23735 / sqr(x2)))
# 33          7.442e-05  1.711e-02  y = m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 / -0.21929))), b...
#                                       iprod(-0.99472, y2) + ((x1 + z1) - x2)) - sqr(z2)) / G) / ...
#                                       m2) - (-0.27531 / sqr(x2)))
# 34          7.064e-05  5.218e-02  y = (m1 / ((((biprod(((biprod(-1.0286, y2) + z1) + x1) - x...
#                                       2, sqr(sqr(z1 / (z2 / -0.20851))) + y1) - sqr(z2)) / G) / ...
#                                       m2) - (-0.24136 / x2))) - 0.0050194
# 35          7.025e-05  5.444e-03  y = biprod(m1, 0.97047 / ((((biprod(sqr(sqr(z1 / (z2 / 0.2...
#                                       0822))) + y1, (z1 + biprod(-1.0224, y2)) + (x1 - x2)) - sq...
#                                       r(z2)) / G) / m2) - (-0.19522 / sqr(x2))))
# 36          6.974e-05  7.277e-03  y = biprod(0.96749, m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 ...
#                                       / 0.20735))), biprod(-1.0091, y2) + ((z1 + x1) - x2)) - sq...
#                                       r(z2)) / G) / m2) - (-0.20692 / sqr(sqr(x2)))))
# 37          6.388e-05  8.783e-02  y = m1 / (((biprod(((x1 + (z1 + biprod(y2, -1.0255))) + sq...
#                                       r(z1 / (z2 / -0.1699))) - x2, y1) - sqr(z2)) / G) / (m2 - ...
#                                       (0.071637 / sqr(x2 / sqr(x1 / y1)))))
# 39          6.196e-05  1.528e-02  y = biprod(0.97468 / ((((biprod(sqr(sqr(z1 / (z2 / -0.2086...
#                                       6))) + y1, (z1 + (biprod(y2, -1.0204) + x1)) - x2) - sqr(z...
#                                       2)) / G) / m2) - (-0.21283 / sqr(x2 / (x1 / y1)))), m1)
# 40          5.570e-05  1.065e-01  y = biprod(0.97171, m1 / ((((biprod(sqr(sqr(z1 / (z2 / 0.2...
#                                       0738))) + y1, ((biprod(-1.0051, y2) + x1) + z1) - x2) - sq...
#                                       r(z2)) / G) / m2) - (-0.20615 / sqr(sqr(x2 / (x1 / y1)))))...
#                                       )
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         0.27732286
# 	1         0.108289                                      m1 / 5.315993
# 	2         0.141703                          biprod(m2, m1 / 7.936466)
# 	3         0.239585              biprod(biprod(m2, G), m1) / 11.815334
# 	4         0.038260                biprod(biprod(G, m2), m1 / sqr(y1))
# 	5         0.265222                   m1 / ((biprod(y1, x1) / m2) / G)
# 	6         0.007726  biprod(G, m1 / (biprod(z1, y1 / m2) + -0.20080...
# 	7         0.053113  m1 / (((biprod(4.132648, y1) - sqr(x2)) / m2) ...
# 	8         0.283670     m1 / (((z1 + (biprod(y1, x1) / x2)) / G) / m2)
# 	9         0.008504  m1 / (((z1 - sqr(x2)) + biprod(x1, y1 - G)) / m2)
# 	10        0.460445  m1 / biprod(y1 - G, ((x1 - x2) - z2) + (z1 / m2))
# 	11        0.029284  m1 / ((((z1 / x2) - sqr(z2)) + (biprod(y1, x1)...
# 	12        0.890972  m1 / (((biprod(((x1 + y1) - x2) - z2, z1) - y2...
# 	13        0.334400  m1 / (((biprod(((y1 - x2) - z2) + x1, z1) - sq...
# 	14        1.127214  m1 / (biprod(y1 / G, ((((x1 + z1) + 1.000136) ...
# 	15        0.370893  m1 / biprod((1.0647261 / m2) / G, biprod(z1, x...
# 	16        0.032037  m1 / biprod((biprod(x1, (z1 + (y1 - x2)) - z2)...
# 	17  >>>>  0.216363  m1 / ((biprod(((((x1 + z1) - z2) - y2) + bipro...
# 	18        0.005721  m1 / ((biprod(biprod(0.2369665, y1 + -0.380418...
# 	19        0.005924  (m1 / ((biprod((y1 - -0.23656212) / m2, ((x1 +...
# 	20        0.002300  (m1 / (biprod((((biprod(y1, 0.21911846) + (x1 ...
# 	21        0.030287  biprod(0.9527632, m1 / (((biprod(y1 + sqr(sqr(...
# 	22        0.015992  m1 / ((((biprod(y1 + sqr(z1 / (z2 / -0.1662308...
# 	23        0.017114  m1 / ((((biprod(y1 + sqr(sqr(z1 / (z2 / -0.219...
# 	24        0.052182  (m1 / ((((biprod(((biprod(-1.0285892, y2) + z1...
# 	25        0.005443  biprod(m1, 0.9704652 / ((((biprod(sqr(sqr(z1 /...
# 	26        0.007277  biprod(0.9674942, m1 / ((((biprod(y1 + sqr(sqr...
# 	27        0.087830  m1 / (((biprod(((x1 + (z1 + biprod(y2, -1.0255...
# 	28        0.015281  biprod(0.9746813 / ((((biprod(sqr(sqr(z1 / (z2...
# 	29        0.106529  biprod(0.9717134, m1 / ((((biprod(sqr(sqr(z1 /...
#
# 	        loss  complexity
# 	0   0.014101           1
# 	1   0.011355           3
# 	2   0.008553           5
# 	3   0.005297           7
# 	4   0.005098           8
# 	5   0.003910           9
# 	6   0.003850          11
# 	7   0.003651          12
# 	8   0.002749          13
# 	9   0.002726          14
# 	10  0.001720          15
# 	11  0.001671          16
# 	12  0.000685          17
# 	13  0.000491          18
# 	14  0.000159          19
# 	15  0.000110          20
# 	16  0.000103          22
# 	17  0.000083          23
# 	18  0.000082          25
# 	19  0.000081          27
# 	20  0.000081          29
# 	21  0.000078          30
# 	22  0.000076          32
# 	23  0.000074          33
# 	24  0.000071          34
# 	25  0.000070          35
# 	26  0.000070          36
# 	27  0.000064          37
# 	28  0.000062          39
# 	29  0.000056          40
# ]
#   - outputs/20250928_093651_ZjIL29/hall_of_fame.csv

# %%
model.sympy()
# Out:
# m1/((((y1 - 1*(-0.3236492))*(x1 - x2 + 0.21669269*y1 - y2 + z1 - z2))/(G*m2)))

# %%
# Define the symbolic variable
x0 = sympy.symbols('x0')

# Build each part of the expression
expr = (sympy.simplify(model.sympy()))

# Optionally simplify or expand the expression
expanded_expr = sympy.expand(expr)
expanded_expr
# Out:
# G*m1*m2/(x1*y1 + 0.3236492*x1 - x2*y1 - 0.3236492*x2 + 0.21669269*y1**2 - y1*y2 + y1*z1 - y1*z2 + 0.070132415764348*y1 - 0.3236492*y2 + 0.3236492*z1 - 0.3236492*z2)
