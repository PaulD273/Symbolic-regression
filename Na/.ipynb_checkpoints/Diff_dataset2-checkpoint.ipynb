# %%
import pandas as pd
import numpy as np
import os
import json
from scipy import constants
from pysr import PySRRegressor
import matplotlib.pyplot as plt
import sympy
import random
from ase.io import read
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
atoms_train = read("/home/paolo/Na_dataset/train_Na_new.xyz", index=":")
atoms_test = read("/home/paolo/Na_dataset/test_Na_new.xyz", index=":")

# %%
# -bottleneck (free distance available for a Na⁺ ion to pass through the narrowest part of a diffusion pathway formed by surrounding framework atoms (typically O²⁻, S²⁻, or halides))

# -face-area   (area of the shared face between two neighboring Voronoi polyhedra corresponding to adjacent Na sites it represents the cross-sectional area available for Na⁺ migration between those sites)

# -pockets  (free-volume region in the crystal structure where a Na⁺ ion can reside with relatively low energy, typically corresponding to a stable or metastable Na site)

# -paths  (connected sequence of pockets linked by Voronoi faces and constrained by bottlenecks, forming a continuous route that allows Na⁺ ions to move through the crystal lattice)

# -poly_dist (Polyhedral distortion is the degree to which the bond lengths and bond angles of a coordination polyhedron differ from those of an ideal reference polyhedron.)

# -Na-Na (are just the Na-Na distances)

# -V^(1/3) parametro reticolare della supercella cubica

# %%
atoms_test[0].info.keys()
# Out:
# dict_keys(['Ea', 'B', 'N', 'O', 'F', 'Na', 'Al', 'Si', 'P', 'S', 'Cl', 'Ge', 'Br', 'I', 'density', 'AAV', 'PF', 'SBI', 'RBI', 'VPA', 'NBI', 'weighted_electronegativity', 'log_conductivity', 'logD', 'Na-Na', 'bottleneck_min', 'bottleneck_avg', 'poly_dist_avg', 'poly_dist_max', 'poly_dist_std', 'Na-Na-max', 'Na-Na-avg', 'face-area-max', 'face-area-avg', 'face-area-min', 'face-area-count', 'pockets-per-ion', 'pockets-per-volume', 'paths-per-ion', 'paths-per-volume', 'poly_dist_avg_fixed'])

# %%
data_train = pd.concat(
    [pd.DataFrame([a.info for a in atoms_train]),
     pd.DataFrame({'volume': [a.get_volume() for a in atoms_train]})],
    axis=1
)
data_test = pd.concat(
    [pd.DataFrame([a.info for a in atoms_test]),
     pd.DataFrame({'volume': [a.get_volume() for a in atoms_test]})],
    axis=1
)

# %%
data_train
# Out:
#             Ea         B    N         O         F        Na        Al  \
# 0     0.365113  0.000000  0.0  0.631387  0.000000  0.127737  0.000000
# 1     0.425024  0.000000  0.0  0.467925  0.000000  0.184906  0.000000
# 2     0.274638  0.113043  0.0  0.000000  0.000000  0.208696  0.108696
# 3     0.324737  0.000000  0.0  0.000000  0.000000  0.101124  0.000000
# 4     0.345059  0.000000  0.0  0.407692  0.000000  0.219231  0.000000
# ...        ...       ...  ...       ...       ...       ...       ...
# 1036  0.321759  0.000000  0.0  0.000000  0.000000  0.241935  0.000000
# 1037  0.389788  0.000000  0.0  0.380711  0.106599  0.335025  0.177665
# 1038  0.393305  0.250000  0.0  0.500000  0.000000  0.250000  0.000000
# 1039  0.335168  0.000000  0.0  0.417969  0.000000  0.187500  0.000000
# 1040  0.449545  0.000000  0.0  0.391753  0.000000  0.386598  0.000000
#
#             Si         P         S  ...  face-area-max  face-area-avg  \
# 0     0.000000  0.171533  0.000000  ...      10.973040       2.521378
# 1     0.000000  0.135849  0.000000  ...      11.777366       2.837638
# 2     0.000000  0.000000  0.304348  ...      15.033404       3.383426
# 3     0.243446  0.033708  0.621723  ...      12.877547       3.444336
# 4     0.000000  0.161538  0.000000  ...      15.090982       3.165906
# ...        ...       ...       ...  ...            ...            ...
# 1036  0.000000  0.161290  0.451613  ...      12.864103       3.268545
# 1037  0.000000  0.000000  0.000000  ...       8.761876       1.934795
# 1038  0.000000  0.000000  0.000000  ...       8.829005       1.864119
# 1039  0.000000  0.027344  0.000000  ...      13.544451       2.987695
# 1040  0.123711  0.000000  0.000000  ...      10.526856       2.167254
#
#       face-area-min  face-area-count  pockets-per-ion  pockets-per-volume  \
# 0      2.554994e-06        24.784055         5.371429            0.046887
# 1      8.278834e-07        29.008265         1.173469            0.011507
# 2      2.368494e-11        39.474009         2.583333            0.021100
# 3      5.345359e-06        40.587672         8.425926            0.032273
# 4      4.092372e-09        35.067899         2.105263            0.021466
# ...             ...              ...              ...                 ...
# 1036   4.741584e-07        37.803003         1.360784            0.012972
# 1037   1.569696e-06        12.466122         0.335859            0.008334
# 1038   7.645468e-07        13.897762         0.412000            0.008600
# 1039   7.102955e-06        32.194261         3.026042            0.029022
# 1040   3.677919e-08        15.919592         0.097778            0.002483
#
#       paths-per-ion  paths-per-volume  poly_dist_avg_fixed        volume
# 0         45.342857          0.395793             0.385197  16038.697093
# 1          5.484694          0.053782             0.375974  19988.125341
# 2         14.566667          0.118978             0.080752  29383.692649
# 3         51.564815          0.197504             0.116010  28196.892709
# 4         13.359649          0.136222             0.363843  22360.631045
# ...             ...               ...                  ...           ...
# 1036       5.980392          0.057011             0.091131  26749.291087
# 1037       2.255051          0.055958             0.317510  15958.495344
# 1038       1.924000          0.040160             0.368284  11977.043019
# 1039      16.453125          0.157799             0.301010  20019.155151
# 1040       0.337778          0.008577             0.342696  17722.570298
#
# [1041 rows x 42 columns]

# %%
data_train.columns
# Out:
# Index(['Ea', 'B', 'N', 'O', 'F', 'Na', 'Al', 'Si', 'P', 'S', 'Cl', 'Ge', 'Br',
#        'I', 'density', 'AAV', 'PF', 'SBI', 'RBI', 'VPA', 'NBI',
#        'weighted_electronegativity', 'log_conductivity', 'logD', 'Na-Na',
#        'bottleneck_min', 'bottleneck_avg', 'poly_dist_avg', 'poly_dist_max',
#        'poly_dist_std', 'Na-Na-max', 'Na-Na-avg', 'face-area-max',
#        'face-area-avg', 'face-area-min', 'face-area-count', 'pockets-per-ion',
#        'pockets-per-volume', 'paths-per-ion', 'paths-per-volume',
#        'poly_dist_avg_fixed', 'volume'],
#       dtype='object')

# %%
def initialize(df, med_flag = False):
    kb = constants.physical_constants['Boltzmann constant in eV/K'][0]
    T = 300
    ln_D_all = np.array(df['logD'])
    if (med_flag == True):
        med =  np.median(ln_D_all).round()
        ln_D = ln_D_all[ln_D_all>med]
        ind = np.where(ln_D_all > med)[0]
    else:
        med = -100
        ln_D = ln_D_all[ln_D_all>med]
        ind = np.where(ln_D_all > med)[0]
    
    return {
        "ln_D_all" : ln_D_all,
        "ln_D" : ln_D,
        "T" : np.repeat(T, len(ln_D_all)),
        "E_T" : np.array(df['Ea'], dtype = 'float')[ind]/(kb*T),
        "E" : np.array(df['Ea'], dtype = 'float')[ind],
        "V" : np.array(df['volume'], dtype = 'float')[ind],
        
        # Atomic fractions of a given element
        "B":  np.array(df['B'], dtype='float')[ind],
        "N":  np.array(df['N'], dtype='float')[ind],
        "O":  np.array(df['O'], dtype='float')[ind],
        "F":  np.array(df['F'], dtype='float')[ind],
        "Na": np.array(df['Na'], dtype='float')[ind],
        "Al": np.array(df['Al'], dtype='float')[ind],
        "Si": np.array(df['Si'], dtype='float')[ind],
        "P":  np.array(df['P'], dtype='float')[ind],
        "S":  np.array(df['S'], dtype='float')[ind],
        "Cl": np.array(df['Cl'], dtype='float')[ind],
        "Ge": np.array(df['Ge'], dtype='float')[ind],
        "Br": np.array(df['Br'], dtype='float')[ind],
        "I":  np.array(df['I'], dtype='float')[ind],
        
        "density": np.array(df['density'], dtype='float')[ind],
        # Average Atomic Volume
        "AAV": np.array(df['AAV'], dtype='float')[ind],
        # Packing fraction
        "PF": np.array(df['PF'], dtype='float')[ind],
        # set-of-non-Na-atoms bond ionicity
        "SBI": np.array(df['SBI'], dtype='float')[ind],
        # Volume per anion
        "VPA": np.array(df['VPA'], dtype='float')[ind],
        # Na bond ionicity
        "NBI": np.array(df['NBI'], dtype='float')[ind],
        # Ratio of NBI and SBI
        "RBI": np.array(df['RBI'], dtype='float')[ind],
        # Weighted electronegativity
        "WE": np.array(df['weighted_electronegativity'], dtype='float')[ind],
        # -Na-Na (are just the Na-Na distances)
        "Na-Na": np.array(df['Na-Na'], dtype='float')[ind],
        "Na-Na-max": np.array(df['Na-Na-max'], dtype='float')[ind],
        "Na-Na-avg": np.array(df['Na-Na-avg'], dtype='float')[ind],
        # -bottleneck (free distance available for a Na⁺ ion to pass through the narrowest part of a diffusion pathway formed by surrounding framework atoms (typically O²⁻, S²⁻, or halides))
        "bottleneck_min": np.array(df['bottleneck_min'], dtype='float')[ind],
        "bottleneck_avg": np.array(df['bottleneck_avg'], dtype='float')[ind],
        # -poly_dist (Polyhedral distortion is the degree to which the bond lengths and bond angles of a coordination polyhedron differ from those of an ideal reference polyhedron.)
        "poly_dist_max": np.array(df['poly_dist_max'], dtype='float')[ind],
        "poly_dist_std": np.array(df['poly_dist_std'], dtype='float')[ind],
        "poly_dist_avg": np.array(df['poly_dist_avg'], dtype='float')[ind],
        "poly_dist_avg_fixed": np.array(df['poly_dist_avg_fixed'], dtype='float')[ind],
        # -face-area   (area of the shared face between two neighboring Voronoi polyhedra corresponding to adjacent Na sites it represents the cross-sectional area available for Na⁺ migration between those sites)
        "face-area-max": np.array(df['face-area-max'], dtype='float')[ind],
        "face-area-avg": np.array(df['face-area-avg'], dtype='float')[ind],
        "face-area-min": np.array(df['face-area-min'], dtype='float')[ind],
        "face-area-count": np.array(df['face-area-count'], dtype='float')[ind],
        # -pockets  (free-volume region in the crystal structure where a Na⁺ ion can reside with relatively low energy, typically corresponding to a stable or metastable Na site)
        "pockets-per-ion": np.array(df['pockets-per-ion'], dtype='float')[ind],
        "pockets-per-volume": np.array(df['pockets-per-volume'], dtype='float')[ind],
        # -paths  (connected sequence of pockets linked by Voronoi faces and constrained by bottlenecks, forming a continuous route that allows Na⁺ ions to move through the crystal lattice)
        "paths-per-ion": np.array(df['paths-per-ion'], dtype='float')[ind],
        "paths-per-volume": np.array(df['paths-per-volume'], dtype='float')[ind],
    }

# %%
kb = constants.physical_constants['Boltzmann constant in eV/K'][0]
data = initialize(data_train)
lnDvsE = pd.DataFrame({
    "sample_id": [f"s{j+1}" for j in range(len(data['ln_D']))], 
    "E_T": data['E_T'],
    "rho (g/cm^3)": data['density'],
    "AAV (A^3)": data['AAV'],
    "PF": data['PF'],
    "VPA (A^3)": data['VPA'],
    "NBI": data['NBI'],
    "SBI": data['SBI'],
    "RBI": data['RBI'],
    "WE": data['WE'],
    "B": data['B'],
    "N": data['N'],
    "S": data['S'],
    "O": data['O'],
    "F": data['F'],
    "Na": data['Na'],
    "Al": data['Al'],
    "Si": data['Si'],
    "P": data['P'],
    "Cl": data['Cl'],
    "Ge": data['Ge'],
    "Br": data['Br'],
    "I": data['I'],

    # Volume
    "cub_root_V (A)" : data['V']**(1/3),
    
    # Na–Na distances
    "Na-Na": data['Na-Na'],
    "Na-Na-max": data['Na-Na-max'],
    "Na-Na-avg": data['Na-Na-avg'],

    # Bottleneck descriptors
    "bottleneck_min": data['bottleneck_min'],
    "bottleneck_avg": data['bottleneck_avg'],

    # Polyhedral distortion
    "poly_dist_max": data['poly_dist_max'],
    "poly_dist_std": data['poly_dist_std'],
    "poly_dist_avg": data['poly_dist_avg'],
    "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],

    # Voronoi face areas
    "face-area-max": data['face-area-max'],
    "face-area-avg": data['face-area-avg'],
    "face-area-min": data['face-area-min'],
    "face-area-count": data['face-area-count'],

    # Pockets
    "pockets-per-ion": data['pockets-per-ion'],
    "pockets-per-volume": data['pockets-per-volume'],

    # Paths
    "paths-per-ion": data['paths-per-ion'],
    "paths-per-volume": data['paths-per-volume'],

    # Target
    "ln_D": data['ln_D']
})

# %%
n_feat = 40
lnDvsE.to_csv(f"/home/paolo/Thesis/Na/data/dataset2/Na_lndiff{n_feat}_temp300_withunits.csv", index=False)
data_file = f"/home/paolo/Thesis/Na/data/dataset2/Na_lndiff{n_feat}_temp300_withunits.csv"
os.environ["SISSOPP_TUT_DAT_FILE"] = data_file

# %%
# Try the fit with the exact functional form
rung = 2
Diff_json = {
    'data_file': data_file,
     'property_key': 'ln_D',
     'desc_dim': 1,
     'n_sis_select': 10,
     'max_rung': rung,
     'calc_type': 'regression',
     'min_abs_feat_val': 1e-05,
     'max_abs_feat_val': 1e8,
     'n_residual': 10,
     'n_models_store': 10,
     'leave_out_frac': 0.0,
     'leave_out_inds': [],
     'opset': ['exp', 'add', 'sub', 'mult', 'div', 'sin', 'cos']
}
json.dump(Diff_json, open(f"/home/paolo/Thesis/Na/data/dataset2/lndiff{n_feat}_{rung}_withunits.json", "w"), indent=4)

# %%
# Rung=2 Features=40 'E_T': E/(kb*T), 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA, 'NBI': NBI, 'SBI': SBI,  'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I, 'cub_root_V': V^(1/3),
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# time input_parsing: 0.0594207 s
# Time to generate feat space: 164.976 s
# Projection time: 7.62679 s
# Time to get best features on rank : 0.0041563 s
# |---Complete final combination/selection from all ranks: 0.0069424 s
# Time for SIS: 11.1319 s
# Time for l0-norm: 0.0118128 s
# Train RMSE: 0.43248 Unitless
# c0 + a0 * ((O * rho) - (face-area-avg - E_T))
# Coefficients
# Task   a0                      c0
# all , -7.449893592450271e-01, -1.235328968693277e+01,

# %%
# Rung=2 Features=38 'E_T': E/(kb*T), 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA,  'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I, 'V': V,
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# time input_parsing: 0.0551246 s
# Time to generate feat space: 123.141 s
# Projection time: 5.96858 s
# Time to get best features on rank : 0.0005478 s
# |---Complete final combination/selection from all ranks: 0.00534 s
# Time for SIS: 8.53285 s
# Time for l0-norm: 0.01114 s
# Train RMSE: 0.43248 Unitless
# c0 + a0 * ((O * rho) - (face-area-avg - E_T))
# Coefficients
# Task   a0                      c0
# all , -7.449893592450271e-01, -1.235328968693277e+01,

# %%
# Rung=2 Features=38 'E_T': E/(kb*T), 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA,  'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I, 'cub_root_V': V^(1/3),
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# time input_parsing: 0.0595599 s
# Time to generate feat space: 124.406 s
# Projection time: 6.24627 s
# Time to get best features on rank : 0.0001272 s
# |---Complete final combination/selection from all ranks: 0.0051718 s
# Time for SIS: 8.9327 s
# Time for l0-norm: 0.0048544 s
# Train RMSE: 0.43248 Unitless
# c0 + a0 * ((O * rho) - (face-area-avg - E_T))
# Coefficients
# Task   a0                      c0
# all , -7.449893592450271e-01, -1.235328968693277e+01,

# %%
# Rung=2 Features=37 'E_T': E/(kb*T), 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA,  'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I,
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# time input_parsing: 0.0625003 s
# Time to generate feat space: 112.924 s
# Projection time: 5.23265 s
# Time to get best features on rank : 0.0004333 s
# |---Complete final combination/selection from all ranks: 0.0051246 s
# Time for SIS: 7.51794 s
# Time for l0-norm: 0.0119735 s
# Train RMSE: 0.43248 Unitless
# c0 + a0 * ((O * rho) - (face-area-avg - E_T))
# Coefficients
# Task   a0                      c0
# all , -7.449893592450271e-01, -1.235328968693277e+01

# %% [raw]
# -12 - 0.74*(O*rho - face-area-avg) - 0.74*E/(kb*T)

# %%
a0 = -7.449893592450271e-01                 
c0 = -1.235328968693277e+01
fct = c0 + a0 * ((data['O'] * data['density']) - (data['face-area-avg'] - data['E_T']))
plt.scatter(fct, data['ln_D'])
plt.plot([-26,-15], [-26, -15], color = 'red')
plt.show()

# %%
plt.title('Test set')
a0 = -7.449893592450271e-01                 
c0 = -1.235328968693277e+01
fct_test = c0 + a0 * ((data_test['O'] * data_test['density']) - (data_test['face-area-avg'] - data_test['Ea']/(kb*300)))
plt.scatter(fct_test, data_test['logD'])
plt.plot([-26,-15], [-26, -15], color = 'red')
plt.show()

# %% [markdown]
# ## Without the activation energy

# %%
kb = constants.physical_constants['Boltzmann constant in eV/K'][0]
data = initialize(data_train)
lnDvsRest = pd.DataFrame({
    "sample_id": [f"s{j+1}" for j in range(len(data['ln_D']))], 
    "rho": data['density'],
    "AAV": data['AAV'],
    "PF": data['PF'],
    "VPA": data['VPA'],
    "NBI": data['NBI'],
    "SBI": data['SBI'],
    "RBI": data['RBI'],
    "WE": data['WE'],
    "B": data['B'],
    "N": data['N'],
    "S": data['S'],
    "O": data['O'],
    "F": data['F'],
    "Na": data['Na'],
    "Al": data['Al'],
    "Si": data['Si'],
    "P": data['P'],
    "Cl": data['Cl'],
    "Ge": data['Ge'],
    "Br": data['Br'],
    "I": data['I'],

    # Volume
    "cub_root_V" : data['V']**(1/3),
    
    # Na–Na distances
    "Na-Na": data['Na-Na'],
    "Na-Na-max": data['Na-Na-max'],
    "Na-Na-avg": data['Na-Na-avg'],

    # Bottleneck descriptors
    "bottleneck_min": data['bottleneck_min'],
    "bottleneck_avg": data['bottleneck_avg'],

    # Polyhedral distortion
    "poly_dist_max": data['poly_dist_max'],
    "poly_dist_std": data['poly_dist_std'],
    "poly_dist_avg": data['poly_dist_avg'],
    "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],

    # Voronoi face areas
    "face-area-max": data['face-area-max'],
    "face-area-avg": data['face-area-avg'],
    "face-area-min": data['face-area-min'],
    "face-area-count": data['face-area-count'],

    # Pockets
    "pockets-per-ion": data['pockets-per-ion'],
    "pockets-per-volume": data['pockets-per-volume'],

    # Paths
    "paths-per-ion": data['paths-per-ion'],
    "paths-per-volume": data['paths-per-volume'],

    # Target
    "ln_D": data['ln_D']
})

# %%
n_feat = 39
lnDvsRest.to_csv(f"/home/paolo/Thesis/Na/data/dataset2/Na_lndiff{n_feat}_noEa_temp300.csv", index=False)
data_file = f"/home/paolo/Thesis/Na/data/dataset2/Na_lndiff{n_feat}_noEa_temp300.csv"
os.environ["SISSOPP_TUT_DAT_FILE"] = data_file

# %%
# Try the fit with the exact functional form
rung = 2
Diff_json = {
    'data_file': data_file,
     'property_key': 'ln_D',
     'desc_dim': 1,
     'n_sis_select': 10,
     'max_rung': rung,
     'calc_type': 'regression',
     'min_abs_feat_val': 1e-05,
     'max_abs_feat_val': 1e8,
     'n_residual': 10,
     'n_models_store': 10,
     'leave_out_frac': 0.0,
     'leave_out_inds': [],
     'opset': ['exp', 'add', 'sub', 'mult', 'div', 'sin', 'cos']
}
json.dump(Diff_json, open(f"/home/paolo/Thesis/Na/data/dataset2/lndiff{n_feat}_{rung}_noEa.json", "w"), indent=4)

# %%
# Rung=2 Features=39 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA, 'NBI': NBI, 'SBI': SBI,  'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I, 'cub_root_V': V^(1/3),
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# Compiler flags: -O3 -march=native -fopenmp
# time input_parsing: 0.0571712 s
# Time to generate feat space: 143.835 s
# Projection time: 6.85295 s
# Time to get best features on rank : 0.0002197 s
# |---Complete final combination/selection from all ranks: 0.0095257 s
# Time for SIS: 9.99096 s
# Time for l0-norm: 0.0258624 s
# Train RMSE: 0.855589 Unitless
# c0 + a0 * ((face-area-avg + B) - (poly_dist_avg_fixed - SBI))
# Coefficients
# Task   a0                      c0
# all ,  3.070398253127043e+00, -2.924442473335629e+01,

# %%
a0 = 3.070398253127043e+00                
c0 = -2.924442473335629e+01
fct = c0 + a0 * ((data['face-area-avg'] + data['B']) - (data['poly_dist_avg_fixed'] - data['SBI']))
plt.scatter(fct, data['ln_D'])
plt.plot([-24,-15], [-24, -15], color = 'red')
plt.show()

# %% [markdown]
# ## Rung = 3

# %%
kb = constants.physical_constants['Boltzmann constant in eV/K'][0]
data = initialize(data_train)
lnDvsE = pd.DataFrame({
    "sample_id": [f"s{j+1}" for j in range(len(data['ln_D']))], 
    "AAV": data['AAV'],
    # Volume
    "cub_root_V" : data['V']**(1/3),
    # Na–Na distances
    #"Na-Na": data['Na-Na'],
    # Voronoi face areas
    "face-area-avg": data['face-area-avg'],
    "face-area-count": data['face-area-count'],

    # Target
    "ln_D": data['ln_D']
})

# %%
n_feat = 4
lnDvsE.to_csv(f"/home/paolo/Thesis/Na/data/dataset2/Na_lndiff{n_feat}_temp300.csv", index=False)
data_file = f"/home/paolo/Thesis/Na/data/dataset2/Na_lndiff{n_feat}_temp300.csv"
os.environ["SISSOPP_TUT_DAT_FILE"] = data_file

# %%
# Try the fit with the exact functional form
rung = 3
Diff_json = {
    'data_file': data_file,
     'property_key': 'ln_D',
     'desc_dim': 1,
     'n_sis_select': 10,
     'max_rung': rung,
     'calc_type': 'regression',
     'min_abs_feat_val': 1e-05,
     'max_abs_feat_val': 1e8,
     'n_residual': 10,
     'n_models_store': 10,
     'leave_out_frac': 0.0,
     'leave_out_inds': [],
     'opset': ['exp', 'add', 'sub', 'mult', 'div', 'sin', 'cos']
}
json.dump(Diff_json, open(f"/home/paolo/Thesis/Na/data/dataset2/lndiff{n_feat}_{rung}.json", "w"), indent=4)

# %%
# time input_parsing: 0.017609 s
# Time to generate feat space: 183.66 s
# Projection time: 10.2298 s
# Time to get best features on rank : 0.0004266 s
# |---Complete final combination/selection from all ranks: 0.0069417 s
# Time for SIS: 14.0847 s
# Time for l0-norm: 0.0221097 s
# Train RMSE: 0.947159 Unitless
# c0 + a0 * (((face-area-count + cub_root_V) - (face-area-avg - cub_root_V)) - (sin(face-area-avg) * cub_root_V))
# Coefficients
# Task   a0                      c0
# all ,  6.030587513372067e-02, -2.498790366170303e+01,

# %%
data = initialize(data_train)
a0 =  6.030587513372067e-02                
c0 = -2.498790366170303e+01
fct = c0 + a0 * (((data['face-area-count'] + data['V']**(1/3)) - (data['face-area-avg'] - data['V']**(1/3))) - (np.sin(data['face-area-avg']) * data['V']**(1/3)))
plt.scatter(fct, data['ln_D'])
plt.plot([-24,-15], [-24, -15], color = 'red')
plt.show()

# %% [markdown]
# # E vs Rest

# %%
kb = constants.physical_constants['Boltzmann constant in eV/K'][0]
data = initialize(data_train)
EvsRest = pd.DataFrame({
    "sample_id": [f"s{j+1}" for j in range(len(data['ln_D']))], 
    "rho": data['density'],
    "AAV": data['AAV'],
    "PF": data['PF'],
    "VPA": data['VPA'],
    "NBI": data['NBI'],
    "SBI": data['SBI'],
    "RBI": data['RBI'],
    "WE": data['WE'],
    "B": data['B'],
    "N": data['N'],
    "S": data['S'],
    "O": data['O'],
    "F": data['F'],
    "Na": data['Na'],
    "Al": data['Al'],
    "Si": data['Si'],
    "P": data['P'],
    "Cl": data['Cl'],
    "Ge": data['Ge'],
    "Br": data['Br'],
    "I": data['I'],

    # Volume
    "cub_root_V" : data['V']**(1/3),
    
    # Na–Na distances
    "Na-Na": data['Na-Na'],
    "Na-Na-max": data['Na-Na-max'],
    "Na-Na-avg": data['Na-Na-avg'],

    # Bottleneck descriptors
    "bottleneck_min": data['bottleneck_min'],
    "bottleneck_avg": data['bottleneck_avg'],

    # Polyhedral distortion
    "poly_dist_max": data['poly_dist_max'],
    "poly_dist_std": data['poly_dist_std'],
    "poly_dist_avg": data['poly_dist_avg'],
    "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],

    # Voronoi face areas
    "face-area-max": data['face-area-max'],
    "face-area-avg": data['face-area-avg'],
    "face-area-min": data['face-area-min'],
    "face-area-count": data['face-area-count'],

    # Pockets
    "pockets-per-ion": data['pockets-per-ion'],
    "pockets-per-volume": data['pockets-per-volume'],

    # Paths
    "paths-per-ion": data['paths-per-ion'],
    "paths-per-volume": data['paths-per-volume'],

    # Target
    "E": data['E'],
})

# %%
n_feat = 39
EvsRest.to_csv(f"/home/paolo/Thesis/Na/data/dataset2/Na_Ea{n_feat}_temp300.csv", index=False)
data_file = f"/home/paolo/Thesis/Na/data/dataset2/Na_Ea{n_feat}_temp300.csv"
os.environ["SISSOPP_TUT_DAT_FILE"] = data_file

# %%
# Try the fit with the exact functional form
rung = 2
Diff_json = {
    'data_file': data_file,
     'property_key': 'E',
     'desc_dim': 1,
     'n_sis_select': 10,
     'max_rung': rung,
     'calc_type': 'regression',
     'min_abs_feat_val': 1e-05,
     'max_abs_feat_val': 1e8,
     'n_residual': 10,
     'n_models_store': 10,
     'leave_out_frac': 0.0,
     'leave_out_inds': [],
     'opset': ['exp', 'add', 'sub', 'mult', 'div', 'sin', 'cos']
}
json.dump(Diff_json, open(f"/home/paolo/Thesis/Na/data/dataset2/Ea{n_feat}_{rung}.json", "w"), indent=4)

# %%
# Rung=2 Features=37 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA,  'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I, 'cub_root_V': V^(1/3),
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# time input_parsing: 0.0611894 s
# Time to generate feat space: 111.347 s
# Projection time: 5.26214 s
# Time to get best features on rank : 0.0001381 s
# |---Complete final combination/selection from all ranks: 0.0048374 s
# Time for SIS: 7.56676 s
# Time for l0-norm: 0.0133861 s
# Train RMSE: 0.0328392 Unitless
# c0 + a0 * ((cub_root_V / RBI) + (face-area-count + RBI))

# %%
# Rung=2 Features=39 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA, 'NBI': NBI, 'SBI': SBI, 'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I, 'cub_root_V': V^(1/3),
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# time input_parsing: 0.0601512 s
# Time to generate feat space: 147.711 s
# Projection time: 6.82075 s
# Time to get best features on rank : 0.000151 s
# |---Complete final combination/selection from all ranks: 0.0058549 s
# Time for SIS: 9.87095 s
# Time for l0-norm: 0.0074323 s
# Train RMSE: 0.0328392 Unitless
# c0 + a0 * ((cub_root_V / RBI) + (face-area-count + RBI))
# Coefficients
# Task   a0                      c0
# all , -3.411175386508987e-03,  4.867769019954426e-01,

# %%
a0 = -3.411175386508987e-03                
c0 = 4.867769019954426e-01
fct = c0 + a0 * ((data['V']**(1/3) / data['RBI']) + (data['face-area-count'] + data['RBI']))
plt.scatter(fct, data['E'])
plt.plot([0.20, 0.45], [0.20, 0.45], color = 'red')
plt.show()

# %%
# Rung=2 Features=36 'rho': density, 'AAV': AAV, 'PF': PF, 'VPA': VPA,  'RBI': RBI, 'WE': WE, 
        # 'B': B, 'N': N, 'S': S, 'O': O, 'F': F, 'Na': Na, 'Al': Al, 'Si': Si, 'P': P, 'Cl': Cl, 'Ge': Ge, 'Br': Br, 'I': I,
        # "Na-Na": data['Na-Na'], "Na-Na-max": data['Na-Na-max'], "Na-Na-avg": data['Na-Na-avg'], "bottleneck_min": data['bottleneck_min'], "bottleneck_avg": data['bottleneck_avg'],
        # "poly_dist_max": data['poly_dist_max'], "poly_dist_std": data['poly_dist_std'], "poly_dist_avg": data['poly_dist_avg'], "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],
        # "face-area-max": data['face-area-max'], "face-area-avg": data['face-area-avg'], "face-area-min": data['face-area-min'], "face-area-count": data['face-area-count'],
        # "pockets-per-ion": data['pockets-per-ion'], "pockets-per-volume": data['pockets-per-volume'],
        # "paths-per-ion": data['paths-per-ion'], "paths-per-volume": data['paths-per-volume'],
# time input_parsing: 0.054325 s
# Time to generate feat space: 93.1427 s
# Projection time: 4.62249 s
# Time to get best features on rank : 0.0001297 s
# |---Complete final combination/selection from all ranks: 0.0041506 s
# Time for SIS: 6.60356 s
# Time for l0-norm: 0.004707 s
# Train RMSE: 0.0330768 Unitless
# c0 + a0 * ((poly_dist_avg * RBI) - (face-area-avg + O))
# Coefficients
# Task   a0                      c0
# all ,  5.964844755407479e-02,  4.856457965869230e-01,

# %% [raw]
# 0.5 + 0.06* ((poly_dist_avg * RBI) - (face-area-avg + O))

# %%
a0 = 5.964844755407479e-02                 
c0 = 4.856457965869230e-01
fct = c0 + a0 * ((data['poly_dist_avg'] * data['RBI']) - (data['face-area-avg'] + data['O']))
plt.scatter(fct, data['E'])
plt.plot([0.20, 0.45], [0.20, 0.45], color = 'red')
plt.show()

# %%
plt.title('Test set')
a0 = 5.964844755407479e-02                 
c0 = 4.856457965869230e-01
fct_test = c0 + a0 * ((data_test['poly_dist_avg'] * data_test['RBI']) - (data_test['face-area-avg'] + data_test['O']))
plt.scatter(fct_test, data_test['Ea'])
plt.plot([0.20, 0.45], [0.20, 0.45], color = 'red')
plt.show()

# %%
# c0 + a0 * ((O * rho) - (face-area-avg - E_T))
# c0 + a0 * ((poly_dist_avg * RBI) - (face-area-avg + O))

# %%
# c0 + a0 * ((cub_root_V / RBI) + (face-area-count + RBI))
# Coefficients
# Task   a0                      c0
# all , -3.411175386508987e-03,  4.867769019954426e-01,

# %%
def E_best(data):
    a0 = 5.964844755407479e-02                 
    c0 = 4.856457965869230e-01
    return(c0 + a0 * ((data['poly_dist_avg'] * data['RBI']) - (data['face-area-avg'] + data['O'])))

# %%
plt.title('Best function for ln_D with best function for E')
a0 = -7.449893592450271e-01                 
c0 = -1.235328968693277e+01
data = initialize(data_train)
fct = c0 + a0 * ((data['O'] * data['density']) - (data['face-area-avg'] - E_best(data_train)/(kb*300)))
plt.scatter(fct, data['ln_D'])
plt.plot([-24,-15], [-24, -15], color = 'red')
plt.show()

# %%
plt.title('Test set')
a0 = -7.449893592450271e-01                 
c0 = -1.235328968693277e+01
fct_test = c0 + a0 * ((data_test['O'] * data_test['density']) - (data_test['face-area-avg'] - E_best(data_test)/(kb*300)))
plt.scatter(fct_test, data_test['logD'])
plt.plot([-24,-15], [-24, -15], color = 'red')
plt.show()

# %%
def E_best_V2(data):
    a0 = -3.411175386508987e-03               
    c0 = 4.867769019954426e-01
    return(c0 + a0 * ((data['volume']**(1/3) / data['RBI']) + (data['face-area-count'] + data['RBI'])))

# %%
plt.title('Best function for ln_D with best function for E V2')
a0 = -7.449893592450271e-01                 
c0 = -1.235328968693277e+01
data = initialize(data_train)
fct2 = c0 + a0 * ((data['O'] * data['density']) - (data['face-area-avg'] - E_best_V2(data_train)/(kb*300)))
fct = c0 + a0 * ((data['O'] * data['density']) - (data['face-area-avg'] - E_best(data_train)/(kb*300)))
plt.scatter(fct2, data['ln_D'])
#plt.scatter(fct, data['ln_D'], alpha = 0.5, color = 'orange')
plt.plot([-24,-15], [-24, -15], color = 'red')
plt.show()

# %%
plt.title('Test set')
a0 = -7.449893592450271e-01                 
c0 = -1.235328968693277e+01
fct_test = c0 + a0 * ((data_test['O'] * data_test['density']) - (data_test['face-area-avg'] - E_best_V2(data_test)/(kb*300)))
plt.scatter(fct_test, data_test['logD'])
plt.plot([-24,-15], [-24, -15], color = 'red')
plt.show()

# %% [markdown]
# # E/T vs Rest

# %%
kb = constants.physical_constants['Boltzmann constant in eV/K'][0]
data = initialize(data_train)
E_TvsRest = pd.DataFrame({
    "sample_id": [f"s{j+1}" for j in range(len(data['ln_D']))], 
    "rho": data['density'],
    "AAV": data['AAV'],
    "PF": data['PF'],
    "VPA": data['VPA'],
    "RBI": data['RBI'],
    "WE": data['WE'],
    "B": data['B'],
    "N": data['N'],
    "S": data['S'],
    "O": data['O'],
    "F": data['F'],
    "Na": data['Na'],
    "Al": data['Al'],
    "Si": data['Si'],
    "P": data['P'],
    "Cl": data['Cl'],
    "Ge": data['Ge'],
    "Br": data['Br'],
    "I": data['I'],
    # Na–Na distances
    "Na-Na": data['Na-Na'],
    "Na-Na-max": data['Na-Na-max'],
    "Na-Na-avg": data['Na-Na-avg'],

    # Bottleneck descriptors
    "bottleneck_min": data['bottleneck_min'],
    "bottleneck_avg": data['bottleneck_avg'],

    # Polyhedral distortion
    "poly_dist_max": data['poly_dist_max'],
    "poly_dist_std": data['poly_dist_std'],
    "poly_dist_avg": data['poly_dist_avg'],
    "poly_dist_avg_fixed": data['poly_dist_avg_fixed'],

    # Voronoi face areas
    "face-area-max": data['face-area-max'],
    "face-area-avg": data['face-area-avg'],
    "face-area-min": data['face-area-min'],
    "face-area-count": data['face-area-count'],

    # Pockets
    "pockets-per-ion": data['pockets-per-ion'],
    "pockets-per-volume": data['pockets-per-volume'],

    # Paths
    "paths-per-ion": data['paths-per-ion'],
    "paths-per-volume": data['paths-per-volume'],

    # Target
    "E_T": data['E_T'],
})

# %%
n_feat = 36
E_TvsRest.to_csv(f"/home/paolo/Thesis/Na/data/dataset2/Na_Ea_T{n_feat}_temp300.csv", index=False)
data_file = f"/home/paolo/Thesis/Na/data/dataset2/Na_Ea_T{n_feat}_temp300.csv"
os.environ["SISSOPP_TUT_DAT_FILE"] = data_file

# %%
# Try the fit with the exact functional form
rung = 2
Diff_json = {
    'data_file': data_file,
     'property_key': 'E_T',
     'desc_dim': 1,
     'n_sis_select': 10,
     'max_rung': rung,
     'calc_type': 'regression',
     'min_abs_feat_val': 1e-05,
     'max_abs_feat_val': 1e8,
     'n_residual': 10,
     'n_models_store': 10,
     'leave_out_frac': 0.0,
     'leave_out_inds': [],
     'opset': ['exp', 'add', 'sub', 'mult', 'div', 'sin', 'cos']
}
json.dump(Diff_json, open(f"/home/paolo/Thesis/Na/data/dataset2/Ea_T{n_feat}_{rung}.json", "w"), indent=4)

# %%
# time input_parsing: 0.0561885 s
# Time to generate feat space: 96.24 s
# Projection time: 4.77915 s
# Time to get best features on rank : 0.0001341 s
# |---Complete final combination/selection from all ranks: 0.006825 s
# Time for SIS: 6.75631 s
# Time for l0-norm: 0.0053839 s
# Train RMSE: 1.27947 Unitless
# c0 + a0 * ((poly_dist_avg * RBI) - (face-area-avg + O))
# Coefficients
# Task   a0                      c0
# all ,  2.307304968584173e+00,  1.878561815747506e+01,
