# %%
import pandas as pd
import numpy as np
import os
import json
from scipy import constants
from pysr import PySRRegressor
import matplotlib.pyplot as plt
import sympy
import random
# Out:
# /home/paolo/.conda/envs/pymc_env/lib/python3.12/site-packages/numpy/_core/getlimits.py:552: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
df = pd.read_pickle('/home/paolo/Na_dataset/diffusion.pckl.gzip', compression='gzip')
# Out:
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data

# %%
df
# Out:
#                                               structure  \
# 0     [[-40.55755644 -31.11690268 -12.78408373] Na, ...
# 1     [[-27.22272146 -48.08938883  -1.16173696] Na, ...
# 2     [[ -8.75124573 -35.84817417   1.41113688] Na, ...
# 3     [[  5.90065301 -22.92956849  38.91278713] Na, ...
# 4     [[-19.7964428  -12.94618545 -22.08417706] Na, ...
# ...                                                 ...
# 1299  [[-45.16852818 -78.13919154  20.16465523] Na, ...
# 1300  [[ 27.78664333 -31.36783786 -24.2354884 ] Na, ...
# 1301  [[  9.75765064 -22.01865729  14.7129202 ] Na, ...
# 1302  [[-39.37930038 -62.24010789 -38.49384248] Na, ...
# 1303  [[61.36195649 26.40706594 11.45059182] Na, [-1...
#
#                                                   atoms  \
# 0     (Atom('Na', [np.float64(-40.557556437030854), ...
# 1     (Atom('Na', [np.float64(-27.222721459416434), ...
# 2     (Atom('Na', [np.float64(-8.751245728991412), n...
# 3     (Atom('Na', [np.float64(5.900653007410151), np...
# 4     (Atom('Na', [np.float64(-19.79644280037215), n...
# ...                                                 ...
# 1299  (Atom('Na', [np.float64(-45.16852817712178), n...
# 1300  (Atom('Na', [np.float64(27.786643333402175), n...
# 1301  (Atom('Na', [np.float64(9.757650639408531), np...
# 1302  (Atom('Na', [np.float64(-39.37930038383808), n...
# 1303  (Atom('Na', [np.float64(61.36195649190371), np...
#
#                                                   D_sim D_300K        Ea  \
# 0     [1.4364625631071203e-07, 1.951308390440328e-06...    0.0   0.41481
# 1     [5.260053344200803e-08, 4.0005952618958283e-07...    0.0  0.342211
# 2     [4.1491531541234836e-07, 2.9527838854461532e-0...    0.0  0.309818
# 3     [3.644390884127098e-07, 2.282692400171146e-06,...    0.0  0.336138
# 4     [6.07698230883191e-08, 2.0869815246937256e-07,...    0.0  0.364908
# ...                                                 ...    ...       ...
# 1299  [3.297906167882209e-06, 1.8844573960753516e-05...    0.0  0.247734
# 1300  [9.156914520012137e-07, 5.1272087089512735e-06...    0.0  0.283584
# 1301  [1.8383356363262403e-07, 1.3151544777712655e-0...    0.0  0.326622
# 1302  [8.887014627167615e-07, 6.4231800149440465e-06...    0.0  0.297862
# 1303  [1.8081455456545138e-06, 1.2636043878082315e-0...    0.0  0.287596
#
#             D0         r                                          D_sim_std  \
# 0    -6.168029 -0.999534  [2.0609274977491014e-08, 9.54751980775219e-08,...
# 1    -8.892149 -0.998229  [1.170380927951024e-08, 3.5028882907097395e-08...
# 2    -7.538836 -0.999465  [4.712111654890927e-08, 1.5290730622277523e-07...
# 3    -7.142088 -0.995077  [2.3186241807603783e-08, 7.300603522025543e-08...
# 4    -8.508542 -0.964053  [1.548478587054459e-08, 3.1640692055019905e-08...
# ...        ...       ...                                                ...
# 1299 -6.836898 -0.999179  [9.792967224616881e-08, 3.9756638417401317e-07...
# 1300 -7.370918 -0.998882  [4.870329640437488e-08, 1.4125831290277235e-07...
# 1301 -7.991634 -0.998646  [1.634566553839534e-08, 5.978999364457793e-08,...
# 1302 -7.015121 -0.999876  [4.980311200542334e-08, 2.1804315739470145e-07...
# 1303 -6.535072 -0.999914  [7.803221965697771e-08, 3.4761268815546753e-07...
#
#                                         atoms_diffusion  \
# 0     [(Atom('Na', [np.float64(16.4013), np.float64(...
# 1     [(Atom('Na', [np.float64(22.3934), np.float64(...
# 2     [(Atom('Na', [np.float64(21.1725), np.float64(...
# 3     [(Atom('Na', [np.float64(6.08525), np.float64(...
# 4     [(Atom('Na', [np.float64(3.56707), np.float64(...
# ...                                                 ...
# 1299  [(Atom('Na', [np.float64(21.5008), np.float64(...
# 1300  [(Atom('Na', [np.float64(-1.42491), np.float64...
# 1301  [(Atom('Na', [np.float64(10.255), np.float64(6...
# 1302  [(Atom('Na', [np.float64(22.5873), np.float64(...
# 1303  [(Atom('Na', [np.float64(27.1031), np.float64(...
#
#             diffusion_temps  ...        VPA       NBI        RBI  \
# 0     [500, 700, 900, 1100]  ...  30.092044  0.672310   3.270586
# 1     [500, 700, 900, 1100]  ...  28.802260  0.534658   1.160079
# 2     [500, 700, 900, 1100]  ...  41.988188  0.418590   3.717974
# 3     [500, 700, 900, 1100]  ...  44.180268  0.459960  12.327698
# 4     [500, 700, 900, 1100]  ...  21.846223  0.603340   1.635307
# ...                     ...  ...        ...       ...        ...
# 1299  [500, 700, 900, 1100]  ...  51.279798  0.503579   9.309462
# 1300  [500, 700, 900, 1100]  ...  47.672488  0.587851   2.941818
# 1301  [500, 700, 900, 1100]  ...  42.832632  0.457983   1.896230
# 1302  [500, 700, 900, 1100]  ...  39.816525  0.617591   3.275683
# 1303  [500, 700, 900, 1100]  ...  47.612967  0.474949   5.485492
#
#       weighted_electronegativity         FV  Na_spacing  Na_former_ratio  \
# 0                       2.779514  16.271870    5.009553         0.818182
# 1                       2.334804   9.578810    4.023160         0.851852
# 2                       2.110441  16.853349    4.911786         0.818182
# 3                       1.925347  13.252481    3.934283         2.846154
# 4                       2.640404   9.327898    4.334335         0.492537
# ...                          ...        ...         ...              ...
# 1299                    2.179317  22.017312    4.934985         1.828571
# 1300                    2.144747  15.234442    3.981873         2.846154
# 1301                    1.958541  11.402734    3.826133         1.857143
# 1302                    2.479636  17.560774    4.693355         1.357143
# 1303                    2.218916  20.650191    5.227357         1.020408
#
#       Na_anion_ratio  log_conductivity       logD
# 0           0.239362         -6.802830 -22.213615
# 1           0.442308         -6.060846 -22.129469
# 2           0.387931         -4.053234 -19.523147
# 3           0.725490         -4.008862 -20.144502
# 4           0.268293         -6.778690 -22.623812
# ...              ...               ...        ...
# 1299        0.426667         -0.963887 -16.419663
# 1300        0.755102         -2.240883 -18.340452
# 1301        0.764706         -4.406686 -20.625948
# 1302        0.385135         -2.930568 -18.536951
# 1303        0.333333         -2.376655 -17.659764
#
# [1302 rows x 39 columns]
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data

# %%
df.columns
# Out:
# Index(['structure', 'atoms', 'D_sim', 'D_300K', 'Ea', 'D0', 'r', 'D_sim_std',
#        'atoms_diffusion', 'diffusion_temps', 'formula', 'composition', 'B%',
#        'N%', 'O%', 'F%', 'Na%', 'Al%', 'Si%', 'P%', 'S%', 'Cl%', 'Ge%', 'Br%',
#        'I%', 'density', 'AAV', 'PF', 'SBI', 'VPA', 'NBI', 'RBI',
#        'weighted_electronegativity', 'FV', 'Na_spacing', 'Na_former_ratio',
#        'Na_anion_ratio', 'log_conductivity', 'logD'],
#       dtype='object')

# %%
kb = constants.physical_constants['Boltzmann constant in eV/K'][0]
kb
# Out:
# 8.617333262145179e-05

# %%
i = 0
D = np.array(df['D_sim'].str[i])[:500]
T = np.array(df['diffusion_temps'].str[i])[:500]
E = np.array(df['Ea'], dtype = 'float')[:500]/(kb*T)
D0 = np.array(df['D0'], dtype = 'float')[:500]

# %%
t_array = np.array(df['diffusion_temps'][0])
E0 = np.array(df['Ea'][0], dtype = 'float')/kb
plt.scatter(t_array , np.array(df['D_sim'][0]), alpha = 0.5)
plt.scatter(t_array , df['D0'][0]*np.exp(-E0/t_array))
plt.xlabel('T [K]')
plt.ylabel('D')
plt.show()

# %%
DvsE = pd.DataFrame({"sample_id": [f"s{i+1}" for i in range(len(D))], 'E/T': E, 'D': D})

# %%
DvsE.to_csv("/home/paolo/Thesis/Na/data/Na_diff.csv", index=False)
data_file = "/home/paolo/Thesis/Na/data/Na_diff.csv"
os.environ["SISSOPP_TUT_DAT_FILE"] = data_file

# %%
# Try the fit with the exact functional form
Diff_json = {
    'data_file': data_file,
     'property_key': 'D',
     'desc_dim': 1,
     'n_sis_select': 15,
     'max_rung': 2,
     'calc_type': 'regression',
     'min_abs_feat_val': 1e-05,
     'max_abs_feat_val': 1e8,
     'n_residual': 10,
     'n_models_store': 10,
     'leave_out_frac': 0.0,
     'leave_out_inds': [],
     'opset': ['exp', 'add', 'sub', 'mult', 'div', 'sin', 'cos']
}
json.dump(Diff_json, open("/home/paolo/Thesis/Na/data/diff.json", "w"), indent=4)

# %% [raw]
# # c0 + a0 * (E/T / exp(E/T))
# # Property Label: $D$; Unit of the Property: Unitless
# # RMSE: 4.99488372656817e-07; Max AE: 2.8212941087041e-06
# # Coefficients
# # Task   a0                      c0
# # all ,  1.704458640741253e-04, -1.390360191953970e-07,

# %%
opt_funct = 1.704458640741253e-04*E/np.exp(E) - 1.390360191953970e-07
worst_funct = 7.570330401562866e-07*np.cos(E) +  6.191808278717039e-07 
plt.scatter(E , D, alpha = 0.5, color = 'blue', label = 'D_sim vs E')
plt.scatter(E , worst_funct, color = 'cyan', label = 'SISSO worst function')
plt.scatter(E, opt_funct, label='SISSO optimal function', color = 'orange')
plt.xlabel(r'E\($k_B$T)')
plt.ylabel('D')
plt.legend()
plt.show()

# %%
plt.scatter(E , D, alpha = 0.5, color = 'blue', label = 'D_sim vs E')
plt.scatter(E , D0*np.exp(-E), color = 'red', label = 'Arrhenius formula vs E')
plt.xlabel(r'E\($k_B$T)')
plt.ylabel('D')
plt.legend()
plt.show()

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %%
model = PySRRegressor(
    niterations=500,
    populations=50,
    binary_operators=["+", "*", "/", "-"],
    unary_operators=["square", "cos", "sin", "exp"],
    maxdepth = 2,
    #maxsize = 100
)
model.fit(E.reshape(-1, 1), D, variable_names=["E_T"])
# Out:
# /home/paolo/.conda/envs/pymc_env/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 4.090e+05
# Progress: 4637 / 25000 total iterations (18.548%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2973e-07
# 3           6.519e-13  7.837e-02  y = 5.4301e-06 / E_T
# 4           2.394e-13  1.002e+00  y = 0.00097795 / exp(E_T)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.280e+05
# Progress: 9128 / 25000 total iterations (36.512%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2973e-07
# 3           6.519e-13  7.837e-02  y = 5.4301e-06 / E_T
# 4           2.394e-13  1.002e+00  y = 0.00097795 / exp(E_T)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+05
# Progress: 13658 / 25000 total iterations (54.632%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2973e-07
# 3           6.519e-13  7.837e-02  y = 5.4301e-06 / E_T
# 4           2.394e-13  1.002e+00  y = 0.00097795 / exp(E_T)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.420e+05
# Progress: 18407 / 25000 total iterations (73.628%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2973e-07
# 3           6.519e-13  7.837e-02  y = 5.4301e-06 / E_T
# 4           2.394e-13  1.002e+00  y = 0.00097795 / exp(E_T)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.950e+05
# Progress: 22976 / 25000 total iterations (91.904%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2973e-07
# 3           6.519e-13  7.837e-02  y = 5.4301e-06 / E_T
# 4           2.394e-13  1.002e+00  y = 0.00097795 / exp(E_T)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2973e-07
# 3           6.519e-13  7.837e-02  y = 5.4301e-06 / E_T
# 4           2.394e-13  1.002e+00  y = 0.00097795 / exp(E_T)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick     score                equation          loss  complexity
# 	0        0.000000             6.297296e-7  7.624840e-13           1
# 	1        0.078370        5.43012e-6 / E_T  6.518678e-13           3
# 	2  >>>>  1.001617  0.000977952 / exp(E_T)  2.394212e-13           4
# ]
#   - outputs/20251216_093102_ezbRUK/hall_of_fame.csv

# %%
model.sympy()
# Out:
# 0.000977952/exp(E_T)

# %%
Ea = np.array(df['Ea'], dtype = 'float')[:500]
# SEED = 42
# np.random.seed(SEED)
# random.seed(SEED)
model2 = PySRRegressor(
    niterations=300,
    populations=50,
    binary_operators=["+", "*", "/", "-"],
    unary_operators=["cos", "sin", "exp"],
    maxdepth = 10,
    #maxsize = 100
)
model2.fit(Ea.reshape(-1, 1), D, variable_names=["Ea"])
# Out:
# /home/paolo/.conda/envs/pymc_env/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.300e+05
# Progress: 1426 / 15000 total iterations (9.507%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2962e-07
# 3           6.519e-13  7.837e-02  y = 2.3394e-07 / Ea
# 5           3.416e-13  3.231e-01  y = (1.5663e-06 / Ea) + -4.0929e-06
# 6           2.864e-13  1.763e-01  y = 0.00017359 / exp(Ea / 0.058201)
# 7           2.511e-13  1.313e-01  y = (2.4429e-07 / (Ea + -0.18899)) - 1.2101e-06
# 8           2.380e-13  5.383e-02  y = (-2.3199e-05 / exp(Ea / 0.041618)) / -0.019046
# 12          2.369e-13  1.119e-03  y = (-0.00018945 / (Ea / (-0.072474 / Ea))) / exp(Ea / 0.0...
#                                       58201)
# 14          2.367e-13  4.168e-04  y = ((-0.00018945 / (Ea / -0.072474)) / (exp(Ea / 0.058201...
#                                       ) - 1.0385)) / Ea
# 16          2.367e-13  9.447e-06  y = ((9.5979e-05 * (-1.9738 / (Ea / -0.072474))) / (exp(Ea...
#                                        / 0.058201) - 1.2062)) / Ea
# 18          2.356e-13  2.414e-03  y = ((((1.8646e-05 / exp(Ea / 0.058201)) * ((-0.45031 / Ea...
#                                       ) / Ea)) - Ea) + Ea) / -0.6046
# 25          2.344e-13  6.931e-04  y = sin(9.5979e-05 / ((Ea / (-0.072474 / (Ea / -1.9738))) ...
#                                       * ((Ea / (((Ea / -1.9738) / -0.072474) + -2.0463)) + exp(E...
#                                       a / 0.058201))))
# 27          2.342e-13  5.290e-04  y = sin(9.5979e-05 / (((Ea * 0.31803) / (((Ea / -1.9738) /...
#                                        -0.072474) + -2.0463)) + ((exp(Ea / 0.058201) * Ea) / (-0...
#                                       .072474 / (Ea / -1.9738)))))
# 30          2.342e-13  6.557e-07  y = sin(9.5979e-05 / (((Ea / (-0.072474 / (Ea / -1.9738)))...
#                                        * exp(Ea / 0.058201)) + (sin(0.3828) * (Ea / ((-0.072474 ...
#                                       + ((Ea / -1.9738) / -0.072474)) + -1.9738)))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.500e+05
# Progress: 3157 / 15000 total iterations (21.047%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2962e-07
# 3           6.519e-13  7.837e-02  y = 2.3394e-07 / Ea
# 5           3.416e-13  3.231e-01  y = (1.5663e-06 / Ea) + -4.0929e-06
# 6           2.864e-13  1.763e-01  y = 0.00017359 / exp(Ea / 0.058201)
# 7           2.509e-13  1.322e-01  y = (2.4099e-07 / (Ea + -0.1892)) - 1.1864e-06
# 8           2.372e-13  5.615e-02  y = (0.00014222 / exp(Ea / 0.04765)) / Ea
# 9           2.371e-13  4.106e-04  y = (0.00014222 / exp(Ea / 0.04765)) / sin(Ea)
# 10          2.367e-13  1.782e-03  y = (1.5212e-05 / (Ea * Ea)) / exp(Ea / 0.057027)
# 11          2.367e-13  5.126e-06  y = (1.5212e-05 / sin(Ea * Ea)) / exp(Ea / 0.057027)
# 14          2.363e-13  6.053e-04  y = (((2.0279e-05 / (Ea * Ea)) / 0.88848) / exp(Ea / 0.052...
#                                       068)) + 5.7276e-08
# 16          2.356e-13  1.482e-03  y = (Ea + ((((-8.3967e-06 / Ea) / exp(Ea / 0.058201)) / Ea...
#                                       ) - Ea)) / -0.60563
# 18          2.345e-13  2.154e-03  y = 1.6766 * ((Ea - ((((-1.0969e-06 / Ea) / exp(Ea / 0.068...
#                                       577)) / Ea) + Ea)) / Ea)
# 23          2.342e-13  2.925e-04  y = sin(9.5979e-05 / ((Ea / (-0.072474 / (Ea / -1.9738))) ...
#                                       * (exp(Ea / 0.058201) + (0.14492 / ((Ea / 0.14305) + -2.04...
#                                       63)))))
# 24          2.331e-13  4.668e-03  y = sin(9.5979e-05 / ((sin((-2.1447 / (Ea * Ea)) / Ea) + (...
#                                       exp(Ea / 0.058201) * Ea)) / (-0.072474 / (Ea / -1.9738))))
# 25          2.326e-13  2.127e-03  y = sin(9.5979e-05 / ((cos((-2.1447 / (sin(Ea) * Ea)) / Ea...
#                                       ) + (Ea * exp(Ea / 0.058201))) / (-0.072474 / (Ea / -1.973...
#                                       8))))
# 26          2.317e-13  3.808e-03  y = sin(9.5979e-05 / ((sin(((-2.1447 / (Ea * Ea)) / Ea) + ...
#                                       0.69236) + (exp(Ea / 0.058201) * Ea)) / (-0.072474 / (Ea /...
#                                        -1.9738))))
# 27          2.317e-13  1.156e-05  y = sin(9.5979e-05 / ((sin(((-2.1447 / (Ea * Ea)) / Ea) + ...
#                                       sin(0.70032)) + (exp(Ea / 0.058201) * Ea)) / (-0.072474 / ...
#                                       (Ea / -1.9738))))
# 28          2.274e-13  1.872e-02  y = sin(9.5979e-05 / (((Ea / (-0.072474 / (Ea / -1.9738)))...
#                                        * exp(Ea / 0.058201)) + (sin(-20565 / ((Ea / -0.072474) /...
#                                        -20566)) / (0.058201 / Ea))))
# 30          2.228e-13  1.032e-02  y = sin(9.5979e-05 / ((Ea / sin((((Ea + Ea) / (Ea * Ea)) /...
#                                        -0.072474) + -2.0463)) + ((Ea / (-0.072474 / (Ea / -1.973...
#                                       8))) * exp(Ea / 0.058201))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.580e+05
# Progress: 4943 / 15000 total iterations (32.953%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2962e-07
# 3           6.519e-13  7.837e-02  y = 2.3394e-07 / Ea
# 5           3.416e-13  3.231e-01  y = (1.5663e-06 / Ea) + -4.0929e-06
# 6           2.864e-13  1.763e-01  y = 0.00017359 / exp(Ea / 0.058201)
# 7           2.509e-13  1.322e-01  y = (2.4099e-07 / (Ea + -0.1892)) - 1.1864e-06
# 8           2.372e-13  5.615e-02  y = (0.00014222 / exp(Ea / 0.04765)) / Ea
# 9           2.371e-13  4.106e-04  y = (0.00014222 / exp(Ea / 0.04765)) / sin(Ea)
# 10          2.367e-13  1.782e-03  y = (1.5212e-05 / (Ea * Ea)) / exp(Ea / 0.057027)
# 11          2.367e-13  6.640e-05  y = ((1.6192e-05 / exp(Ea / 0.056121)) / Ea) / sin(Ea)
# 12          2.366e-13  4.255e-04  y = sin((1.7293e-05 / (Ea * Ea)) / exp(sin(Ea) / 0.054803)...
#                                       )
# 13          2.365e-13  2.604e-04  y = ((1.7726e-06 / (Ea * Ea)) / exp(Ea / 0.068992)) / sin(...
#                                       Ea)
# 14          2.363e-13  1.069e-03  y = (((2.028e-05 / (Ea * Ea)) / 0.88848) / exp(Ea / 0.0520...
#                                       68)) + 5.7022e-08
# 15          2.363e-13  2.503e-06  y = (((2.0279e-05 / sin(Ea * Ea)) / 0.88848) / exp(Ea / 0....
#                                       052068)) + 5.7276e-08
# 16          2.356e-13  2.961e-03  y = (Ea + ((((-8.3967e-06 / Ea) / exp(Ea / 0.058201)) / Ea...
#                                       ) - Ea)) / -0.60563
# 18          2.345e-13  2.154e-03  y = 1.6766 * ((Ea - ((((-1.0969e-06 / Ea) / exp(Ea / 0.068...
#                                       577)) / Ea) + Ea)) / Ea)
# 21          2.316e-13  4.227e-03  y = sin(sin(1.1303e-05 / (((exp(Ea / 0.058201) * Ea) + sin...
#                                       (Ea * -20566)) / (-0.61049 / (Ea / -1.9738)))))
# 23          2.292e-13  5.158e-03  y = sin(sin(1.1303e-05 / (((exp(Ea / 0.058201) * Ea) + (1....
#                                       5821 * sin(Ea * -20566))) / (-0.61049 / (Ea / -1.9738)))))
# 24          2.267e-13  1.113e-02  y = sin(1.1303e-05 / (((exp(Ea / 0.058201) * Ea) + ((Ea / ...
#                                       0.057027) * sin(Ea * -20566))) / (-0.61049 / (Ea / -1.9738...
#                                       ))))
# 26          2.217e-13  1.107e-02  y = sin(1.1303e-05 / (((exp(Ea / 0.058201) * Ea) / (-0.610...
#                                       49 / (Ea / -1.9738))) + sin((Ea / ((Ea / Ea) / -20565)) + ...
#                                       -0.63536)))
# 29          2.217e-13  1.729e-06  y = sin(1.1303e-05 / (((exp(Ea / 0.058201) * Ea) / (-0.610...
#                                       49 / (Ea / -1.9738))) + sin((Ea / ((Ea / Ea) / -20565)) + ...
#                                       (0.29391 - cos(-0.36086)))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+05
# Progress: 6647 / 15000 total iterations (44.313%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2962e-07
# 3           6.519e-13  7.837e-02  y = 2.3394e-07 / Ea
# 5           3.416e-13  3.231e-01  y = (1.5663e-06 / Ea) + -4.0929e-06
# 6           2.836e-13  1.861e-01  y = 0.00018511 / exp(Ea / 0.057425)
# 7           2.509e-13  1.224e-01  y = (2.4099e-07 / (Ea + -0.1892)) - 1.1864e-06
# 8           2.372e-13  5.615e-02  y = (0.00014222 / exp(Ea / 0.04765)) / Ea
# 9           2.371e-13  4.106e-04  y = (0.00014222 / exp(Ea / 0.04765)) / sin(Ea)
# 10          2.367e-13  1.782e-03  y = (1.5212e-05 / (Ea * Ea)) / exp(Ea / 0.057027)
# 11          2.366e-13  4.920e-04  y = (1.7293e-05 / (Ea * Ea)) / exp(sin(Ea) / 0.054803)
# 12          2.366e-13  4.375e-05  y = ((1.7584e-05 / Ea) / exp(sin(Ea) / 0.054478)) / sin(Ea...
#                                       )
# 13          2.364e-13  5.294e-04  y = sin(((1.6391e-06 / Ea) / (Ea * Ea)) / exp(Ea / 0.07065...
#                                       ))
# 14          2.363e-13  7.561e-04  y = (((2.028e-05 / (Ea * Ea)) / 0.88848) / exp(Ea / 0.0520...
#                                       68)) + 5.7022e-08
# 15          2.363e-13  4.351e-06  y = 5.7022e-08 + (((2.028e-05 / sin(Ea * Ea)) / 0.88848) /...
#                                        exp(Ea / 0.052068))
# 16          2.356e-13  2.959e-03  y = (Ea + ((((-8.3967e-06 / Ea) / exp(Ea / 0.058201)) / Ea...
#                                       ) - Ea)) / -0.60563
# 18          2.345e-13  2.154e-03  y = 1.6766 * ((Ea - ((((-1.0969e-06 / Ea) / exp(Ea / 0.068...
#                                       577)) / Ea) + Ea)) / Ea)
# 20          2.247e-13  2.133e-02  y = sin(1.1303e-05 / ((((Ea * exp(Ea / 0.058201)) / (-0.61...
#                                       049 / Ea)) / -1.9738) + sin(Ea * -20567)))
# 21          2.241e-13  2.983e-03  y = sin(1.1303e-05 / ((((Ea * exp(Ea / 0.058201)) / (-0.61...
#                                       049 / Ea)) / -1.9738) + sin(sin(Ea * -20567))))
# 22          2.217e-13  1.083e-02  y = sin(1.1303e-05 / ((Ea * ((exp(Ea / 0.058201) / (-0.610...
#                                       49 / Ea)) / -1.9738)) + sin(-0.45824 + (Ea * -20566))))
# 23          2.217e-13  2.980e-06  y = sin(sin(1.1303e-05 / (sin((Ea * -20566) + -0.45544) + ...
#                                       (((exp(Ea / 0.058201) * Ea) / (-0.61049 / Ea)) / -1.9738))...
#                                       ))
# 26          2.215e-13  2.049e-04  y = sin(1.1303e-05 / ((sin((Ea * -1.7924) + (Ea * -20566))...
#                                        + -0.010702) + (((exp(Ea / 0.058201) / (-0.61049 / Ea)) /...
#                                        -1.9738) * Ea)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+05
# Progress: 8642 / 15000 total iterations (57.613%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2962e-07
# 3           6.519e-13  7.837e-02  y = 2.3394e-07 / Ea
# 5           3.333e-13  3.354e-01  y = 7.6998e-08 / (Ea + -0.21458)
# 6           2.698e-13  2.112e-01  y = 0.00035426 / exp(Ea / 0.052068)
# 7           2.509e-13  7.279e-02  y = (2.4099e-07 / (Ea + -0.1892)) - 1.1864e-06
# 8           2.372e-13  5.615e-02  y = (0.00014222 / exp(Ea / 0.04765)) / Ea
# 9           2.371e-13  4.106e-04  y = (0.00014222 / exp(Ea / 0.04765)) / sin(Ea)
# 10          2.367e-13  1.782e-03  y = (1.5212e-05 / (Ea * Ea)) / exp(Ea / 0.057027)
# 11          2.366e-13  4.920e-04  y = (1.7293e-05 / (Ea * Ea)) / exp(sin(Ea) / 0.054803)
# 12          2.364e-13  5.731e-04  y = (((1.6391e-06 / Ea) / Ea) / exp(Ea / 0.07065)) / Ea
# 13          2.364e-13  5.186e-06  y = (((1.6249e-06 / Ea) / Ea) / exp(Ea / 0.07065)) / sin(E...
#                                       a)
# 14          2.363e-13  7.509e-04  y = (((2.028e-05 / (Ea * Ea)) / 0.88848) / exp(Ea / 0.0520...
#                                       68)) + 5.7022e-08
# 15          2.363e-13  4.351e-06  y = 5.7022e-08 + (((2.028e-05 / sin(Ea * Ea)) / 0.88848) /...
#                                        exp(Ea / 0.052068))
# 16          2.356e-13  2.959e-03  y = (Ea + ((((-8.3967e-06 / Ea) / exp(Ea / 0.058201)) / Ea...
#                                       ) - Ea)) / -0.60563
# 18          2.345e-13  2.154e-03  y = 1.6766 * ((Ea - ((((-1.0969e-06 / Ea) / exp(Ea / 0.068...
#                                       577)) / Ea) + Ea)) / Ea)
# 19          2.247e-13  4.265e-02  y = 1.1303e-05 / (((exp(Ea / 0.058201) * (Ea / (-0.61049 /...
#                                        Ea))) / -1.9738) + sin(-20567 * Ea))
# 20          2.216e-13  1.423e-02  y = sin(1.1303e-05 / (sin(Ea * -20568) + (((exp(Ea / 0.058...
#                                       201) / (-0.61049 / Ea)) / -1.9738) * Ea)))
# 22          2.214e-13  4.049e-04  y = sin(1.1303e-05 / (sin(Ea * -20568) + (((exp(Ea / 0.058...
#                                       201) / (-0.61049 / Ea)) / (Ea + -2.2285)) * Ea)))
# 23          2.214e-13  4.053e-05  y = sin(1.1303e-05 / (sin(Ea * -20568) + (((exp(Ea / 0.058...
#                                       201) / (-0.61049 / Ea)) / (sin(Ea) + -2.2285)) * Ea)))
# 24          2.211e-13  1.311e-03  y = sin(1.1303e-05 / (((((exp(Ea / 0.058201) / (-0.60005 /...
#                                        Ea)) / -1.9738) * Ea) + sin(Ea * -20568)) - (0.28334 - Ea...
#                                       )))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.980e+05
# Progress: 10441 / 15000 total iterations (69.607%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2962e-07
# 3           6.519e-13  7.837e-02  y = 2.3394e-07 / Ea
# 5           3.333e-13  3.354e-01  y = 7.6998e-08 / (Ea + -0.21458)
# 6           2.608e-13  2.453e-01  y = 0.00035643 / exp(Ea * 19.785)
# 7           2.447e-13  6.385e-02  y = (1.6969e-07 / (Ea + -0.20363)) + -8.3943e-07
# 8           2.372e-13  3.102e-02  y = (0.00014222 / exp(Ea / 0.04765)) / Ea
# 9           2.371e-13  4.106e-04  y = (0.00014222 / exp(Ea / 0.04765)) / sin(Ea)
# 10          2.367e-13  1.782e-03  y = (1.5212e-05 / (Ea * Ea)) / exp(Ea / 0.057027)
# 11          2.366e-13  4.920e-04  y = (1.7293e-05 / (Ea * Ea)) / exp(sin(Ea) / 0.054803)
# 12          2.363e-13  1.327e-03  y = ((2.1098e-05 / (Ea * Ea)) / exp(Ea / 0.052882)) + 4.91...
#                                       24e-08
# 13          2.362e-13  4.649e-05  y = ((2.1098e-05 / (Ea * sin(Ea))) / exp(Ea / 0.052882)) +...
#                                        4.6445e-08
# 14          2.362e-13  6.598e-05  y = ((1.6284e-05 / (Ea * Ea)) / exp((Ea / 0.052882) + -0.2...
#                                       6382)) + 5.0215e-08
# 16          2.340e-13  4.650e-03  y = (Ea - ((((-1.3416e-06 / Ea) / exp(Ea / 0.074785)) / Ea...
#                                       ) + Ea)) / Ea
# 19          2.217e-13  1.801e-02  y = 1.1303e-05 / ((((Ea * exp(Ea / 0.058201)) / (-0.60005 ...
#                                       / Ea)) / -1.9738) + sin(Ea * -20568))
# 20          2.216e-13  7.165e-04  y = sin(1.1303e-05 / (sin(Ea * -20568) + (((exp(Ea / 0.058...
#                                       201) / (-0.61049 / Ea)) / -1.9738) * Ea)))
# 21          2.214e-13  8.098e-04  y = 1.1303e-05 / (((exp(Ea / 0.058201) / (-0.61049 / Ea)) ...
#                                       * (Ea / (Ea + -2.2285))) + sin(-20568 * Ea))
# 23          2.212e-13  4.760e-04  y = sin(1.1303e-05 / ((sin(Ea * -20568) - exp(-2.7935)) + ...
#                                       (((exp(Ea / 0.058201) / (-0.60005 / Ea)) / -1.9738) * Ea))...
#                                       )
# 24          2.211e-13  3.994e-04  y = sin(1.1303e-05 / (((((exp(Ea / 0.058201) / (-0.60005 /...
#                                        Ea)) / -1.9738) * Ea) + sin(Ea * -20568)) - (0.28334 - Ea...
#                                       )))
# 25          2.208e-13  1.503e-03  y = sin(1.1303e-05 / ((Ea * ((exp(Ea / 0.058201) / (-0.600...
#                                       05 / Ea)) / -1.9738)) + (sin(Ea * -20568) - cos(Ea - -1.21...
#                                       34))))
# 26          2.200e-13  3.606e-03  y = sin(1.1303e-05 / ((((exp(Ea / 0.058201) / (-0.60005 / ...
#                                       Ea)) / -1.9738) * Ea) + (sin(Ea * -20568) - ((0.28334 - Ea...
#                                       ) / Ea))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.990e+05
# Progress: 12290 / 15000 total iterations (81.933%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-13  0.000e+00  y = 6.2962e-07
# 3           6.519e-13  7.837e-02  y = 2.3394e-07 / Ea
# 5           3.333e-13  3.354e-01  y = 7.6998e-08 / (Ea + -0.21458)
# 6           2.608e-13  2.453e-01  y = 0.00035643 / exp(Ea * 19.785)
# 7           2.380e-13  9.143e-02  y = sin(0.0019561 / exp(Ea / 0.038825))
# 8           2.372e-13  3.444e-03  y = (0.00014222 / exp(Ea / 0.04765)) / Ea
# 9           2.371e-13  4.130e-04  y = (0.00014222 / exp(Ea / 0.047647)) / sin(Ea)
# 10          2.367e-13  1.780e-03  y = (1.5212e-05 / (Ea * Ea)) / exp(Ea / 0.057027)
# 11          2.366e-13  4.920e-04  y = (1.7293e-05 / (Ea * Ea)) / exp(sin(Ea) / 0.054803)
# 12          2.362e-13  1.354e-03  y = ((2.1098e-05 / (Ea * Ea)) / exp(Ea / 0.052882)) + 5.02...
#                                       15e-08
# 13          2.362e-13  2.867e-05  y = ((2.1098e-05 / sin(Ea * Ea)) / exp(Ea / 0.052882)) + 5...
#                                       .0215e-08
# 14          2.362e-13  5.669e-05  y = ((1.6284e-05 / (Ea * Ea)) / exp((Ea / 0.052882) + -0.2...
#                                       6382)) + 5.0215e-08
# 16          2.340e-13  4.650e-03  y = (Ea - ((((-1.3416e-06 / Ea) / exp(Ea / 0.074785)) / Ea...
#                                       ) + Ea)) / Ea
# 19          2.217e-13  1.801e-02  y = 1.1303e-05 / ((((Ea * exp(Ea / 0.058201)) / (-0.60005 ...
#                                       / Ea)) / -1.9738) + sin(Ea * -20568))
# 20          2.216e-13  7.165e-04  y = sin(1.1303e-05 / (sin(Ea * -20568) + (((exp(Ea / 0.058...
#                                       201) / (-0.61049 / Ea)) / -1.9738) * Ea)))
# 21          2.214e-13  8.098e-04  y = 1.1303e-05 / (((exp(Ea / 0.058201) / (-0.61049 / Ea)) ...
#                                       * (Ea / (Ea + -2.2285))) + sin(-20568 * Ea))
# 22          2.211e-13  1.356e-03  y = sin(1.1303e-05 / ((sin(Ea * -20568) - 0.13892) + (((ex...
#                                       p(Ea / 0.058201) / (-0.60005 / Ea)) / -1.9738) * Ea)))
# 24          2.210e-13  1.797e-04  y = sin(1.1303e-05 / ((sin(Ea * -20568) - (0.29327 - Ea)) ...
#                                       + (((exp(Ea / 0.058201) / (-0.60005 / Ea)) / -1.9738) * Ea...
#                                       )))
# 25          2.208e-13  1.139e-03  y = sin(1.1303e-05 / ((Ea * ((exp(Ea / 0.058201) / (-0.600...
#                                       05 / Ea)) / -1.9738)) + (sin(Ea * -20568) - cos(Ea - -1.21...
#                                       34))))
# 26          2.200e-13  3.606e-03  y = sin(1.1303e-05 / (((((Ea * exp(Ea / 0.058201)) / (-0.6...
#                                       0005 / Ea)) / -1.9738) + sin(Ea * -20568)) - ((0.28334 - E...
#                                       a) / Ea)))
# 28          2.193e-13  1.411e-03  y = sin(1.1303e-05 / ((((exp(Ea / 0.058201) / (-0.60005 / ...
#                                       Ea)) / -1.9738) * Ea) + (sin(Ea * -20568) - (((0.52624 - E...
#                                       a) - Ea) / Ea))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.930e+05
# Progress: 13744 / 15000 total iterations (91.627%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                        6.296226e-7
# 	1         7.836982e-02                                  2.3394387e-7 / Ea
# 	2         3.353803e-01                   7.699797e-8 / (Ea + -0.21458335)
# 	3   >>>>  3.368279e-01                 0.0019560584 / exp(Ea / 0.0388154)
# 	4         1.008421e-06            sin(0.0019560356 / exp(Ea / 0.0388154))
# 	5         6.082141e-03  (0.0018723569 / exp(Ea / 0.03881541)) + 4.8767...
# 	6         1.509195e-04  (0.0018723081 / (exp(Ea / 0.03881541) - 6.1503...
# 	7         5.351704e-04  ((2.1221058e-5 / (Ea * Ea)) / exp(Ea / 0.05288...
# 	8         7.196458e-06  ((2.100196e-5 / (Ea * sin(Ea))) / exp(Ea / 0.0...
# 	9         5.825089e-05  (((1.8864883e-6 / (Ea * Ea)) / exp(Ea / 0.0676...
# 	10        5.164970e-05  (((2.1339594e-5 / sin(Ea * Ea)) / exp(Ea / 0.0...
# 	11        9.182571e-03  (Ea - ((((-1.3416416e-6 / Ea) / exp(Ea / 0.074...
# 	12        1.800877e-02  1.13028655e-5 / ((((Ea * exp(Ea / 0.05820057))...
# 	13        7.164797e-04  sin(1.13028655e-5 / (sin(Ea * -20567.934) + ((...
# 	14        8.097647e-04  1.13028655e-5 / (((exp(Ea / 0.05820057) / (-0....
# 	15        4.119280e-03  sin(1.13028655e-5 / (((((Ea * exp(Ea / 0.05820...
# 	16        8.149023e-04  sin(1.13028655e-5 / (sin(Ea * -20568.031) + ((...
# 	17        2.018317e-04  sin(1.13028655e-5 / ((sin(sin(Ea) / (-0.561839...
# 	18        1.933992e-03  1.1157795e-5 / (((Ea * exp(Ea / 0.05820058)) /...
# 	19        2.274436e-08  (1.9423744e-5 / (((Ea * exp(Ea / 0.05820058)) ...
# 	20        2.212288e-03  sin(1.13028655e-5 / ((((exp(Ea / 0.05820057) /...
# 	21        8.667310e-05  sin(1.13028655e-5 / ((Ea * ((exp(Ea / 0.058200...
#
# 	            loss  complexity
# 	0   7.624840e-13           1
# 	1   6.518679e-13           3
# 	2   3.333128e-13           5
# 	3   2.379959e-13           6
# 	4   2.379957e-13           7
# 	5   2.365525e-13           8
# 	6   2.364811e-13          10
# 	7   2.362282e-13          12
# 	8   2.362265e-13          13
# 	9   2.362127e-13          14
# 	10  2.362005e-13          15
# 	11  2.340415e-13          16
# 	12  2.217326e-13          19
# 	13  2.215738e-13          20
# 	14  2.213944e-13          21
# 	15  2.204843e-13          22
# 	16  2.203047e-13          23
# 	17  2.202603e-13          24
# 	18  2.198347e-13          25
# 	19  2.198347e-13          27
# 	20  2.193489e-13          28
# 	21  2.193109e-13          30
# ]
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data

# %%
sympy.simplify(model2.sympy())
# Out:
# 0.0019560584*exp(-25.7629703674315*Ea)
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data

# %%
model2.get_best()
# Out:
# complexity                                                     6
# loss                                                         0.0
# equation                      0.0019560584 / exp(Ea / 0.0388154)
# score                                                   0.336828
# sympy_format                      0.0019560584/exp(Ea/0.0388154)
# lambda_format    PySRFunction(X=>0.0019560584/exp(Ea/0.0388154))
# Name: 3, dtype: object
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data

# %%
1/0.0388154
# Out:
# 25.762970367431482
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data

# %%
1/(kb*500)
# Out:
# 23.20903624310016

# %%
opt_funct = 1.704458640741253e-04*E/np.exp(E) - 1.390360191953970e-07
pysr_fuct =  0.000977952*np.exp(-E)
pysr_fuct2 =  0.0019560584*np.exp(-25.762970367431482*Ea)
plt.scatter(E , D, alpha = 0.5, color = 'blue', label = 'D_sim vs E')
plt.scatter(E , pysr_fuct, color = 'm', label = 'PySR optimal function')
plt.scatter(E , pysr_fuct2, alpha = 0.5, color = 'g', label = 'PySR optimal function 2')
plt.scatter(E, opt_funct, label='SISSO optimal function', color = 'orange')
plt.xlabel(r'E\($k_B$T)')
plt.ylabel('D')
plt.legend()
plt.show()
# Out:
# Error in callback _flush_stdio (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/avYrV/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data
